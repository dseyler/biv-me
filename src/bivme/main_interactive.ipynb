# %% [markdown]
# # Interactive version of biv-me
# This jupyter notebook contains an identical implementation of biv-me to the main.py. The only difference is that it can be run step-by-step, allowing you to make manual corrections if and when needed to both the view selection and segmentation steps, which can be prone to occasional errors.
#
# The only thing you will need on top of the regular biv-me environment is to download a Python IDE which can run Jupyter notebooks (e.g. Visual Studio Code), and install the ipython kernel as below.
#
# ```
# conda install -n bivme311 ipykernel --update-deps --force-reinstall
# ```
#
# When you run the notebook, you will be prompted to select the kernel to use. Make sure to select your bivme311 environment.
#
# ### Troubleshooting model performance
# Though we are confident in the robustness of our deep learning models, they may not work perfectly for your data. If you find that the segmentation or view selection models perform poorly for your data, reach out to us at [joshua.dillon@auckland.ac.nz](joshua.dillon@auckland.ac.nz) or [charlene.1.mauger@kcl.ac.uk](charlene.1.mauger@kcl.ac.uk) and let us know what kind of data you are using. We are actively developing these models and always looking for ways to enhance their generalisability across vendors, protocols, centres, and patient demographics.

# %%
# Import libraries
import os,sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import tomli
from pathlib import Path
import shutil
import time
import datetime
from loguru import logger

import warnings
warnings.filterwarnings('ignore')

# %%
# This allows for modules to be reloaded automatically if you make any changes to those files.
# %load_ext autoreload
# %autoreload 2

# %%
# Import modules
from bivme.preprocessing.dicom.extract_cines import extract_cines
from bivme.preprocessing.dicom.select_views import select_views
from bivme.preprocessing.dicom.segment_views import segment_views
from bivme.preprocessing.dicom.correct_phase_mismatch import correct_phase_mismatch
from bivme.preprocessing.dicom.generate_contours import generate_contours
from bivme.preprocessing.dicom.export_guidepoints import export_guidepoints
from bivme.plotting.plot_guidepoints import generate_html 
from main import run_fitting

# %%
# Set up logging
log_level = "DEBUG"
log_format = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS zz}</green> | <level>{level: <8}</level> | <yellow>Line {line: >4} ({file}):</yellow> <b>{message}</b>"

# %%
# Check if GPU is available (torch)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2025-07-11 14:21:06.510 | INFO     | __main__:<module>:3 - Using device: cuda

# %% [markdown]
# # Config file
# As with the main.py, you should customise the template config file in `src/bivme/configs/config.toml` for your specific batch and use case. This config file will be read in and the inputs used for the remainder of this pipeline.

# %%
config_file = 'configs/plane-test-config.toml' # Path to the config file

# %%
# Load config
with open(config_file, mode="rb") as fp:
    logger.info(f'Loading config file: {config_file}')
    config = tomli.load(fp)

# TOML Schema Validation
# This needs to be done to make sure the config file is valid.
# Going forward, we will trust you that all of the inputs in the config file are correct, unlike the main.py which does not trust you.

match config:
    case {
        "modules": {"preprocessing": bool(), "fitting": bool()},

        "logging": {"show_detailed_logging": bool(), "generate_log_file": bool()},

        "input_pp": {"source": str(),
                    "batch_ID": str(),
                    "analyst_id": str(),
                    "processing": str(),
                    "states": str()
                    },
        "view-selection": {"option": str(), "correct_mode": str()},
        "output_pp": {"overwrite": bool(), "generate_plots": bool(), "output_directory": str()},

        "input_fitting": {"gp_directory": str(),
                    "gp_suffix": str(),
                    "si_suffix": str(),
                    },
        "breathhold_correction": {"shifting": str(), "ed_frame": int()},
        "gp_processing": {"sampling": int(), "num_of_phantom_points_av": int(), "num_of_phantom_points_mv": int(), "num_of_phantom_points_tv": int(), "num_of_phantom_points_pv": int()},
        "multiprocessing": {"workers": int()},
        "fitting_weights": {"guide_points": float(), "convex_problem": float(), "transmural": float()},
        "output_fitting": {"output_directory": str(), "output_meshes": list(), "closed_mesh": bool(),   "export_control_mesh": bool(), "mesh_format": str(),  "overwrite": bool()},
    }:
        pass
    case _:
            raise ValueError(f"Invalid configuration: {config}")
# Out:
# 2025-07-11 14:21:06.781 | INFO     | __main__:<module>:3 - Loading config file: configs/plane-test-config.toml

# %% [markdown]
# ## Start of preprocessing
# This code reads in DICOM files and generates GPFiles for personalised biventricular mesh fitting.

# %% [markdown]
# ## Step 0: Set up directories
# All directories will be created for you except for the input_path. This should point to your DICOMs, separated into folders by case like so:
#
#     input_path
#     └─── case1
#         │─── *
#     └─── case2
#         │─── *
#     └─── ...
#
# Don't worry about preprocessing your dicoms, separating by scan type, or excluding non-cines. The pipeline should find which ones are cines and which ones aren't by checking key terms within the series descriptions. Check src/bivme/preprocessing/dicom/extract_cines.py for the list of key terms.

# %%
batch_ID = config['input_pp']['batch_ID'] # This will serve as your output folder name. Example: 'test'
analyst_id = config['input_pp']['analyst_id'] # Example: 'analyst1'
input_path = config['input_pp']['source'] # Path to the input DICOM folder
processed_path = config['input_pp']['processing'] # Path to the processed folder, where view predictions and segmentations will be stored. This will be created upon run time.
states_path = config['input_pp']['states'] # Path to the states folder, where the logs and view predictions will be stored for reference. This will be created upon run time.
output_path = config['output_pp']['output_directory'] # Path to the output folder, where GP files will be stored. This will be created upon run time.
plotting_path = processed_path # Path to the plotting folder, where the HTML file of plotted guidepoints will be stored. This will be created upon run time.

# Target path: src/bivme/preprocessing/dicom/models
# You can hardcode the model path here or set it as an environment variable.
cwd = os.getcwd()
print('Current working directory:', cwd)
MODEL_DIR = os.path.join(cwd,'preprocessing/dicom/models')
print('Model directory:', MODEL_DIR)
# Out:
# Current working directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme
# Model directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme\preprocessing/dicom/models

# %% [markdown]
# ## Step 0.1: Choose case

# %%
case = 'cardiohance_176' # Enter the case ID. This should be a subfolder within the input_path.

# %%
# Set up batch specific folders
src = os.path.join(input_path)
dst = os.path.join(processed_path, batch_ID)
states = os.path.join(states_path, batch_ID)
output = os.path.join(output_path, batch_ID)
plotting = os.path.join(plotting_path, batch_ID)


case_src = os.path.join(src, case)
if not os.path.isdir(case_src):
    logger.error(f'Case {case} not found in source folder. Please check the case ID.')
    sys.exit()

os.makedirs(dst, exist_ok=True)
os.makedirs(states, exist_ok=True)
os.makedirs(output, exist_ok=True)
os.makedirs(plotting, exist_ok=True)

case_dst = os.path.join(dst, case)
case_output = os.path.join(output, case)

if os.path.exists(case_output):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
        shutil.rmtree(case_output)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

elif os.path.exists(case_dst):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

# %%
# Create log file to record some details
states = os.path.join(states, case, analyst_id)
os.makedirs(states, exist_ok=True)

logger_id = logger.add(f'{states}/log_file_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.log', level=log_level, format=log_format,
    colorize=False, backtrace=True,
    diagnose=True)

logger.info(f'Processing case: {case}')

start_time = time.time()
# Out:
# 2025-07-11 14:21:07.279 | INFO     | __main__:<module>:9 - Processing case: cardiohance_176

# %% [markdown]
# ## Step 0.2: Pre-preprocess dicoms
# By default, the pipeline takes in only cardiac cine images in .dcm format. The pre-preprocessing reads in the raw dicoms and uses the series descriptions to infer which are cines and which aren't. The 'cine only' dicoms are saved to:
#
#     processed_path
#     └───batch_ID
#         └───processed-dicoms

# %%
logger.info(f'Finding cines...')
extract_cines(case_src, case_dst, logger)

case_src = os.path.join(case_dst, 'processed-dicoms') # Update source directory

logger.success(f'Pre-preprocessing complete. Cines extracted to {case_src}.')
# Out:
# 2025-07-11 14:21:07.410 | INFO     | __main__:<module>:1 - Finding cines...
# 2025-07-11 14:21:07.654 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:45 - Found 275 images in the source directory
# 2025-07-11 14:21:07.655 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:46 - Extracted 275 which matched the inclusion criteria.
# 2025-07-11 14:21:08.928 | SUCCESS  | __main__:<module>:6 - Pre-preprocessing complete. Cines extracted to C:\Users\jdil469\bivme-data\fitting\processed\plane-test\cardiohance_176\processed-dicoms.

# %% [markdown]
# ## Step 1: View selection
# View selection can be carried out in three main ways.
#
# The first option is the **'default'** option. This involves the use of two models - one using only dicom metadata and one using only image data. The metadata predictions are only broad categories (SAX, LAX, or Outflow) and are used to correct image-based predictions. This should be the most robust option, but takes longer to complete.
#
# The second option is the **'image-only'** option. This only uses image data. Use this if the metadata step is adding unnecessary time, or is not performing as expected.
#
# The third option is the **'load'** option. This loads view predictions from the states folder. This is useful if view predictions have already been made, avoiding the need to rerun prediction from scratch. It also allows for you to make and save manual corrections to the selected views.
#
# On top of these options, you can also manually review and correct the selected views using a simple GUI. There are three options - **'manual'**, which always launches the GUI after view selection, **'adaptive'**, which only launches the GUI if there are low confidence predictions or missing views, or **'automatic'**, which does not launch the GUI and keeps the automatic predictions as they are.
#
# #### Important note about required views
# To proceed with fitting, you must have at least some SAX images and a 4ch image. This is because the fitting requires landmarks from the 4ch image to initialise the model (mitral valve, tricuspid valve, and apex point). The SAX images are required, along with at least one long axis image e.g. 4ch, to correct for breath-hold misalignment. Using the GUI on **'adaptive'** mode will make sure that you never miss a required view.

# %%
option = 'default' # Either 'default', 'image-only', or 'load'. 
# 'default' will combine dicom metadata and image data to select the correct view. 'metadata-only' will only use metadata. 'image-only' will only use the image data. 
# 'load' will load view predictions from the states folder, if view predictions have already been made.

correct_mode = 'manual' # Either 'manual', 'adaptive', or 'automatic'. 
# 'manual' will launch a GUI after completing view predictions to allow you to correct any mispredictions. 
# 'adaptive' will only launch a GUI if there are any poor predictions or missing views
# 'automatic' will not launch the GUI and will use the predictions as they are.

slice_info_df, num_phases, slice_mapping = select_views(case, case_src, case_dst, MODEL_DIR, states, option, correct_mode, logger)

logger.success(f'View selection complete.')
logger.info(f'Number of phases: {num_phases}')
# Out:
# 2025-07-11 14:21:09.065 | INFO     | bivme.preprocessing.dicom.select_views:select_views:97 - Performing metadata-based view prediction...
# 2025-07-11 14:21:13.709 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:100 - Metadata-based view prediction complete.
# 2025-07-11 14:21:13.710 | INFO     | bivme.preprocessing.dicom.select_views:select_views:103 - Performing image-based view prediction...
# 2025-07-11 14:21:20.553 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:107 - Image-based view prediction complete.
# 2025-07-11 14:21:20.554 | INFO     | bivme.preprocessing.dicom.select_views:select_views:110 - Combining metadata and image-based view predictions...
# 2025-07-11 14:21:20.577 | WARNING  | bivme.preprocessing.dicom.select_views:select_views:134 - Low confidence for series 8001 with image based prediction (SAX). Metadata-based prediction is SAX.
# 2025-07-11 14:21:20.586 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:181 - View predictions for cardiohance_176:
# 2025-07-11 14:21:20.588 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 3ch: 1 series
# 2025-07-11 14:21:20.589 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX: 5 series
# 2025-07-11 14:21:20.590 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch: 1 series
# 2025-07-11 14:21:20.590 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 4ch: 1 series
# 2025-07-11 14:21:20.592 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - RVOT: 1 series
# 2025-07-11 14:21:20.593 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX-atria: 1 series
# 2025-07-11 14:21:20.594 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch-RT: 1 series
# 2025-07-11 14:21:20.733 | INFO     | bivme.preprocessing.dicom.select_views:select_views:200 - Manual corrections mode enabled. Launching view correction GUI...
# 2025-07-11 14:22:12.433 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:55 - ----- Saving view predictions...
# 2025-07-11 14:22:12.435 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 10001 corrected to SAX.
# 2025-07-11 14:22:12.436 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 11001 corrected to SAX.
# 2025-07-11 14:22:12.437 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 12001 corrected to SAX.
# 2025-07-11 14:22:12.438 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 14001 corrected to 4ch.
# 2025-07-11 14:22:12.439 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 16001 corrected to 3ch.
# 2025-07-11 14:22:12.439 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 17001 corrected to 2ch.
# 2025-07-11 14:22:12.440 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 19001 corrected to 2ch-RT.
# 2025-07-11 14:22:12.440 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 22001 corrected to RVOT.
# 2025-07-11 14:22:12.441 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 7001 corrected to SAX-atria.
# 2025-07-11 14:22:12.442 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 8001 corrected to SAX.
# 2025-07-11 14:22:12.442 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 9001 corrected to SAX.
# 2025-07-11 14:22:12.444 | SUCCESS  | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:72 - ----- View predictions saved successfully. Close the window to continue.
# 2025-07-11 14:22:17.273 | SUCCESS  | bivme.preprocessing.dicom.select_views:correct_views:89 - View correction complete. Predictions saved.
# 2025-07-11 14:22:17.285 | SUCCESS  | __main__:<module>:12 - View selection complete.
# 2025-07-11 14:22:17.286 | INFO     | __main__:<module>:13 - Number of phases: 25

# %% [markdown]
# ## Step 2: Segmentation
# Using the view classifications from step 1, images will be written into nifti form and sent to the segmentation models to be automatically segmented. There is one segmentation model specific to each view (currently SAX, 2ch, 3ch, 4ch, or RVOT), so only images belonging to those classes will be used from now on.

# %%
## Segmentation
seg_start_time = time.time()
segment_views(case_dst, MODEL_DIR, slice_info_df, logger) # Segmentation occurs on 2D+t (3D) images using 3D nnU-Net models
seg_end_time = time.time()

logger.success(f'Segmentation complete. Time taken: {seg_end_time-seg_start_time} seconds.')
# Out:
# 2025-07-11 14:22:20.142 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing SAX images to nifti files...
# 2025-07-11 14:22:20.310 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting SAX images...
# There are 5 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 5 cases that I would like to predict
#
# Predicting SAX_3d_10001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:03<00:00,  1.77s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_10001
#
# Predicting SAX_3d_11001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_11001
#
# Predicting SAX_3d_12001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.46it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_12001
#
# Predicting SAX_3d_8001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_8001
#
# Predicting SAX_3d_9001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.62it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_9001
# 2025-07-11 14:22:40.427 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with SAX
# 2025-07-11 14:22:40.431 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 2ch images to nifti files...
# 2025-07-11 14:22:40.467 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 2ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 2ch_3d_17001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.82s/it]
# sending off prediction to background worker for resampling and export
# done with 2ch_3d_17001
# 2025-07-11 14:22:53.795 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 2ch
# 2025-07-11 14:22:53.798 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 3ch images to nifti files...
# 2025-07-11 14:22:53.833 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 3ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 3ch_3d_16001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:05<00:00,  1.29s/it]
# sending off prediction to background worker for resampling and export
# done with 3ch_3d_16001
# 2025-07-11 14:23:09.994 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 3ch
# 2025-07-11 14:23:09.996 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 4ch images to nifti files...
# 2025-07-11 14:23:10.031 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 4ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 4ch_3d_14001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:05<00:00,  1.46s/it]
# sending off prediction to background worker for resampling and export
# done with 4ch_3d_14001
# 2025-07-11 14:23:26.734 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 4ch
# 2025-07-11 14:23:26.738 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing RVOT images to nifti files...
# 2025-07-11 14:23:26.767 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting RVOT images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting RVOT_3d_22001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.28s/it]
# sending off prediction to background worker for resampling and export
# done with RVOT_3d_22001
# 2025-07-11 14:23:39.493 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with RVOT
# 2025-07-11 14:23:39.495 | SUCCESS  | __main__:<module>:6 - Segmentation complete. Time taken: 79.3541829586029 seconds.

# %% [markdown]
# ## Step 2.1: Correct for mismatching phases (conditional)
# Often, LAX and SAX series do not have matching number of phases. In that case, we need to resample segmentations to have the same number of phases. We use the SAX series as the reference for the 'right' number of phases.

# %%
## Resample segmentations if phases are not consistent between SAX and LAX views
correct_phase_mismatch(case_dst, slice_info_df, num_phases, logger)
# Out:
# 2025-07-11 14:23:39.718 | SUCCESS  | bivme.preprocessing.dicom.correct_phase_mismatch:correct_phase_mismatch:27 - No phase mismatches found. No resampling required.

# %% [markdown]
# ## Step 2.2: Review segmentations (optional)
# Images and segmentations are stored here in nifti format (.nii.gz).
#
#     processed_path
#     └───batch_ID
#         └───case
#
#
# Hopefully it won't be necessary 99% of the time, but, if you wish, segmentations can be corrected here, and the rest of the code will incorporate those changes.
#
# By default, the contouring code (after segmentation) carries out some basic QC. All label types (except for the RV myocardium) have all but their largest components removed, so you shouldn't need to worry about fixing minor things such as removing extraneous label regions. If you find a problem with the exported contours or fitted models, it's more likely due to poor RV myo segmentation or poor segmentation around valve planes.
#
# 3D Slicer or ITKSnap are good tools for correcting segmentations. We are working on a way to automatically load the images and segmentations into Slicer via a Python backend to make this review process easier.

# %% [markdown]
# ## Step 3: Generate contours
# Contours are generated from the perimeters of the segmentation labels, and other key landmarks (mitral valve, tricuspid valve, aortic valve, pulmonary valve, rv inserts, and LV apex) are estimated from intersections of contours. 2D contours are transformed into 3D cartesian space using the affine constructed from the image position, orientation, and pixel spacing metadata in the DICOMs.

# %%
slice_dict = generate_contours(case_dst, slice_info_df, num_phases, logger)
logger.success(f'Guide points generated successfully.')
# Out:
# 2025-07-11 14:23:39.863 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 8001...
# 2025-07-11 14:23:40.008 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 9001...
# 2025-07-11 14:23:40.222 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 10001...
# 2025-07-11 14:23:40.374 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 11001...
# 2025-07-11 14:23:40.471 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 12001...
# 2025-07-11 14:23:40.533 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 2ch slice 17001...
# 2025-07-11 14:23:40.632 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 3ch slice 16001...
# 2025-07-11 14:23:40.821 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 4ch slice 14001...
# 2025-07-11 14:23:41.017 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for RVOT slice 22001...
# 2025-07-11 14:23:41.160 | SUCCESS  | __main__:<module>:2 - Guide points generated successfully.

# %% [markdown]
# ## Step 4: Export guidepoints
# Contours are then exported into a standardised form, called a GPFile. There is one of these files per frame. This is what the model fitting part of the code requires. There is also a SliceInfoFile which contains the affine information for each slice, which is necessary to allow for breath hold correction prior to model fitting.

# %%
gp_dir = os.path.join(output, case)
export_guidepoints(case_dst, gp_dir, slice_dict, slice_mapping, smooth_landmarks=True)
logger.success(f'Guide points exported successfully.')
logger.success(f'Case {case} complete.')
logger.info(f'Total time taken: {time.time()-start_time} seconds.')
# Out:
# 2025-07-11 14:23:43.251 | SUCCESS  | __main__:<module>:3 - Guide points exported successfully.
# 2025-07-11 14:23:43.252 | SUCCESS  | __main__:<module>:4 - Case cardiohance_176 complete.
# 2025-07-11 14:23:43.252 | INFO     | __main__:<module>:5 - Total time taken: 155.97091031074524 seconds.

# %% [markdown]
# ## Step 5 (Optional): Plot guidepoints
# The code below will plot the guidepoints at each frame as html files, which can be viewed at:
#
#     plotting_path
#     └───batch_ID
#         └───case
#             └───html
#
# Here's a good place to find any issues before proceeding to model fitting.

# %%
gp_dir = os.path.join(output, case)
generate_html(gp_dir, out_dir=plotting, gp_suffix='', si_suffix='', frames_to_fit=[], my_logger=logger, model_path=None)

logger.info(f'Guidepoints plotted at {os.path.join(plotting,case,"html")}.')
# Out:
# 2025-07-11 14:23:43.441 | INFO     | bivme.plotting.plot_guidepoints:generate_html:63 - case: cardiohance_176
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-07-11 14:23:47.663 | INFO     | __main__:<module>:4 - Guidepoints plotted at C:\Users\jdil469\bivme-data\fitting\processed\plane-test\cardiohance_176\html.

# %% [markdown]
# # Start of model fitting

# %% [markdown]
# # Step 6: Model fitting
# The model fitting takes in the GPFiles and SliceInfoFiles generated during preprocessing to generate biventricular meshes at each frame. An iterative linear least squares fit is applied, as described in Mauger, C., Gilbert, K., Suinesiaputra, A., Pontre, B., Omens, J., McCulloch, A., & Young, A. (2018, July). An iterative diffeomorphic algorithm for registration of subdivision surfaces: application to congenital heart disease. In 2018 40th Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC) (pp. 596-599). IEEE. DOI: 10.1109/EMBC.2018.8512394.
#
# Breath hold misalignment is corrected by the intersection of short and long axis contours.
#
# Meshes are generated in the output directory you provided in the config file. Mesh vertices are exported in .txt format by default, but can also be exported with faces in .vtk and .obj formats as well for visualisation and postprocessing purposes.
#
# Unfortunately, there is no opportunity for intervention during this step.

# %%
# Set input for fitting equal to the output of preprocessing
config["input_fitting"]["gp_directory"] = output

# Save a copy of the config file to the output folder
output_folder = Path(config["output_fitting"]["output_directory"])
output_folder.mkdir(parents=True, exist_ok=True)
shutil.copy(config_file, output_folder)

# Force overwrite to true
config["output_fitting"]["overwrite"] = True

# %%
# Where Charlène's magic happens
run_fitting(case, config, logger)
# Out:
# 2025-07-11 14:23:48.035 | INFO     | main:run_fitting:26 - Processing cardiohance_176
# 2025-07-11 14:23:48.039 | INFO     | bivme.fitting.perform_fit:perform_fitting:85 - case: cardiohance_176
# 2025-07-11 14:23:48.041 | INFO     | bivme.fitting.perform_fit:perform_fitting:93 - ED set to frame #0
# 2025-07-11 14:23:48.041 | INFO     | bivme.fitting.perform_fit:perform_fitting:110 - Shift measured only at ED frame
# 2025-07-11 14:23:49.427 | INFO     | bivme.fitting.perform_fit:perform_fitting:209 - Calculating pose and scale cardiohance_176...
# 2025-07-11 14:23:49.500 | INFO     | bivme.fitting.perform_fit:perform_fitting:214 - Fitting of cardiohance_176
# 2025-07-11 14:23:49.503 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #0
# 2025-07-11 14:23:49.906 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4008095354005845
# 2025-07-11 14:23:50.271 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.351734831035315
# 2025-07-11 14:23:50.600 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2035150397653895
# 2025-07-11 14:23:50.958 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.11229727474686
# 2025-07-11 14:23:51.316 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.059647996135538
# 2025-07-11 14:23:51.692 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0163976686267864
# 2025-07-11 14:23:52.064 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.957642423039329
# 2025-07-11 14:23:52.436 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8552883661381219
# 2025-07-11 14:23:52.754 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7148745936059961
# 2025-07-11 14:23:53.064 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5274774343785422
# 2025-07-11 14:23:53.398 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.353173108831553
# 2025-07-11 14:23:53.758 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2323020075420674
# 2025-07-11 14:23:53.888 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2323020075420674
# 2025-07-11 14:23:54.243 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2323020075420674
# 2025-07-11 14:23:54.611 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2323020075420674
# 2025-07-11 14:23:54.916 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.068686008453369
# 2025-07-11 14:23:54.998 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2323020075420674
# 2025-07-11 14:23:58.409 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2249537584577812
# 2025-07-11 14:24:00.511 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2218738200238204
# 2025-07-11 14:24:02.720 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2204840776711585
# 2025-07-11 14:24:04.765 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.219827206795123
# 2025-07-11 14:24:06.481 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.562468767166138
# 2025-07-11 14:24:07.776 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_000.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:07.786 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_000.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:07.792 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_000.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:07.793 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #1
# 2025-07-11 14:24:08.096 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3685130645025105
# 2025-07-11 14:24:08.401 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2798826491680177
# 2025-07-11 14:24:08.690 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.17599174611075
# 2025-07-11 14:24:08.984 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0983715876844764
# 2025-07-11 14:24:09.290 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.053265878977645
# 2025-07-11 14:24:09.588 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.014792689215931
# 2025-07-11 14:24:09.873 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9473309314620766
# 2025-07-11 14:24:10.168 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.841186997358479
# 2025-07-11 14:24:10.448 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6870400536141537
# 2025-07-11 14:24:10.729 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.503377595796062
# 2025-07-11 14:24:11.020 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3294261455360126
# 2025-07-11 14:24:11.310 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2126017874017327
# 2025-07-11 14:24:11.400 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2126017874017327
# 2025-07-11 14:24:11.720 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2126017874017327
# 2025-07-11 14:24:12.013 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2126017874017327
# 2025-07-11 14:24:12.049 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.9980404376983643
# 2025-07-11 14:24:12.108 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2126017874017327
# 2025-07-11 14:24:14.533 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2050834912804227
# 2025-07-11 14:24:16.350 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.201867749179462
# 2025-07-11 14:24:18.062 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2004165996044984
# 2025-07-11 14:24:19.750 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1997320182636073
# 2025-07-11 14:24:21.564 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.513363361358643
# 2025-07-11 14:24:22.904 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_001.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:22.914 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_001.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:22.922 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_001.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:22.923 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #2
# 2025-07-11 14:24:23.204 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3469364598537212
# 2025-07-11 14:24:23.478 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.568556519105393
# 2025-07-11 14:24:23.756 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2043675169556303
# 2025-07-11 14:24:24.043 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0460745259863624
# 2025-07-11 14:24:24.321 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9978888079008903
# 2025-07-11 14:24:24.616 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9685315218915815
# 2025-07-11 14:24:24.892 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9158612932195869
# 2025-07-11 14:24:25.160 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.822423688356767
# 2025-07-11 14:24:25.437 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6776084767408603
# 2025-07-11 14:24:25.712 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.494717065947503
# 2025-07-11 14:24:25.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.334034774776629
# 2025-07-11 14:24:26.275 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2065564951691576
# 2025-07-11 14:24:26.552 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2065564951691576
# 2025-07-11 14:24:26.810 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2065564951691576
# 2025-07-11 14:24:27.068 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2065564951691576
# 2025-07-11 14:24:27.299 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.1384100914001465
# 2025-07-11 14:24:27.357 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2065564951691576
# 2025-07-11 14:24:29.648 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1992550478096489
# 2025-07-11 14:24:31.323 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1962676633744036
# 2025-07-11 14:24:32.987 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1949478615487625
# 2025-07-11 14:24:34.652 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1943322691850082
# 2025-07-11 14:24:36.341 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.040619611740112
# 2025-07-11 14:24:37.807 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_002.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:37.819 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_002.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:37.837 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_002.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:37.838 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #3
# 2025-07-11 14:24:38.170 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.370724609347462
# 2025-07-11 14:24:38.456 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2443784328148495
# 2025-07-11 14:24:38.763 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.123531626936298
# 2025-07-11 14:24:39.051 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0355315437277244
# 2025-07-11 14:24:39.353 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9975791699290222
# 2025-07-11 14:24:39.660 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9693109346481878
# 2025-07-11 14:24:40.034 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9207877261490616
# 2025-07-11 14:24:40.366 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8215044435227563
# 2025-07-11 14:24:40.666 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6794225952160582
# 2025-07-11 14:24:41.039 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5008978121976495
# 2025-07-11 14:24:41.332 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3362871930925746
# 2025-07-11 14:24:41.615 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2210688214848546
# 2025-07-11 14:24:41.761 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2210688214848546
# 2025-07-11 14:24:42.019 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2210688214848546
# 2025-07-11 14:24:42.282 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2210688214848546
# 2025-07-11 14:24:42.502 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.384356737136841
# 2025-07-11 14:24:42.565 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2210688214848546
# 2025-07-11 14:24:45.003 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2133020213301455
# 2025-07-11 14:24:46.707 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2102220725515394
# 2025-07-11 14:24:48.395 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2088892924706642
# 2025-07-11 14:24:50.079 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.208275362204715
# 2025-07-11 14:24:51.843 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.339906930923462
# 2025-07-11 14:24:53.332 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_003.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:53.341 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_003.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:53.348 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_003.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:24:53.348 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #4
# 2025-07-11 14:24:53.626 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4235326023922203
# 2025-07-11 14:24:53.921 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.303318129320953
# 2025-07-11 14:24:54.212 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1477816268100467
# 2025-07-11 14:24:54.505 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.036279620832711
# 2025-07-11 14:24:54.795 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9964696039326837
# 2025-07-11 14:24:55.070 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9500243147198753
# 2025-07-11 14:24:55.383 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9075279749995206
# 2025-07-11 14:24:55.670 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8061693489535289
# 2025-07-11 14:24:55.971 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.656777310813901
# 2025-07-11 14:24:56.270 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.487422680410413
# 2025-07-11 14:24:56.545 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.32976196998328
# 2025-07-11 14:24:56.654 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.32976196998328
# 2025-07-11 14:24:56.981 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2505599900650368
# 2025-07-11 14:24:57.102 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2505599900650368
# 2025-07-11 14:24:57.222 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2505599900650368
# 2025-07-11 14:24:57.284 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.7018978595733643
# 2025-07-11 14:24:57.346 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2505599900650368
# 2025-07-11 14:24:59.867 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.239414809467053
# 2025-07-11 14:25:01.565 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 4.280304670333862
# 2025-07-11 14:25:02.895 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_004.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:02.905 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_004.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:02.914 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_004.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:02.914 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #5
# 2025-07-11 14:25:03.193 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.505725253328823
# 2025-07-11 14:25:03.464 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2900324328903885
# 2025-07-11 14:25:03.753 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.100203841493922
# 2025-07-11 14:25:04.038 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.024570995554812
# 2025-07-11 14:25:04.315 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.972754680828568
# 2025-07-11 14:25:04.588 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.943140451382379
# 2025-07-11 14:25:04.870 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.900905622300224
# 2025-07-11 14:25:05.159 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8011413598361599
# 2025-07-11 14:25:05.457 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6561822008434088
# 2025-07-11 14:25:05.746 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4900072476217843
# 2025-07-11 14:25:06.032 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3280861069631062
# 2025-07-11 14:25:06.326 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2108855376105916
# 2025-07-11 14:25:06.515 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2108855376105916
# 2025-07-11 14:25:06.722 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2108855376105916
# 2025-07-11 14:25:06.898 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2108855376105916
# 2025-07-11 14:25:07.032 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.880784749984741
# 2025-07-11 14:25:07.082 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2108855376105916
# 2025-07-11 14:25:09.351 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.203299372194251
# 2025-07-11 14:25:11.076 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.200180709788387
# 2025-07-11 14:25:12.706 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1987993122442608
# 2025-07-11 14:25:14.303 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1981541143391194
# 2025-07-11 14:25:15.931 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.899245977401733
# 2025-07-11 14:25:17.266 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_005.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:17.276 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_005.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:17.285 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_005.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:17.286 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #6
# 2025-07-11 14:25:17.578 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.6719902065045606
# 2025-07-11 14:25:17.867 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.6167106842792167
# 2025-07-11 14:25:18.144 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1836487769432398
# 2025-07-11 14:25:18.412 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0533076386127456
# 2025-07-11 14:25:18.685 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0041705564602705
# 2025-07-11 14:25:19.036 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9759408468315136
# 2025-07-11 14:25:19.326 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.933164423878858
# 2025-07-11 14:25:19.622 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8402883171449518
# 2025-07-11 14:25:19.883 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6995855260823545
# 2025-07-11 14:25:20.189 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.517669653723796
# 2025-07-11 14:25:20.517 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3380138009138083
# 2025-07-11 14:25:20.872 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2121275864420595
# 2025-07-11 14:25:20.978 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2121275864420595
# 2025-07-11 14:25:21.090 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2121275864420595
# 2025-07-11 14:25:21.208 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2121275864420595
# 2025-07-11 14:25:21.294 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.754269599914551
# 2025-07-11 14:25:21.400 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2121275864420595
# 2025-07-11 14:25:23.805 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2037581016276941
# 2025-07-11 14:25:25.306 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 4.009398698806763
# 2025-07-11 14:25:26.619 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_006.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:26.627 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_006.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:26.636 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_006.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:26.637 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #7
# 2025-07-11 14:25:26.889 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.7790486123370126
# 2025-07-11 14:25:27.177 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.2292876505734767
# 2025-07-11 14:25:27.478 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.3654049657480325
# 2025-07-11 14:25:27.758 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1046360581807892
# 2025-07-11 14:25:28.034 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0330662523666403
# 2025-07-11 14:25:28.302 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9929797678665075
# 2025-07-11 14:25:28.581 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9579813935083994
# 2025-07-11 14:25:28.880 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8589948133639254
# 2025-07-11 14:25:29.147 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7189443258285944
# 2025-07-11 14:25:29.418 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5379521586234541
# 2025-07-11 14:25:29.694 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.339403232095483
# 2025-07-11 14:25:29.964 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1972148259756492
# 2025-07-11 14:25:30.154 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1972148259756492
# 2025-07-11 14:25:30.347 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1972148259756492
# 2025-07-11 14:25:30.543 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1972148259756492
# 2025-07-11 14:25:30.701 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.847172260284424
# 2025-07-11 14:25:30.748 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1972148259756492
# 2025-07-11 14:25:33.087 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1898533423705742
# 2025-07-11 14:25:34.691 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1868058690286982
# 2025-07-11 14:25:36.309 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1854455506688064
# 2025-07-11 14:25:37.916 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1848066402240078
# 2025-07-11 14:25:39.491 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.789697885513306
# 2025-07-11 14:25:40.745 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_007.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:40.754 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_007.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:40.760 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_007.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:40.761 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #8
# 2025-07-11 14:25:40.979 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8675417520939894
# 2025-07-11 14:25:41.257 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.6478449668153745
# 2025-07-11 14:25:41.530 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2717970852062908
# 2025-07-11 14:25:41.797 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.121622990962637
# 2025-07-11 14:25:42.062 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0668044179437906
# 2025-07-11 14:25:42.331 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0238711778458165
# 2025-07-11 14:25:42.590 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9889361451158367
# 2025-07-11 14:25:42.855 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8889554902984307
# 2025-07-11 14:25:43.143 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.744530631389624
# 2025-07-11 14:25:43.412 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.552019804565273
# 2025-07-11 14:25:43.674 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3470740478039587
# 2025-07-11 14:25:43.776 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3470740478039587
# 2025-07-11 14:25:44.047 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2394868688375436
# 2025-07-11 14:25:44.144 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2394868688375436
# 2025-07-11 14:25:44.244 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2394868688375436
# 2025-07-11 14:25:44.307 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.3616244792938232
# 2025-07-11 14:25:44.356 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2394868688375436
# 2025-07-11 14:25:46.793 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2288754521228695
# 2025-07-11 14:25:48.463 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2243581147965203
# 2025-07-11 14:25:50.112 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2222901308075294
# 2025-07-11 14:25:51.752 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2213047114060753
# 2025-07-11 14:25:53.386 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.077776432037354
# 2025-07-11 14:25:54.866 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_008.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:54.875 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_008.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:54.883 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_008.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:25:54.883 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #9
# 2025-07-11 14:25:55.109 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.887708522187935
# 2025-07-11 14:25:55.384 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.5018142870658644
# 2025-07-11 14:25:55.692 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2805260067235427
# 2025-07-11 14:25:55.972 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1564233663493884
# 2025-07-11 14:25:56.232 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0954822111755957
# 2025-07-11 14:25:56.495 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0460286325008776
# 2025-07-11 14:25:56.770 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 2.0041119247650623
# 2025-07-11 14:25:57.038 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.892977452278948
# 2025-07-11 14:25:57.405 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7387794735620965
# 2025-07-11 14:25:57.689 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.544305258880778
# 2025-07-11 14:25:57.971 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3253787964236778
# 2025-07-11 14:25:58.247 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1959980104728247
# 2025-07-11 14:25:58.432 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1959980104728247
# 2025-07-11 14:25:58.623 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1959980104728247
# 2025-07-11 14:25:58.823 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1959980104728247
# 2025-07-11 14:25:58.979 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.902759313583374
# 2025-07-11 14:25:59.024 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1959980104728247
# 2025-07-11 14:26:01.340 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.188782798391459
# 2025-07-11 14:26:02.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1858808928109683
# 2025-07-11 14:26:04.656 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1846077378961917
# 2025-07-11 14:26:06.315 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.335272312164307
# 2025-07-11 14:26:07.614 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_009.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:26:07.623 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_009.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:26:07.630 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_009.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:26:07.631 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #10
# 2025-07-11 14:26:07.851 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8894857621371903
# 2025-07-11 14:26:08.106 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.190386340157654
# 2025-07-11 14:26:08.387 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.253854936317684
# 2025-07-11 14:26:08.683 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1345304372147886
# 2025-07-11 14:26:08.954 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.081358039806736
# 2025-07-11 14:26:09.253 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0362219332944664
# 2025-07-11 14:26:09.521 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9849165075277768
# ...
# 2025-07-11 14:28:34.576 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1963182653344007
# 2025-07-11 14:28:36.208 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1930262046885547
# 2025-07-11 14:28:37.844 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.191592980501252
# 2025-07-11 14:28:39.487 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1909303436532737
# 2025-07-11 14:28:41.106 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.872995376586914
# 2025-07-11 14:28:42.476 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_021.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:28:42.487 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_021.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:28:42.496 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_021.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:28:42.496 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #22
# 2025-07-11 14:28:42.809 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.375869110231275
# 2025-07-11 14:28:43.098 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3147310306897024
# 2025-07-11 14:28:43.390 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1952067536270667
# 2025-07-11 14:28:43.670 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1093948715125967
# 2025-07-11 14:28:43.969 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0439234961000117
# 2025-07-11 14:28:44.265 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0132672947188843
# 2025-07-11 14:28:44.551 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9579127172354869
# 2025-07-11 14:28:44.854 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8385617793138906
# 2025-07-11 14:28:45.150 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6803064607459324
# 2025-07-11 14:28:45.435 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.504867006282256
# 2025-07-11 14:28:45.722 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.345961365446751
# 2025-07-11 14:28:46.007 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2298137065625974
# 2025-07-11 14:28:46.275 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2298137065625974
# 2025-07-11 14:28:46.560 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2298137065625974
# 2025-07-11 14:28:46.861 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2298137065625974
# 2025-07-11 14:28:47.085 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.323517322540283
# 2025-07-11 14:28:47.146 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2298137065625974
# 2025-07-11 14:28:49.623 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.221921388460261
# 2025-07-11 14:28:51.373 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2187136287111704
# 2025-07-11 14:28:53.014 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2172976261545445
# 2025-07-11 14:28:54.618 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2166363147698322
# 2025-07-11 14:28:56.233 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.14689302444458
# 2025-07-11 14:28:57.575 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_022.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:28:57.586 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_022.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:28:57.596 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_022.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:28:57.597 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #23
# 2025-07-11 14:28:57.927 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.403060088733344
# 2025-07-11 14:28:58.225 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3256357715777884
# 2025-07-11 14:28:58.521 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.207547911020586
# 2025-07-11 14:28:58.841 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.113670471675661
# 2025-07-11 14:28:59.143 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0583065892643075
# 2025-07-11 14:28:59.436 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0161294929210323
# 2025-07-11 14:28:59.742 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9702554986269623
# 2025-07-11 14:29:00.027 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8642083602154178
# 2025-07-11 14:29:00.315 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7095053157589193
# 2025-07-11 14:29:00.608 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5224074300990942
# 2025-07-11 14:29:00.909 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3584509009288481
# 2025-07-11 14:29:01.191 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2376256008255209
# 2025-07-11 14:29:01.465 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2376256008255209
# 2025-07-11 14:29:01.734 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2376256008255209
# 2025-07-11 14:29:02.035 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2376256008255209
# 2025-07-11 14:29:02.262 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.381002902984619
# 2025-07-11 14:29:02.321 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2376256008255209
# 2025-07-11 14:29:04.765 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2314878241945058
# 2025-07-11 14:29:06.511 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2291230915584856
# 2025-07-11 14:29:08.169 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2281168913870493
# 2025-07-11 14:29:09.757 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.493978500366211
# 2025-07-11 14:29:11.026 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_023.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:29:11.037 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_023.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:29:11.044 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_023.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:29:11.044 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #24
# 2025-07-11 14:29:11.350 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.436870929853748
# 2025-07-11 14:29:11.638 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3477219717743756
# 2025-07-11 14:29:11.926 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.221794739903366
# 2025-07-11 14:29:12.215 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1300388275922106
# 2025-07-11 14:29:12.510 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.070257321160457
# 2025-07-11 14:29:12.798 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.024136419307296
# 2025-07-11 14:29:13.078 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9771890919100354
# 2025-07-11 14:29:13.376 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8749379157819648
# 2025-07-11 14:29:13.664 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7118807917284735
# 2025-07-11 14:29:13.947 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5315825723771144
# 2025-07-11 14:29:14.233 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3660285392127574
# 2025-07-11 14:29:14.510 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2514936212885555
# 2025-07-11 14:29:14.599 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2514936212885555
# 2025-07-11 14:29:14.684 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2514936212885555
# 2025-07-11 14:29:14.773 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2514936212885555
# 2025-07-11 14:29:14.813 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.5074615478515625
# 2025-07-11 14:29:14.874 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2514936212885555
# 2025-07-11 14:29:17.170 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2439545638396867
# 2025-07-11 14:29:18.815 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.240856964328528
# 2025-07-11 14:29:20.541 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.239477070122107
# 2025-07-11 14:29:22.276 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2388298164973348
# 2025-07-11 14:29:23.932 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.118173837661743
# 2025-07-11 14:29:25.225 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_LV_ENDOCARDIAL_024.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:29:25.235 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_EPICARDIAL_024.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# 2025-07-11 14:29:25.242 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - cardiohance_176_RV_ENDOCARDIAL_024.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\josh-test\cardiohance_176\vtk
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-07-11 14:29:25.256 | INFO     | main:run_fitting:38 - Average residuals: 1.2091527983064745 for case cardiohance_176

# %% [markdown]
# ## (Optional) Analysis and/or visualisation of models
# You can visualise the fitted models frame-by-frame in your browser by opening an html in `output_directory\case\html`. Alternatively, if you have a mesh visualisation software, you can load in the .vtk or .obj files you generated to view the meshes beating through time. I recommend Paraview, as it is open source, and has nice camera controls for creating  videos of the meshes beating through time.
#
# We haven't added any analysis tools to this notebook yet. Refer to the main README on how to generate metrics from the biv-me models.
