# %% [markdown]
# # Interactive version of biv-me
# This jupyter notebook contains an identical implementation of biv-me to the main.py. The only difference is that it can be run step-by-step, allowing you to make manual corrections if and when needed to both the view selection and segmentation steps, which can be prone to occasional errors.
#
# The only thing you will need on top of the regular biv-me environment is to download a Python IDE which can run Jupyter notebooks (e.g. Visual Studio Code), and install the ipython kernel as below.
#
# ```
# conda install -n bivme311 ipykernel --update-deps --force-reinstall
# ```
#
# When you run the notebook, you will be prompted to select the kernel to use. Make sure to select your bivme311 environment.
#
# ### Troubleshooting model performance
# Though we are confident in the robustness of our deep learning models, they may not work perfectly for your data. If you find that the segmentation or view selection models perform poorly for your data, reach out to us at [joshua.dillon@auckland.ac.nz](joshua.dillon@auckland.ac.nz) or [charlene.1.mauger@kcl.ac.uk](charlene.1.mauger@kcl.ac.uk) and let us know what kind of data you are using. We are actively developing these models and always looking for ways to enhance their generalisability across vendors, protocols, centres, and patient demographics.

# %%
# Import libraries
import os,sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import tomli
from pathlib import Path
import shutil
import time
import datetime
from loguru import logger

import warnings
warnings.filterwarnings('ignore')

# %%
# This allows for modules to be reloaded automatically if you make any changes to those files.
# %load_ext autoreload
# %autoreload 2

# %%
# Import modules
from bivme.preprocessing.dicom.extract_cines import extract_cines
from bivme.preprocessing.dicom.select_views import select_views
from bivme.preprocessing.dicom.segment_views import segment_views
from bivme.preprocessing.dicom.correct_phase_mismatch import correct_phase_mismatch
from bivme.preprocessing.dicom.generate_contours import generate_contours
from bivme.preprocessing.dicom.export_guidepoints import export_guidepoints
from bivme.plotting.plot_guidepoints import generate_html 
from main import run_fitting

# %%
# Set up logging
log_level = "DEBUG"
log_format = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS zz}</green> | <level>{level: <8}</level> | <yellow>Line {line: >4} ({file}):</yellow> <b>{message}</b>"

# %%
# Check if GPU is available (torch)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2025-07-22 11:01:11.742 | INFO     | __main__:<module>:3 - Using device: cuda

# %% [markdown]
# # Config file
# As with the main.py, you should customise the template config file in `src/bivme/configs/config.toml` for your specific batch and use case. This config file will be read in and the inputs used for the remainder of this pipeline.

# %%
config_file = 'configs/config.toml' # Path to the config file

# %%
# Load config
with open(config_file, mode="rb") as fp:
    logger.info(f'Loading config file: {config_file}')
    config = tomli.load(fp)

# TOML Schema Validation
# This needs to be done to make sure the config file is valid.
# Going forward, we will trust you that all of the inputs in the config file are correct, unlike the main.py which does not trust you.

match config:
    case {
        "modules": {"preprocessing": bool(), "fitting": bool()},

        "logging": {"show_detailed_logging": bool(), "generate_log_file": bool()},

        "input_pp": {"source": str(),
                    "batch_ID": str(),
                    "analyst_id": str(),
                    "processing": str(),
                    "states": str()
                    },
        "view-selection": {"option": str(), "correct_mode": str()},
        "contouring": {"smooth_landmarks": bool()},
        "output_pp": {"overwrite": bool(), "generate_plots": bool(), "output_directory": str()},

        "input_fitting": {"gp_directory": str(),
                    "gp_suffix": str(),
                    "si_suffix": str(),
                    },
        "breathhold_correction": {"shifting": str(), "ed_frame": int()},
        "gp_processing": {"sampling": int(), "num_of_phantom_points_av": int(), "num_of_phantom_points_mv": int(), "num_of_phantom_points_tv": int(), "num_of_phantom_points_pv": int()},
        "multiprocessing": {"workers": int()},
        "fitting_weights": {"guide_points": float(), "convex_problem": float(), "transmural": float()},
        "output_fitting": {"output_directory": str(), "output_meshes": list(), "closed_mesh": bool(),   "export_control_mesh": bool(), "mesh_format": str(),  "overwrite": bool()},
    }:
        pass
    case _:
            raise ValueError(f"Invalid configuration: {config}")
# Out:
# 2025-07-22 11:01:12.042 | INFO     | __main__:<module>:3 - Loading config file: configs/config.toml

# %% [markdown]
# ## Start of preprocessing
# This code reads in DICOM files and generates GPFiles for personalised biventricular mesh fitting.

# %% [markdown]
# ## Step 0: Set up directories
# All directories will be created for you except for the input_path. This should point to your DICOMs, separated into folders by case like so:
#
#     input_path
#     └─── case1
#         │─── *
#     └─── case2
#         │─── *
#     └─── ...
#
# Don't worry about preprocessing your dicoms, separating by scan type, or excluding non-cines. The pipeline should find which ones are cines and which ones aren't by checking key terms within the series descriptions. Check src/bivme/preprocessing/dicom/extract_cines.py for the list of key terms.

# %%
batch_ID = config['input_pp']['batch_ID'] # This will serve as your output folder name. Example: 'test'
analyst_id = config['input_pp']['analyst_id'] # Example: 'analyst1'
input_path = config['input_pp']['source'] # Path to the input DICOM folder
processed_path = config['input_pp']['processing'] # Path to the processed folder, where view predictions and segmentations will be stored. This will be created upon run time.
states_path = config['input_pp']['states'] # Path to the states folder, where the logs and view predictions will be stored for reference. This will be created upon run time.
output_path = config['output_pp']['output_directory'] # Path to the output folder, where GP files will be stored. This will be created upon run time.
plotting_path = processed_path # Path to the plotting folder, where the HTML file of plotted guidepoints will be stored. This will be created upon run time.

# Target path: src/bivme/preprocessing/dicom/models
# You can hardcode the model path here or set it as an environment variable.
cwd = os.getcwd()
print('Current working directory:', cwd)
MODEL_DIR = os.path.join(cwd,'preprocessing/dicom/models')
print('Model directory:', MODEL_DIR)
# Out:
# Current working directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme
# Model directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme\preprocessing/dicom/models

# %% [markdown]
# ## Step 0.1: Choose case

# %%
case = 'patient1' # Enter the case ID. This should be a subfolder within the input_path.

# %%
# Set up batch specific folders
src = os.path.join(input_path)
dst = os.path.join(processed_path, batch_ID)
states = os.path.join(states_path, batch_ID)
output = os.path.join(output_path, batch_ID)
plotting = os.path.join(plotting_path, batch_ID)


case_src = os.path.join(src, case)
if not os.path.isdir(case_src):
    logger.error(f'Case {case} not found in source folder. Please check the case ID.')
    sys.exit()

os.makedirs(dst, exist_ok=True)
os.makedirs(states, exist_ok=True)
os.makedirs(output, exist_ok=True)
os.makedirs(plotting, exist_ok=True)

case_dst = os.path.join(dst, case)
case_output = os.path.join(output, case)

if os.path.exists(case_output):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
        shutil.rmtree(case_output)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

elif os.path.exists(case_dst):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

# %%
# Create log file to record some details
states = os.path.join(states, case, analyst_id)
os.makedirs(states, exist_ok=True)

logger_id = logger.add(f'{states}/log_file_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.log', level=log_level, format=log_format,
    colorize=False, backtrace=True,
    diagnose=True)

logger.info(f'Processing case: {case}')

start_time = time.time()
# Out:
# 2025-07-22 11:01:12.615 | INFO     | __main__:<module>:9 - Processing case: patient1

# %% [markdown]
# ## Step 0.2: Pre-preprocess dicoms
# By default, the pipeline takes in only cardiac cine images in .dcm format. The pre-preprocessing reads in the raw dicoms and uses the series descriptions to infer which are cines and which aren't. The 'cine only' dicoms are saved to:
#
#     processed_path
#     └───batch_ID
#         └───processed-dicoms

# %%
logger.info(f'Finding cines...')
extract_cines(case_src, case_dst, logger)

case_src = os.path.join(case_dst, 'processed-dicoms') # Update source directory

logger.success(f'Pre-preprocessing complete. Cines extracted to {case_src}.')
# Out:
# 2025-07-22 11:01:12.748 | INFO     | __main__:<module>:1 - Finding cines...
# 2025-07-22 11:01:16.497 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:45 - Found 275 images in the source directory
# 2025-07-22 11:01:16.498 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:46 - Extracted 275 which matched the inclusion criteria.
# 2025-07-22 11:01:17.852 | SUCCESS  | __main__:<module>:6 - Pre-preprocessing complete. Cines extracted to ../../example/processing\test\patient1\processed-dicoms.

# %% [markdown]
# ## Step 1: View selection
# View selection can be carried out in three main ways.
#
# The first option is the **'default'** option. This involves the use of two models - one using only dicom metadata and one using only image data. The metadata predictions are only broad categories (SAX, LAX, or Outflow) and are used to correct image-based predictions. This should be the most robust option, but takes longer to complete.
#
# The second option is the **'image-only'** option. This only uses image data. Use this if the metadata step is adding unnecessary time, or is not performing as expected.
#
# The third option is the **'load'** option. This loads view predictions from the states folder. This is useful if view predictions have already been made, avoiding the need to rerun prediction from scratch. It also allows for you to make and save manual corrections to the selected views.
#
# On top of these options, you can also manually review and correct the selected views using a simple GUI. There are three options - **'manual'**, which always launches the GUI after view selection, **'adaptive'**, which only launches the GUI if there are low confidence predictions or missing views, or **'automatic'**, which does not launch the GUI and keeps the automatic predictions as they are.
#
# #### Important note about required views
# To proceed with fitting, you must have at least some SAX images and a 4ch image. This is because the fitting requires landmarks from the 4ch image to initialise the model (mitral valve, tricuspid valve, and apex point). The SAX images are required, along with at least one long axis image e.g. 4ch, to correct for breath-hold misalignment. Using the GUI on **'adaptive'** mode will make sure that you never miss a required view.

# %%
option = 'default' # Either 'default', 'image-only', or 'load'. 
# 'default' will combine dicom metadata and image data to select the correct view. 'image-only' will only use the image data. 
# 'load' will load view predictions from the states folder, if view predictions have already been made.

correct_mode = 'manual' # Either 'manual', 'adaptive', or 'automatic'. 
# 'manual' will launch a GUI after completing view predictions to allow you to correct any mispredictions. 
# 'adaptive' will only launch a GUI if there are any poor predictions or missing views
# 'automatic' will not launch the GUI and will use the predictions as they are.

slice_info_df, num_phases, slice_mapping = select_views(case, case_src, case_dst, MODEL_DIR, states, option, correct_mode, logger)

logger.success(f'View selection complete.')
logger.info(f'Number of phases: {num_phases}')
# Out:
# 2025-07-22 11:01:17.992 | INFO     | bivme.preprocessing.dicom.select_views:select_views:97 - Performing metadata-based view prediction...
# 2025-07-22 11:01:23.523 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:100 - Metadata-based view prediction complete.
# 2025-07-22 11:01:23.524 | INFO     | bivme.preprocessing.dicom.select_views:select_views:103 - Performing image-based view prediction...
# 2025-07-22 11:01:31.473 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:107 - Image-based view prediction complete.
# 2025-07-22 11:01:31.474 | INFO     | bivme.preprocessing.dicom.select_views:select_views:110 - Combining metadata and image-based view predictions...
# 2025-07-22 11:01:31.507 | WARNING  | bivme.preprocessing.dicom.select_views:select_views:137 - Low confidence for series 8001 with image based prediction (SAX)...
# 2025-07-22 11:01:31.530 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:181 - View predictions for patient1:
# 2025-07-22 11:01:31.532 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX: 5 series
# 2025-07-22 11:01:31.532 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 3ch: 1 series
# 2025-07-22 11:01:31.535 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch: 1 series
# 2025-07-22 11:01:31.536 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 4ch: 1 series
# 2025-07-22 11:01:31.537 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - RVOT: 1 series
# 2025-07-22 11:01:31.538 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX-atria: 1 series
# 2025-07-22 11:01:31.539 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch-RT: 1 series
# 2025-07-22 11:01:31.727 | INFO     | bivme.preprocessing.dicom.select_views:select_views:200 - Manual corrections mode enabled. Launching view correction GUI...
# 2025-07-22 11:01:36.036 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:55 - ----- Saving view predictions...
# 2025-07-22 11:01:36.038 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 10001 saved to SAX.
# 2025-07-22 11:01:36.039 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 11001 saved to SAX.
# 2025-07-22 11:01:36.040 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 12001 saved to SAX.
# 2025-07-22 11:01:36.041 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 14001 saved to 4ch.
# 2025-07-22 11:01:36.042 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 16001 saved to 3ch.
# 2025-07-22 11:01:36.042 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 17001 saved to 2ch.
# 2025-07-22 11:01:36.044 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 19001 saved to 2ch-RT.
# 2025-07-22 11:01:36.045 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 22001 saved to RVOT.
# 2025-07-22 11:01:36.046 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 7001 saved to SAX-atria.
# 2025-07-22 11:01:36.047 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 8001 saved to SAX.
# 2025-07-22 11:01:36.048 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 9001 saved to SAX.
# 2025-07-22 11:01:36.051 | SUCCESS  | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:72 - ----- View predictions saved successfully. Close the window to continue.
# 2025-07-22 11:01:42.248 | SUCCESS  | bivme.preprocessing.dicom.select_views:correct_views:89 - View correction complete. Predictions saved.
# 2025-07-22 11:01:42.259 | SUCCESS  | __main__:<module>:12 - View selection complete.
# 2025-07-22 11:01:42.260 | INFO     | __main__:<module>:13 - Number of phases: 25

# %% [markdown]
# ## Step 2: Segmentation
# Using the view classifications from step 1, images will be written into nifti form and sent to the segmentation models to be automatically segmented. There is one segmentation model specific to each view (currently SAX, 2ch, 3ch, 4ch, or RVOT), so only images belonging to those classes will be used from now on.

# %%
## Segmentation
seg_start_time = time.time()
segment_views(case_dst, MODEL_DIR, slice_info_df, logger) # Segmentation occurs on 2D+t (3D) images using 3D nnU-Net models
seg_end_time = time.time()

logger.success(f'Segmentation complete. Time taken: {seg_end_time-seg_start_time} seconds.')
# Out:
# 2025-07-22 11:01:42.404 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing SAX images to nifti files...
# 2025-07-22 11:01:42.575 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting SAX images...
# There are 5 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 5 cases that I would like to predict
#
# Predicting SAX_3d_10001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:03<00:00,  1.77s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_10001
#
# Predicting SAX_3d_11001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_11001
#
# Predicting SAX_3d_12001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.45it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_12001
#
# Predicting SAX_3d_8001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_8001
#
# Predicting SAX_3d_9001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.66it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_9001
# 2025-07-22 11:02:03.261 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with SAX
# 2025-07-22 11:02:03.264 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 2ch images to nifti files...
# 2025-07-22 11:02:03.300 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 2ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 2ch_3d_17001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.69s/it]
# sending off prediction to background worker for resampling and export
# done with 2ch_3d_17001
# 2025-07-22 11:02:17.172 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 2ch
# 2025-07-22 11:02:17.175 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 3ch images to nifti files...
# 2025-07-22 11:02:17.210 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 3ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 3ch_3d_16001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:05<00:00,  1.28s/it]
# sending off prediction to background worker for resampling and export
# done with 3ch_3d_16001
# 2025-07-22 11:02:33.144 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 3ch
# 2025-07-22 11:02:33.147 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 4ch images to nifti files...
# 2025-07-22 11:02:33.179 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 4ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 4ch_3d_14001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:05<00:00,  1.40s/it]
# sending off prediction to background worker for resampling and export
# done with 4ch_3d_14001
# 2025-07-22 11:02:50.000 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 4ch
# 2025-07-22 11:02:50.002 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing RVOT images to nifti files...
# 2025-07-22 11:02:50.039 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting RVOT images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting RVOT_3d_22001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]
# sending off prediction to background worker for resampling and export
# done with RVOT_3d_22001
# 2025-07-22 11:03:03.061 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with RVOT
# 2025-07-22 11:03:03.064 | SUCCESS  | __main__:<module>:6 - Segmentation complete. Time taken: 80.66045188903809 seconds.

# %% [markdown]
# ## Step 2.1: Correct for mismatching phases (conditional)
# Often, LAX and SAX series do not have matching number of phases. In that case, we need to resample segmentations to have the same number of phases. We use the SAX series as the reference for the 'right' number of phases.

# %%
## Resample segmentations if phases are not consistent between SAX and LAX views
correct_phase_mismatch(case_dst, slice_info_df, num_phases, logger)
# Out:
# 2025-07-22 11:03:03.256 | SUCCESS  | bivme.preprocessing.dicom.correct_phase_mismatch:correct_phase_mismatch:27 - No phase mismatches found. No resampling required.

# %% [markdown]
# ## Step 2.2: Review segmentations (optional)
# Images and segmentations are stored here in nifti format (.nii.gz).
#
#     processed_path
#     └───batch_ID
#         └───case
#
#
# If needed, segmentations can be corrected here, and subsequent code executions will incorporate those changes. 3D Slicer or ITKSnap are good tools for correcting segmentations. We are working on a way to automatically load the images and segmentations into Slicer via a Python backend to make this review process easier.

# %% [markdown]
# ## Step 3: Generate contours
# Contours are generated from the perimeters of the segmentation labels, and other key landmarks (mitral valve, tricuspid valve, aortic valve, pulmonary valve, rv inserts, and LV apex) are estimated from intersections of contours. 2D contours are transformed into 3D cartesian space using the affine constructed from the image position, orientation, and pixel spacing metadata in the DICOMs.

# %%
slice_dict = generate_contours(case_dst, slice_info_df, num_phases, logger)
logger.success(f'Guide points generated successfully.')
# Out:
# 2025-07-22 11:03:03.400 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 8001...
# 2025-07-22 11:03:03.563 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 9001...
# 2025-07-22 11:03:03.781 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 10001...
# 2025-07-22 11:03:03.948 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 11001...
# 2025-07-22 11:03:04.056 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 12001...
# 2025-07-22 11:03:04.140 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 2ch slice 17001...
# 2025-07-22 11:03:04.262 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 3ch slice 16001...
# 2025-07-22 11:03:04.484 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 4ch slice 14001...
# 2025-07-22 11:03:04.684 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for RVOT slice 22001...
# 2025-07-22 11:03:04.838 | SUCCESS  | __main__:<module>:2 - Guide points generated successfully.

# %% [markdown]
# ## Step 4: Export guidepoints
# Contours are then exported into a standardised form, called a GPFile. There is one of these files per frame. This is what the model fitting part of the code requires. There is also a SliceInfoFile which contains the affine information for each slice, which is necessary to allow for breath hold correction prior to model fitting.
#
# Temporal smoothing of landmark points is enabled by default, but can be disabled by changing the boolean below.

# %%
smooth_landmarks = True # Set to True to smooth the landmarks, False to keep them as they are
gp_dir = os.path.join(output, case)

export_guidepoints(case_dst, gp_dir, slice_dict, slice_mapping, smooth_landmarks)
logger.success(f'Guide points exported successfully.')
logger.success(f'Case {case} complete.')
logger.info(f'Total time taken: {time.time()-start_time} seconds.')
# Out:
# 2025-07-22 11:03:07.021 | SUCCESS  | __main__:<module>:5 - Guide points exported successfully.
# 2025-07-22 11:03:07.022 | SUCCESS  | __main__:<module>:6 - Case patient1 complete.
# 2025-07-22 11:03:07.023 | INFO     | __main__:<module>:7 - Total time taken: 114.40659213066101 seconds.

# %% [markdown]
# ## Step 5 (Optional): Plot guidepoints
# The code below will plot the guidepoints at each frame as html files, which can be viewed at:
#
#     plotting_path
#     └───batch_ID
#         └───case
#             └───html
#
# Here's a good place to find any issues before proceeding to model fitting.

# %%
generate_html(gp_dir, out_dir=plotting, gp_suffix='', si_suffix='', frames_to_fit=[], my_logger=logger, model_path=None)

logger.info(f'Guidepoints plotted at {os.path.join(plotting,case,"html")}.')
# Out:
# 2025-07-22 11:03:07.201 | INFO     | bivme.plotting.plot_guidepoints:generate_html:63 - case: patient1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-07-22 11:03:10.947 | INFO     | __main__:<module>:3 - Guidepoints plotted at ../../example/processing\test\patient1\html.

# %% [markdown]
# # Start of model fitting

# %% [markdown]
# # Step 6: Model fitting
# The model fitting takes in the GPFiles and SliceInfoFiles generated during preprocessing to generate biventricular meshes at each frame. An iterative linear least squares fit is applied, as described in Mauger, C., Gilbert, K., Suinesiaputra, A., Pontre, B., Omens, J., McCulloch, A., & Young, A. (2018, July). An iterative diffeomorphic algorithm for registration of subdivision surfaces: application to congenital heart disease. In 2018 40th Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC) (pp. 596-599). IEEE. DOI: 10.1109/EMBC.2018.8512394.
#
# Breath hold misalignment is corrected by the intersection of short and long axis contours.
#
# Meshes are generated in the output directory you provided in the config file. Mesh vertices are exported in .txt format by default, but can also be exported with faces in .vtk and .obj formats as well for visualisation and postprocessing purposes.
#
# Unfortunately, there is no opportunity for intervention during this step.

# %%
# Set input for fitting equal to the output of preprocessing
config["input_fitting"]["gp_directory"] = output

# Save a copy of the config file to the output folder
output_folder = Path(config["output_fitting"]["output_directory"])
output_folder.mkdir(parents=True, exist_ok=True)
shutil.copy(config_file, output_folder)

# Force overwrite to true
config["output_fitting"]["overwrite"] = True

# %%
# Where Charlène's magic happens
run_fitting(case, config, logger)
# Out:
# 2025-07-22 11:03:11.315 | INFO     | main:run_fitting:26 - Processing patient1
# 2025-07-22 11:03:11.318 | INFO     | bivme.fitting.perform_fit:perform_fitting:85 - case: patient1
# 2025-07-22 11:03:11.320 | INFO     | bivme.fitting.perform_fit:perform_fitting:93 - ED set to frame #0
# 2025-07-22 11:03:11.321 | INFO     | bivme.fitting.perform_fit:perform_fitting:110 - Shift measured only at ED frame
# 2025-07-22 11:03:12.674 | INFO     | bivme.fitting.perform_fit:perform_fitting:209 - Calculating pose and scale patient1...
# 2025-07-22 11:03:12.741 | INFO     | bivme.fitting.perform_fit:perform_fitting:214 - Fitting of patient1
# 2025-07-22 11:03:12.744 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #0
# 2025-07-22 11:03:13.079 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3790388211822178
# 2025-07-22 11:03:13.403 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2909431432030853
# 2025-07-22 11:03:13.701 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.182984183097816
# 2025-07-22 11:03:13.999 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.098855305402005
# 2025-07-22 11:03:14.276 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0385210669850897
# 2025-07-22 11:03:14.582 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.004761978893367
# 2025-07-22 11:03:14.919 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9526342099627707
# 2025-07-22 11:03:15.250 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8512510605699077
# 2025-07-22 11:03:15.581 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7065228340404333
# 2025-07-22 11:03:15.901 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5189144109571238
# 2025-07-22 11:03:16.238 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3490058458213907
# 2025-07-22 11:03:16.567 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.235102093040421
# 2025-07-22 11:03:16.658 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.235102093040421
# 2025-07-22 11:03:16.756 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.235102093040421
# 2025-07-22 11:03:16.856 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.235102093040421
# 2025-07-22 11:03:16.909 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.8839926719665527
# 2025-07-22 11:03:16.986 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.235102093040421
# 2025-07-22 11:03:19.754 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.228450878688069
# 2025-07-22 11:03:21.559 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2256127818647482
# 2025-07-22 11:03:23.265 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2243185300147936
# 2025-07-22 11:03:24.957 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2237030696880402
# 2025-07-22 11:03:26.589 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.679198980331421
# 2025-07-22 11:03:27.863 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:27.872 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:27.881 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:27.882 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #1
# 2025-07-22 11:03:28.180 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.36356966988252
# 2025-07-22 11:03:28.454 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.259643983552607
# 2025-07-22 11:03:28.735 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.161669012413419
# 2025-07-22 11:03:29.010 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.074994147835134
# 2025-07-22 11:03:29.280 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.032549979828784
# 2025-07-22 11:03:29.551 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.997082927525511
# 2025-07-22 11:03:29.827 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.945178540160294
# 2025-07-22 11:03:30.122 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8412336423465872
# 2025-07-22 11:03:30.406 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6900017617555394
# 2025-07-22 11:03:30.685 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5072642257288995
# 2025-07-22 11:03:30.968 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3376954601572477
# 2025-07-22 11:03:31.235 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2214061370270193
# 2025-07-22 11:03:31.316 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2214061370270193
# 2025-07-22 11:03:31.400 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2214061370270193
# 2025-07-22 11:03:31.482 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2214061370270193
# 2025-07-22 11:03:31.515 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.381394386291504
# 2025-07-22 11:03:31.571 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2214061370270193
# 2025-07-22 11:03:33.840 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2132696265699117
# 2025-07-22 11:03:35.519 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2099511683195847
# 2025-07-22 11:03:37.196 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2084864317574506
# 2025-07-22 11:03:38.901 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2078035346241436
# 2025-07-22 11:03:40.680 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 9.164162874221802
# 2025-07-22 11:03:42.007 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:42.017 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:42.025 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:42.026 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #2
# 2025-07-22 11:03:42.342 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.346939038743983
# 2025-07-22 11:03:42.636 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.420586922133302
# 2025-07-22 11:03:42.930 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.111567848050134
# 2025-07-22 11:03:43.222 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0274767059822154
# 2025-07-22 11:03:43.516 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9880401826398275
# 2025-07-22 11:03:43.806 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9573731746760261
# 2025-07-22 11:03:44.103 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9147839478566415
# 2025-07-22 11:03:44.412 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8189074326507126
# 2025-07-22 11:03:44.707 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6669642203172466
# 2025-07-22 11:03:44.987 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.487138146956409
# 2025-07-22 11:03:45.277 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3304540954375599
# 2025-07-22 11:03:45.558 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2125426456014425
# 2025-07-22 11:03:45.821 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2125426456014425
# 2025-07-22 11:03:46.086 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2125426456014425
# 2025-07-22 11:03:46.352 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2125426456014425
# 2025-07-22 11:03:46.571 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.277522325515747
# 2025-07-22 11:03:46.630 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2125426456014425
# 2025-07-22 11:03:48.972 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2058386815485578
# 2025-07-22 11:03:50.586 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.20305199421348
# 2025-07-22 11:03:52.198 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2018044091327513
# 2025-07-22 11:03:53.831 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.258928537368774
# 2025-07-22 11:03:55.165 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:55.172 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:55.182 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:03:55.183 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #3
# 2025-07-22 11:03:55.479 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.376898881866754
# 2025-07-22 11:03:55.531 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 2500000000000.0	 ICF error 2.376898881866754
# 2025-07-22 11:03:55.811 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 1000000000000.0	 ICF error 2.349152697921716
# 2025-07-22 11:03:56.102 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 400000000000.0	 ICF error 2.381223236246919
# 2025-07-22 11:03:56.379 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 160000000000.0	 ICF error 2.135967787608418
# 2025-07-22 11:03:56.668 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 64000000000.0	 ICF error 2.051591489682969
# 2025-07-22 11:03:56.949 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 25600000000.0	 ICF error 2.0044682119962363
# 2025-07-22 11:03:57.230 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 10240000000.0	 ICF error 1.9772694419369108
# 2025-07-22 11:03:57.545 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 4096000000.0	 ICF error 1.9556603886952963
# 2025-07-22 11:03:57.840 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 1638400000.0	 ICF error 1.9429566573902257
# 2025-07-22 11:03:58.126 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 655360000.0	 ICF error 1.9253010506275134
# 2025-07-22 11:03:58.425 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 262144000.0	 ICF error 1.9097024142450643
# 2025-07-22 11:03:58.709 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 104857600.0	 ICF error 1.875214254270165
# 2025-07-22 11:03:58.979 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 41943040.0	 ICF error 1.8176827651696192
# 2025-07-22 11:03:59.260 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 16777216.0	 ICF error 1.741462830389282
# 2025-07-22 11:03:59.541 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 16 Weight 6710886.4	 ICF error 1.6451135480042567
# 2025-07-22 11:03:59.825 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 17 Weight 2684354.56	 ICF error 1.5412836202246376
# 2025-07-22 11:04:00.114 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 18 Weight 1073741.824	 ICF error 1.4335985180457267
# 2025-07-22 11:04:00.388 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 19 Weight 429496.7296	 ICF error 1.3348463457341322
# 2025-07-22 11:04:00.678 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 20 Weight 171798.69184	 ICF error 1.2686861613312623
# 2025-07-22 11:04:00.955 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 21 Weight 68719.47673600001	 ICF error 1.207711785417293
# 2025-07-22 11:04:01.221 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 22 Weight 27487.790694400006	 ICF error 1.1596483380351006
# 2025-07-22 11:04:01.315 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 23 Weight 34359.738368000006	 ICF error 1.1596483380351006
# 2025-07-22 11:04:01.447 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 24 Weight 21474.836480000005	 ICF error 1.1596483380351006
# 2025-07-22 11:04:01.487 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.058417081832886
# 2025-07-22 11:04:01.544 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1596483380351006
# 2025-07-22 11:04:03.842 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1562195151027064
# 2025-07-22 11:04:05.585 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 4.09725022315979
# 2025-07-22 11:04:07.187 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:07.195 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:07.203 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:07.204 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #4
# 2025-07-22 11:04:07.492 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.432812752783622
# 2025-07-22 11:04:07.785 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.5330750565657607
# 2025-07-22 11:04:08.062 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1100344227318626
# 2025-07-22 11:04:08.351 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.9898952113925108
# 2025-07-22 11:04:08.644 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9504433471465188
# 2025-07-22 11:04:08.935 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9128318429641198
# 2025-07-22 11:04:09.222 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8725201769878375
# 2025-07-22 11:04:09.512 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.7827370116119843
# 2025-07-22 11:04:09.786 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6422857799215296
# 2025-07-22 11:04:10.061 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4733803970978687
# 2025-07-22 11:04:10.390 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3227096525420645
# 2025-07-22 11:04:10.681 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2125209189754842
# 2025-07-22 11:04:10.820 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2125209189754842
# 2025-07-22 11:04:10.944 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2125209189754842
# 2025-07-22 11:04:11.207 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2125209189754842
# 2025-07-22 11:04:11.291 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.8433501720428467
# 2025-07-22 11:04:11.346 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2125209189754842
# 2025-07-22 11:04:13.679 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2058051542984605
# 2025-07-22 11:04:15.316 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2031018491455852
# 2025-07-22 11:04:16.974 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2019132575257938
# 2025-07-22 11:04:18.626 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.334506511688232
# 2025-07-22 11:04:19.964 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:19.974 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:19.984 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:19.985 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #5
# 2025-07-22 11:04:20.272 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.538681789163622
# 2025-07-22 11:04:20.534 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 4.092954303873399
# 2025-07-22 11:04:20.802 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.6422902469534892
# 2025-07-22 11:04:21.068 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.214042849139239
# 2025-07-22 11:04:21.353 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0770897492230125
# 2025-07-22 11:04:21.641 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.012071166500019
# 2025-07-22 11:04:21.918 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9423540992517772
# 2025-07-22 11:04:22.207 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8212930596018106
# 2025-07-22 11:04:22.495 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6621188267806692
# 2025-07-22 11:04:22.775 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4934112533281962
# 2025-07-22 11:04:23.060 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3353868114306944
# 2025-07-22 11:04:23.324 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2058090244299324
# 2025-07-22 11:04:23.482 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2058090244299324
# 2025-07-22 11:04:23.653 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2058090244299324
# 2025-07-22 11:04:23.826 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2058090244299324
# 2025-07-22 11:04:23.951 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.721095561981201
# 2025-07-22 11:04:24.007 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2058090244299324
# 2025-07-22 11:04:26.502 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1970457269282782
# 2025-07-22 11:04:28.027 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 4.0754783153533936
# 2025-07-22 11:04:29.284 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:29.294 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:29.303 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:29.303 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #6
# 2025-07-22 11:04:29.547 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.7017809579380625
# 2025-07-22 11:04:29.580 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 2500000000000.0	 ICF error 2.7017809579380625
# 2025-07-22 11:04:29.839 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 1000000000000.0	 ICF error 2.6877153929693125
# 2025-07-22 11:04:30.100 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 400000000000.0	 ICF error 2.3939589604680345
# 2025-07-22 11:04:30.365 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 160000000000.0	 ICF error 2.1720983600897177
# 2025-07-22 11:04:30.635 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 64000000000.0	 ICF error 2.076386609265063
# 2025-07-22 11:04:30.906 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 25600000000.0	 ICF error 2.019451318886404
# 2025-07-22 11:04:31.163 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 10240000000.0	 ICF error 1.971789616475267
# 2025-07-22 11:04:31.424 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 4096000000.0	 ICF error 1.9593224563070368
# 2025-07-22 11:04:31.685 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 1638400000.0	 ICF error 1.9481631938644393
# 2025-07-22 11:04:31.989 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 655360000.0	 ICF error 1.933859102363313
# 2025-07-22 11:04:32.255 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 262144000.0	 ICF error 1.9062379321393244
# 2025-07-22 11:04:32.524 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 104857600.0	 ICF error 1.872465738753096
# 2025-07-22 11:04:32.788 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 41943040.0	 ICF error 1.8152839646155614
# 2025-07-22 11:04:33.050 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 16777216.0	 ICF error 1.741027116988472
# 2025-07-22 11:04:33.314 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 16 Weight 6710886.4	 ICF error 1.6505519203026555
# 2025-07-22 11:04:33.579 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 17 Weight 2684354.56	 ICF error 1.5579416331695348
# 2025-07-22 11:04:33.838 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 18 Weight 1073741.824	 ICF error 1.4412419018364793
# 2025-07-22 11:04:34.096 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 19 Weight 429496.7296	 ICF error 1.3438003543713073
# 2025-07-22 11:04:34.363 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 20 Weight 171798.69184	 ICF error 1.2582350875322
# 2025-07-22 11:04:34.640 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 21 Weight 68719.47673600001	 ICF error 1.196255392805275
# 2025-07-22 11:04:34.904 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 22 Weight 27487.790694400006	 ICF error 1.1506695277409527
# 2025-07-22 11:04:35.008 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 23 Weight 34359.738368000006	 ICF error 1.1506695277409527
# 2025-07-22 11:04:35.107 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 24 Weight 21474.836480000005	 ICF error 1.1506695277409527
# 2025-07-22 11:04:35.166 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.657768964767456
# 2025-07-22 11:04:35.212 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1506695277409527
# 2025-07-22 11:04:37.414 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1480132422956937
# 2025-07-22 11:04:38.969 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.147043665074903
# 2025-07-22 11:04:40.562 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 5.394841909408569
# 2025-07-22 11:04:41.817 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:41.826 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:41.834 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:41.834 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #7
# 2025-07-22 11:04:42.067 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8080787738137927
# 2025-07-22 11:04:42.330 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.44167184229381
# 2025-07-22 11:04:42.590 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.195526394531519
# 2025-07-22 11:04:42.848 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0754186664306613
# 2025-07-22 11:04:43.107 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.017152716507538
# 2025-07-22 11:04:43.370 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9915847085944098
# 2025-07-22 11:04:43.628 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9567972444340656
# 2025-07-22 11:04:43.890 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.857359550546899
# 2025-07-22 11:04:44.186 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7039729271116844
# 2025-07-22 11:04:44.452 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.534247144180868
# 2025-07-22 11:04:44.718 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3409508163639843
# 2025-07-22 11:04:44.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2038245387908224
# 2025-07-22 11:04:45.180 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2038245387908224
# 2025-07-22 11:04:45.358 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2038245387908224
# 2025-07-22 11:04:45.546 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2038245387908224
# 2025-07-22 11:04:45.692 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.659287691116333
# 2025-07-22 11:04:45.739 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2038245387908224
# 2025-07-22 11:04:47.938 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1963644925394306
# 2025-07-22 11:04:49.490 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1932745315704412
# 2025-07-22 11:04:51.042 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.191896074884663
# 2025-07-22 11:04:52.587 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1912492590884716
# 2025-07-22 11:04:54.133 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.438096284866333
# 2025-07-22 11:04:55.379 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:55.387 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:55.394 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:04:55.395 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #8
# 2025-07-22 11:04:55.617 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.899031995206427
# 2025-07-22 11:04:55.867 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.775650099341716
# 2025-07-22 11:04:56.117 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2593523591230946
# 2025-07-22 11:04:56.373 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.102473512810098
# 2025-07-22 11:04:56.648 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.043977369680004
# 2025-07-22 11:04:56.944 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0234510549506854
# 2025-07-22 11:04:57.221 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9749790082877465
# 2025-07-22 11:04:57.499 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8787422041743551
# 2025-07-22 11:04:57.768 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7392386691554507
# 2025-07-22 11:04:58.037 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.557790494464967
# 2025-07-22 11:04:58.314 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3457350970449942
# 2025-07-22 11:04:58.584 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2009225476676944
# 2025-07-22 11:04:58.664 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2009225476676944
# 2025-07-22 11:04:58.779 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2009225476676944
# 2025-07-22 11:04:58.903 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2009225476676944
# 2025-07-22 11:04:58.980 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.398432493209839
# 2025-07-22 11:04:59.031 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2009225476676944
# 2025-07-22 11:05:01.281 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1912825312167636
# 2025-07-22 11:05:02.865 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1874223551004137
# 2025-07-22 11:05:04.469 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1857526613409175
# 2025-07-22 11:05:06.188 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1849831933570885
# 2025-07-22 11:05:07.837 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.85545039176941
# 2025-07-22 11:05:09.343 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:05:09.353 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:05:09.362 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:05:09.363 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #9
# 2025-07-22 11:05:09.585 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.93020797843482
# 2025-07-22 11:05:09.843 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.6176608392352816
# 2025-07-22 11:05:10.116 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.300029324012943
# 2025-07-22 11:05:10.368 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.151146825952122
# 2025-07-22 11:05:10.636 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0771578460901683
# 2025-07-22 11:05:10.907 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.036440818590939
# 2025-07-22 11:05:11.202 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9894372940793519
# 2025-07-22 11:05:11.462 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.9015941187233765
# 2025-07-22 11:05:11.720 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7530953175208104
# 2025-07-22 11:05:11.977 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5615786535263434
# 2025-07-22 11:05:12.236 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3521863447492746
# 2025-07-22 11:05:12.524 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1984130576792105
# 2025-07-22 11:05:12.707 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1984130576792105
# 2025-07-22 11:05:12.904 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1984130576792105
# 2025-07-22 11:05:13.085 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1984130576792105
# 2025-07-22 11:05:13.233 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.679351329803467
# 2025-07-22 11:05:13.274 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1984130576792105
# 2025-07-22 11:05:15.523 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1892040743389714
# 2025-07-22 11:05:17.155 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1855204715588206
# 2025-07-22 11:05:18.750 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1839114561852613
# 2025-07-22 11:05:20.318 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1831664679501477
# 2025-07-22 11:05:21.913 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.679214000701904
# 2025-07-22 11:05:23.211 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:05:23.222 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:05:23.229 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:05:23.230 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #10
# 2025-07-22 11:05:23.451 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.923675516632862
# 2025-07-22 11:05:23.710 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.5204386605859885
# 2025-07-22 11:05:23.965 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2699183033414645
# ...
# 2025-07-22 11:07:58.557 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.332117985564453
# 2025-07-22 11:07:58.844 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2180737150163732
# 2025-07-22 11:07:59.106 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2180737150163732
# 2025-07-22 11:07:59.382 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 20480.0	 ICF error 1.1640341937363359
# 2025-07-22 11:07:59.633 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 25600.0	 ICF error 1.1640341937363359
# 2025-07-22 11:07:59.888 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 16 Weight 16000.0	 ICF error 1.1640341937363359
# 2025-07-22 11:08:00.097 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.435326814651489
# 2025-07-22 11:08:00.152 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1640341937363359
# 2025-07-22 11:08:02.367 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1607335711304037
# 2025-07-22 11:08:03.942 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1594846975571929
# 2025-07-22 11:08:05.518 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 5.419500827789307
# 2025-07-22 11:08:06.778 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:06.787 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:06.795 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:06.795 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #22
# 2025-07-22 11:08:07.082 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3499145772297787
# 2025-07-22 11:08:07.358 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.28933038150258
# 2025-07-22 11:08:07.628 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.151987266952302
# 2025-07-22 11:08:07.904 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.062594427196233
# 2025-07-22 11:08:08.185 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0124179975436682
# 2025-07-22 11:08:08.457 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9859098091323455
# 2025-07-22 11:08:08.740 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.936422107648345
# 2025-07-22 11:08:09.037 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8320727782168869
# 2025-07-22 11:08:09.346 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6752905425723812
# 2025-07-22 11:08:09.620 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.494846209335667
# 2025-07-22 11:08:09.893 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3339771651536296
# 2025-07-22 11:08:10.165 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.222626381142263
# 2025-07-22 11:08:10.313 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.222626381142263
# 2025-07-22 11:08:10.572 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.222626381142263
# 2025-07-22 11:08:10.833 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.222626381142263
# 2025-07-22 11:08:11.033 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.0010106563568115
# 2025-07-22 11:08:11.088 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.222626381142263
# 2025-07-22 11:08:13.317 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.214885101838488
# 2025-07-22 11:08:14.908 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2118787450749988
# 2025-07-22 11:08:16.523 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2105991087306074
# 2025-07-22 11:08:18.100 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.065960645675659
# 2025-07-22 11:08:19.455 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:19.465 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:19.476 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:19.477 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #23
# 2025-07-22 11:08:19.787 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3768248015344673
# 2025-07-22 11:08:20.076 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.316252122901214
# 2025-07-22 11:08:20.362 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1777366793610904
# 2025-07-22 11:08:20.645 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0838968665367057
# 2025-07-22 11:08:20.921 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.034483391829436
# 2025-07-22 11:08:21.214 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0050174454677503
# 2025-07-22 11:08:21.505 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.966124970190985
# 2025-07-22 11:08:21.807 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.858921196304963
# 2025-07-22 11:08:22.105 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.700524250425416
# 2025-07-22 11:08:22.413 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5155635511141134
# 2025-07-22 11:08:22.691 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.352215446134737
# 2025-07-22 11:08:22.968 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2402726457498368
# 2025-07-22 11:08:23.057 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2402726457498368
# 2025-07-22 11:08:23.320 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2402726457498368
# 2025-07-22 11:08:23.585 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2402726457498368
# 2025-07-22 11:08:23.787 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.046465635299683
# 2025-07-22 11:08:23.841 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2402726457498368
# 2025-07-22 11:08:26.118 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2330455136358611
# 2025-07-22 11:08:27.805 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2301068247149225
# 2025-07-22 11:08:29.561 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.228809944836651
# 2025-07-22 11:08:31.295 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.50701117515564
# 2025-07-22 11:08:32.575 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:32.586 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:32.597 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:32.599 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #24
# 2025-07-22 11:08:32.917 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.385844172905367
# 2025-07-22 11:08:33.186 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.357309669394457
# 2025-07-22 11:08:33.462 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.196680338272026
# 2025-07-22 11:08:33.730 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0949702569350936
# 2025-07-22 11:08:34.000 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.044943125511826
# 2025-07-22 11:08:34.277 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0093516293498737
# 2025-07-22 11:08:34.543 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9720629133742866
# 2025-07-22 11:08:34.813 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8746265459715885
# 2025-07-22 11:08:35.087 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.710835018262271
# 2025-07-22 11:08:35.361 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5241507839586614
# 2025-07-22 11:08:35.633 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3622861090467993
# 2025-07-22 11:08:35.928 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2476998666853027
# 2025-07-22 11:08:36.017 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2476998666853027
# 2025-07-22 11:08:36.105 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2476998666853027
# 2025-07-22 11:08:36.195 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2476998666853027
# 2025-07-22 11:08:36.233 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.3672966957092285
# 2025-07-22 11:08:36.288 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2476998666853027
# 2025-07-22 11:08:38.513 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2392806126527496
# 2025-07-22 11:08:40.097 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2357583667056347
# 2025-07-22 11:08:41.647 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2341772793592047
# 2025-07-22 11:08:43.222 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2334326708366006
# 2025-07-22 11:08:44.810 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.57631802558899
# 2025-07-22 11:08:46.258 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_LV_ENDOCARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:46.268 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_EPICARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# 2025-07-22 11:08:46.275 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:413 - patient1_RV_ENDOCARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-07-22 11:08:46.288 | INFO     | main:run_fitting:38 - Average residuals: 1.1987398642623874 for case patient1

# %% [markdown]
# ## (Optional) Analysis and/or visualisation of models
# You can visualise the fitted models frame-by-frame in your browser by opening an html in `output_directory\case\html`. Alternatively, if you have a mesh visualisation software, you can load in the .vtk or .obj files you generated to view the meshes beating through time. I recommend Paraview, as it is open source, and has nice camera controls for creating  videos of the meshes beating through time.
#
# We haven't added any analysis tools to this notebook yet. Refer to the main README on how to generate metrics from the biv-me models.
