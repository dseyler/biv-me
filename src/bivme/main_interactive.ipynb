# %% [markdown]
# # Interactive version of biv-me
# This jupyter notebook contains an identical implementation of biv-me to the main.py. The only difference is that it can be run step-by-step, allowing you to make manual corrections if and when needed to both the view selection and segmentation steps, which can be prone to occasional errors.
#
# The only thing you will need on top of the regular biv-me environment is to download a Python IDE which can run Jupyter notebooks (e.g. Visual Studio Code), and install the ipython kernel as below.
#
# ```
# conda install -n bivme311 ipykernel --update-deps --force-reinstall
# ```
#
# When you run the notebook, you will be prompted to select the kernel to use. Make sure to select your bivme311 environment.
#
# ### Troubleshooting model performance
# Though we are confident in the robustness of our deep learning models, they may not work perfectly for your data. If you find that the segmentation or view selection models perform poorly for your data, reach out to us at [joshua.dillon@auckland.ac.nz](joshua.dillon@auckland.ac.nz) or [charlene.1.mauger@kcl.ac.uk](charlene.1.mauger@kcl.ac.uk) and let us know what kind of data you are using. We are actively developing these models and always looking for ways to enhance their generalisability across vendors, protocols, centres, and patient demographics.

# %%
# Import libraries
import os,sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import tomli
from pathlib import Path
import shutil
import time
import datetime
from loguru import logger

import warnings
warnings.filterwarnings('ignore')

# %%
# This allows for modules to be reloaded automatically if you make any changes to those files.
# %load_ext autoreload
# %autoreload 2

# %%
# Import modules
from bivme.preprocessing.dicom.extract_cines import extract_cines
from bivme.preprocessing.dicom.select_views import select_views
from bivme.preprocessing.dicom.segment_views import segment_views
from bivme.preprocessing.dicom.correct_phase_mismatch import correct_phase_mismatch
from bivme.preprocessing.dicom.generate_contours import generate_contours
from bivme.preprocessing.dicom.export_guidepoints import export_guidepoints
from bivme.plotting.plot_guidepoints import generate_html 
from main import run_fitting

# %%
# Set up logging
log_level = "DEBUG"
log_format = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS zz}</green> | <level>{level: <8}</level> | <yellow>Line {line: >4} ({file}):</yellow> <b>{message}</b>"

# %%
# Check if GPU is available (torch)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2025-07-22 10:29:18.102 | INFO     | __main__:<module>:3 - Using device: cuda

# %% [markdown]
# # Config file
# As with the main.py, you should customise the template config file in `src/bivme/configs/config.toml` for your specific batch and use case. This config file will be read in and the inputs used for the remainder of this pipeline.

# %%
config_file = 'configs/config.toml' # Path to the config file

# %%
# Load config
with open(config_file, mode="rb") as fp:
    logger.info(f'Loading config file: {config_file}')
    config = tomli.load(fp)

# TOML Schema Validation
# This needs to be done to make sure the config file is valid.
# Going forward, we will trust you that all of the inputs in the config file are correct, unlike the main.py which does not trust you.

match config:
    case {
        "modules": {"preprocessing": bool(), "fitting": bool()},

        "logging": {"show_detailed_logging": bool(), "generate_log_file": bool()},

        "input_pp": {"source": str(),
                    "batch_ID": str(),
                    "analyst_id": str(),
                    "processing": str(),
                    "states": str()
                    },
        "view-selection": {"option": str(), "correct_mode": str()},
        "contouring": {"smooth_landmarks": bool()},
        "output_pp": {"overwrite": bool(), "generate_plots": bool(), "output_directory": str()},

        "input_fitting": {"gp_directory": str(),
                    "gp_suffix": str(),
                    "si_suffix": str(),
                    },
        "breathhold_correction": {"shifting": str(), "ed_frame": int()},
        "gp_processing": {"sampling": int(), "num_of_phantom_points_av": int(), "num_of_phantom_points_mv": int(), "num_of_phantom_points_tv": int(), "num_of_phantom_points_pv": int()},
        "multiprocessing": {"workers": int()},
        "fitting_weights": {"guide_points": float(), "convex_problem": float(), "transmural": float()},
        "output_fitting": {"output_directory": str(), "output_meshes": list(), "closed_mesh": bool(),   "export_control_mesh": bool(), "mesh_format": str(),  "overwrite": bool()},
    }:
        pass
    case _:
            raise ValueError(f"Invalid configuration: {config}")
# Out:
# 2025-07-22 10:49:57.358 | INFO     | __main__:<module>:3 - Loading config file: configs/config.toml

# %% [markdown]
# ## Start of preprocessing
# This code reads in DICOM files and generates GPFiles for personalised biventricular mesh fitting.

# %% [markdown]
# ## Step 0: Set up directories
# All directories will be created for you except for the input_path. This should point to your DICOMs, separated into folders by case like so:
#
#     input_path
#     └─── case1
#         │─── *
#     └─── case2
#         │─── *
#     └─── ...
#
# Don't worry about preprocessing your dicoms, separating by scan type, or excluding non-cines. The pipeline should find which ones are cines and which ones aren't by checking key terms within the series descriptions. Check src/bivme/preprocessing/dicom/extract_cines.py for the list of key terms.

# %%
batch_ID = config['input_pp']['batch_ID'] # This will serve as your output folder name. Example: 'test'
analyst_id = config['input_pp']['analyst_id'] # Example: 'analyst1'
input_path = config['input_pp']['source'] # Path to the input DICOM folder
processed_path = config['input_pp']['processing'] # Path to the processed folder, where view predictions and segmentations will be stored. This will be created upon run time.
states_path = config['input_pp']['states'] # Path to the states folder, where the logs and view predictions will be stored for reference. This will be created upon run time.
output_path = config['output_pp']['output_directory'] # Path to the output folder, where GP files will be stored. This will be created upon run time.
plotting_path = processed_path # Path to the plotting folder, where the HTML file of plotted guidepoints will be stored. This will be created upon run time.

# Target path: src/bivme/preprocessing/dicom/models
# You can hardcode the model path here or set it as an environment variable.
cwd = os.getcwd()
print('Current working directory:', cwd)
MODEL_DIR = os.path.join(cwd,'preprocessing/dicom/models')
print('Model directory:', MODEL_DIR)
# Out:
# Current working directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme
# Model directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme\preprocessing/dicom/models

# %% [markdown]
# ## Step 0.1: Choose case

# %%
case = 'patient1' # Enter the case ID. This should be a subfolder within the input_path.

# %%
# Set up batch specific folders
src = os.path.join(input_path)
dst = os.path.join(processed_path, batch_ID)
states = os.path.join(states_path, batch_ID)
output = os.path.join(output_path, batch_ID)
plotting = os.path.join(plotting_path, batch_ID)


case_src = os.path.join(src, case)
if not os.path.isdir(case_src):
    logger.error(f'Case {case} not found in source folder. Please check the case ID.')
    sys.exit()

os.makedirs(dst, exist_ok=True)
os.makedirs(states, exist_ok=True)
os.makedirs(output, exist_ok=True)
os.makedirs(plotting, exist_ok=True)

case_dst = os.path.join(dst, case)
case_output = os.path.join(output, case)

if os.path.exists(case_output):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
        shutil.rmtree(case_output)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

elif os.path.exists(case_dst):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

# %%
# Create log file to record some details
states = os.path.join(states, case, analyst_id)
os.makedirs(states, exist_ok=True)

logger_id = logger.add(f'{states}/log_file_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.log', level=log_level, format=log_format,
    colorize=False, backtrace=True,
    diagnose=True)

logger.info(f'Processing case: {case}')

start_time = time.time()
# Out:
# 2025-07-22 10:29:18.902 | INFO     | __main__:<module>:9 - Processing case: patient1

# %% [markdown]
# ## Step 0.2: Pre-preprocess dicoms
# By default, the pipeline takes in only cardiac cine images in .dcm format. The pre-preprocessing reads in the raw dicoms and uses the series descriptions to infer which are cines and which aren't. The 'cine only' dicoms are saved to:
#
#     processed_path
#     └───batch_ID
#         └───processed-dicoms

# %%
logger.info(f'Finding cines...')
extract_cines(case_src, case_dst, logger)

case_src = os.path.join(case_dst, 'processed-dicoms') # Update source directory

logger.success(f'Pre-preprocessing complete. Cines extracted to {case_src}.')
# Out:
# 2025-07-22 10:29:19.052 | INFO     | __main__:<module>:1 - Finding cines...
# 2025-07-22 10:29:23.002 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:45 - Found 275 images in the source directory
# 2025-07-22 10:29:23.003 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:46 - Extracted 275 which matched the inclusion criteria.
# 2025-07-22 10:29:24.372 | SUCCESS  | __main__:<module>:6 - Pre-preprocessing complete. Cines extracted to ../../example/processing\test\patient1\processed-dicoms.

# %% [markdown]
# ## Step 1: View selection
# View selection can be carried out in three main ways.
#
# The first option is the **'default'** option. This involves the use of two models - one using only dicom metadata and one using only image data. The metadata predictions are only broad categories (SAX, LAX, or Outflow) and are used to correct image-based predictions. This should be the most robust option, but takes longer to complete.
#
# The second option is the **'image-only'** option. This only uses image data. Use this if the metadata step is adding unnecessary time, or is not performing as expected.
#
# The third option is the **'load'** option. This loads view predictions from the states folder. This is useful if view predictions have already been made, avoiding the need to rerun prediction from scratch. It also allows for you to make and save manual corrections to the selected views.
#
# On top of these options, you can also manually review and correct the selected views using a simple GUI. There are three options - **'manual'**, which always launches the GUI after view selection, **'adaptive'**, which only launches the GUI if there are low confidence predictions or missing views, or **'automatic'**, which does not launch the GUI and keeps the automatic predictions as they are.
#
# #### Important note about required views
# To proceed with fitting, you must have at least some SAX images and a 4ch image. This is because the fitting requires landmarks from the 4ch image to initialise the model (mitral valve, tricuspid valve, and apex point). The SAX images are required, along with at least one long axis image e.g. 4ch, to correct for breath-hold misalignment. Using the GUI on **'adaptive'** mode will make sure that you never miss a required view.

# %%
option = 'default' # Either 'default', 'image-only', or 'load'. 
# 'default' will combine dicom metadata and image data to select the correct view. 'image-only' will only use the image data. 
# 'load' will load view predictions from the states folder, if view predictions have already been made.

correct_mode = 'manual' # Either 'manual', 'adaptive', or 'automatic'. 
# 'manual' will launch a GUI after completing view predictions to allow you to correct any mispredictions. 
# 'adaptive' will only launch a GUI if there are any poor predictions or missing views
# 'automatic' will not launch the GUI and will use the predictions as they are.

slice_info_df, num_phases, slice_mapping = select_views(case, case_src, case_dst, MODEL_DIR, states, option, correct_mode, logger)

logger.success(f'View selection complete.')
logger.info(f'Number of phases: {num_phases}')
# Out:
# 2025-07-22 10:29:24.499 | INFO     | bivme.preprocessing.dicom.select_views:select_views:97 - Performing metadata-based view prediction...
# 2025-07-22 10:29:30.235 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:100 - Metadata-based view prediction complete.
# 2025-07-22 10:29:30.236 | INFO     | bivme.preprocessing.dicom.select_views:select_views:103 - Performing image-based view prediction...
# 2025-07-22 10:29:39.091 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:107 - Image-based view prediction complete.
# 2025-07-22 10:29:39.092 | INFO     | bivme.preprocessing.dicom.select_views:select_views:110 - Combining metadata and image-based view predictions...
# 2025-07-22 10:29:39.124 | WARNING  | bivme.preprocessing.dicom.select_views:select_views:137 - Low confidence for series 8001 with image based prediction (SAX)...
# 2025-07-22 10:29:39.134 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:181 - View predictions for patient1:
# 2025-07-22 10:29:39.136 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX: 5 series
# 2025-07-22 10:29:39.137 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 3ch: 1 series
# 2025-07-22 10:29:39.138 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch: 1 series
# 2025-07-22 10:29:39.139 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 4ch: 1 series
# 2025-07-22 10:29:39.139 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - RVOT: 1 series
# 2025-07-22 10:29:39.140 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX-atria: 1 series
# 2025-07-22 10:29:39.140 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch-RT: 1 series
# 2025-07-22 10:29:39.284 | INFO     | bivme.preprocessing.dicom.select_views:select_views:200 - Manual corrections mode enabled. Launching view correction GUI...
# 2025-07-22 10:29:44.332 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:55 - ----- Saving view predictions...
# 2025-07-22 10:29:44.334 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 10001 saved to SAX.
# 2025-07-22 10:29:44.335 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 11001 saved to SAX.
# 2025-07-22 10:29:44.336 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 12001 saved to SAX.
# 2025-07-22 10:29:44.337 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 14001 saved to 4ch.
# 2025-07-22 10:29:44.338 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 16001 saved to 3ch.
# 2025-07-22 10:29:44.339 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 17001 saved to 2ch.
# 2025-07-22 10:29:44.340 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 19001 saved to 2ch-RT.
# 2025-07-22 10:29:44.341 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 22001 saved to RVOT.
# 2025-07-22 10:29:44.342 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 7001 saved to SAX-atria.
# 2025-07-22 10:29:44.342 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 8001 saved to SAX.
# 2025-07-22 10:29:44.343 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 9001 saved to SAX.
# 2025-07-22 10:29:44.346 | SUCCESS  | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:72 - ----- View predictions saved successfully. Close the window to continue.
# 2025-07-22 10:29:51.297 | SUCCESS  | bivme.preprocessing.dicom.select_views:correct_views:89 - View correction complete. Predictions saved.
# 2025-07-22 10:29:51.308 | SUCCESS  | __main__:<module>:12 - View selection complete.
# 2025-07-22 10:29:51.308 | INFO     | __main__:<module>:13 - Number of phases: 25

# %% [markdown]
# ## Step 2: Segmentation
# Using the view classifications from step 1, images will be written into nifti form and sent to the segmentation models to be automatically segmented. There is one segmentation model specific to each view (currently SAX, 2ch, 3ch, 4ch, or RVOT), so only images belonging to those classes will be used from now on.

# %%
## Segmentation
seg_start_time = time.time()
segment_views(case_dst, MODEL_DIR, slice_info_df, logger) # Segmentation occurs on 2D+t (3D) images using 3D nnU-Net models
seg_end_time = time.time()

logger.success(f'Segmentation complete. Time taken: {seg_end_time-seg_start_time} seconds.')
# Out:
# 2025-07-22 10:29:51.449 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing SAX images to nifti files...
# 2025-07-22 10:29:51.616 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting SAX images...
# There are 5 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 5 cases that I would like to predict
#
# Predicting SAX_3d_10001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:03<00:00,  1.79s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_10001
#
# Predicting SAX_3d_11001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.46it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_11001
#
# Predicting SAX_3d_12001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_12001
#
# Predicting SAX_3d_8001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_8001
#
# Predicting SAX_3d_9001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.59it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_9001
# 2025-07-22 10:30:12.272 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with SAX
# 2025-07-22 10:30:12.274 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 2ch images to nifti files...
# 2025-07-22 10:30:12.308 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 2ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 2ch_3d_17001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:03<00:00,  3.01s/it]
# sending off prediction to background worker for resampling and export
# done with 2ch_3d_17001
# 2025-07-22 10:30:26.145 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 2ch
# 2025-07-22 10:30:26.150 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 3ch images to nifti files...
# 2025-07-22 10:30:26.187 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 3ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 3ch_3d_16001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:05<00:00,  1.36s/it]
# sending off prediction to background worker for resampling and export
# done with 3ch_3d_16001
# 2025-07-22 10:30:42.705 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 3ch
# 2025-07-22 10:30:42.707 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing 4ch images to nifti files...
# 2025-07-22 10:30:42.746 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting 4ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 4ch_3d_14001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:06<00:00,  1.50s/it]
# sending off prediction to background worker for resampling and export
# done with 4ch_3d_14001
# 2025-07-22 10:31:00.225 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 4ch
# 2025-07-22 10:31:00.227 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:90 - Writing RVOT images to nifti files...
# 2025-07-22 10:31:00.263 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:105 - Segmenting RVOT images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting RVOT_3d_22001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.29s/it]
# sending off prediction to background worker for resampling and export
# done with RVOT_3d_22001
# 2025-07-22 10:31:13.687 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with RVOT
# 2025-07-22 10:31:13.689 | SUCCESS  | __main__:<module>:6 - Segmentation complete. Time taken: 82.24108552932739 seconds.

# %% [markdown]
# ## Step 2.1: Correct for mismatching phases (conditional)
# Often, LAX and SAX series do not have matching number of phases. In that case, we need to resample segmentations to have the same number of phases. We use the SAX series as the reference for the 'right' number of phases.

# %%
## Resample segmentations if phases are not consistent between SAX and LAX views
correct_phase_mismatch(case_dst, slice_info_df, num_phases, logger)
# Out:
# 2025-07-22 10:31:13.915 | SUCCESS  | bivme.preprocessing.dicom.correct_phase_mismatch:correct_phase_mismatch:27 - No phase mismatches found. No resampling required.

# %% [markdown]
# ## Step 2.2: Review segmentations (optional)
# Images and segmentations are stored here in nifti format (.nii.gz).
#
#     processed_path
#     └───batch_ID
#         └───case
#
#
# If needed, segmentations can be corrected here, and subsequent code executions will incorporate those changes. 3D Slicer or ITKSnap are good tools for correcting segmentations. We are working on a way to automatically load the images and segmentations into Slicer via a Python backend to make this review process easier.

# %% [markdown]
# ## Step 3: Generate contours
# Contours are generated from the perimeters of the segmentation labels, and other key landmarks (mitral valve, tricuspid valve, aortic valve, pulmonary valve, rv inserts, and LV apex) are estimated from intersections of contours. 2D contours are transformed into 3D cartesian space using the affine constructed from the image position, orientation, and pixel spacing metadata in the DICOMs.

# %%
slice_dict = generate_contours(case_dst, slice_info_df, num_phases, logger)
logger.success(f'Guide points generated successfully.')
# Out:
# 2025-07-22 10:31:14.078 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 8001...
# 2025-07-22 10:31:14.249 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 9001...
# 2025-07-22 10:31:14.486 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 10001...
# 2025-07-22 10:31:14.640 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 11001...
# 2025-07-22 10:31:14.730 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 12001...
# 2025-07-22 10:31:14.809 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 2ch slice 17001...
# 2025-07-22 10:31:14.917 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 3ch slice 16001...
# 2025-07-22 10:31:15.145 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 4ch slice 14001...
# 2025-07-22 10:31:15.350 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for RVOT slice 22001...
# 2025-07-22 10:31:15.514 | SUCCESS  | __main__:<module>:2 - Guide points generated successfully.

# %% [markdown]
# ## Step 4: Export guidepoints
# Contours are then exported into a standardised form, called a GPFile. There is one of these files per frame. This is what the model fitting part of the code requires. There is also a SliceInfoFile which contains the affine information for each slice, which is necessary to allow for breath hold correction prior to model fitting.
#
# Temporal smoothing of landmark points is enabled by default, but can be disabled by changing the boolean below.

# %%
smooth_landmarks = True # Set to True to smooth the landmarks, False to keep them as they are
gp_dir = os.path.join(output, case)

export_guidepoints(case_dst, gp_dir, slice_dict, slice_mapping, smooth_landmarks)
logger.success(f'Guide points exported successfully.')
logger.success(f'Case {case} complete.')
logger.info(f'Total time taken: {time.time()-start_time} seconds.')
# Out:
# 2025-07-22 10:31:17.592 | SUCCESS  | __main__:<module>:5 - Guide points exported successfully.
# 2025-07-22 10:31:17.593 | SUCCESS  | __main__:<module>:6 - Case patient1 complete.
# 2025-07-22 10:31:17.593 | INFO     | __main__:<module>:7 - Total time taken: 118.68991231918335 seconds.

# %% [markdown]
# ## Step 5 (Optional): Plot guidepoints
# The code below will plot the guidepoints at each frame as html files, which can be viewed at:
#
#     plotting_path
#     └───batch_ID
#         └───case
#             └───html
#
# Here's a good place to find any issues before proceeding to model fitting.

# %%
generate_html(gp_dir, out_dir=plotting, gp_suffix='', si_suffix='', frames_to_fit=[], my_logger=logger, model_path=None)

logger.info(f'Guidepoints plotted at {os.path.join(plotting,case,"html")}.')
# Out:
# 2025-07-22 10:31:17.750 | INFO     | bivme.plotting.plot_guidepoints:generate_html:63 - case: patient1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-07-22 10:31:22.034 | INFO     | __main__:<module>:3 - Guidepoints plotted at ../../example/processing\test\patient1\html.

# %% [markdown]
# # Start of model fitting

# %% [markdown]
# # Step 6: Model fitting
# The model fitting takes in the GPFiles and SliceInfoFiles generated during preprocessing to generate biventricular meshes at each frame. An iterative linear least squares fit is applied, as described in Mauger, C., Gilbert, K., Suinesiaputra, A., Pontre, B., Omens, J., McCulloch, A., & Young, A. (2018, July). An iterative diffeomorphic algorithm for registration of subdivision surfaces: application to congenital heart disease. In 2018 40th Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC) (pp. 596-599). IEEE. DOI: 10.1109/EMBC.2018.8512394.
#
# Breath hold misalignment is corrected by the intersection of short and long axis contours.
#
# Meshes are generated in the output directory you provided in the config file. Mesh vertices are exported in .txt format by default, but can also be exported with faces in .vtk and .obj formats as well for visualisation and postprocessing purposes.
#
# Unfortunately, there is no opportunity for intervention during this step.

# %%
# Set input for fitting equal to the output of preprocessing
config["input_fitting"]["gp_directory"] = output

# Save a copy of the config file to the output folder
output_folder = Path(config["output_fitting"]["output_directory"])
output_folder.mkdir(parents=True, exist_ok=True)
shutil.copy(config_file, output_folder)

# Force overwrite to true
config["output_fitting"]["overwrite"] = True

# %%
# Where Charlène's magic happens
run_fitting(case, config, logger)
# Out:
# 2025-07-22 10:50:13.615 | INFO     | main:run_fitting:26 - Processing patient1
# 2025-07-22 10:50:13.618 | INFO     | bivme.fitting.perform_fit:perform_fitting:85 - case: patient1
# 2025-07-22 10:50:13.619 | INFO     | bivme.fitting.perform_fit:perform_fitting:93 - ED set to frame #0
# 2025-07-22 10:50:13.620 | INFO     | bivme.fitting.perform_fit:perform_fitting:110 - Shift measured only at ED frame
# 2025-07-22 10:50:14.867 | INFO     | bivme.fitting.perform_fit:perform_fitting:209 - Calculating pose and scale patient1...
# 2025-07-22 10:50:14.932 | INFO     | bivme.fitting.perform_fit:perform_fitting:214 - Fitting of patient1
# 2025-07-22 10:50:14.936 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #0
# 2025-07-22 10:50:15.219 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4008095354005845
# 2025-07-22 10:50:15.484 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3517713929101762
# 2025-07-22 10:50:15.759 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2041129950250595
# 2025-07-22 10:50:16.036 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.112652735974574
# 2025-07-22 10:50:16.317 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0592318252080974
# 2025-07-22 10:50:16.586 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.016274274487221
# 2025-07-22 10:50:16.881 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9561515506245961
# 2025-07-22 10:50:17.151 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8552318919303088
# 2025-07-22 10:50:17.418 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7151573728505702
# 2025-07-22 10:50:17.685 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5250525894691196
# 2025-07-22 10:50:17.953 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3517339264514296
# 2025-07-22 10:50:18.223 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2379357612037167
# 2025-07-22 10:50:18.339 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2379357612037167
# 2025-07-22 10:50:18.586 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2379357612037167
# 2025-07-22 10:50:18.840 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2379357612037167
# 2025-07-22 10:50:19.036 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.8634185791015625
# 2025-07-22 10:50:19.096 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2379357612037167
# 2025-07-22 10:50:21.529 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2306826012983578
# 2025-07-22 10:50:23.082 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2277591894941469
# 2025-07-22 10:50:24.616 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2264707172315752
# 2025-07-22 10:50:26.163 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.125702381134033
# 2025-07-22 10:50:27.835 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_000.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:27.847 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_000.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:27.859 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_000.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:27.860 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #1
# 2025-07-22 10:50:28.141 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3685130645025105
# 2025-07-22 10:50:28.410 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.279874051948688
# 2025-07-22 10:50:28.675 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1754822791350263
# 2025-07-22 10:50:28.959 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0982716575956313
# 2025-07-22 10:50:29.239 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0531504193622876
# 2025-07-22 10:50:29.514 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0146978944930205
# 2025-07-22 10:50:29.781 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9464010914031504
# 2025-07-22 10:50:30.049 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8420051659626535
# 2025-07-22 10:50:30.327 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6870432189177103
# 2025-07-22 10:50:30.609 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5045218189798617
# 2025-07-22 10:50:30.881 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3309029652901991
# 2025-07-22 10:50:31.158 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2128299869284043
# 2025-07-22 10:50:31.244 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2128299869284043
# 2025-07-22 10:50:31.504 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2128299869284043
# 2025-07-22 10:50:31.759 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2128299869284043
# 2025-07-22 10:50:31.803 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.7059664726257324
# 2025-07-22 10:50:31.867 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2128299869284043
# 2025-07-22 10:50:34.069 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.205383184602993
# 2025-07-22 10:50:35.603 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2021855777126462
# 2025-07-22 10:50:37.157 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.200737402873121
# 2025-07-22 10:50:38.726 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.200052600328811
# 2025-07-22 10:50:40.311 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.507610321044922
# 2025-07-22 10:50:41.544 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_001.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:41.557 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_001.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:41.571 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_001.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:41.572 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #2
# 2025-07-22 10:50:41.858 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3469364598537212
# 2025-07-22 10:50:42.139 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.5685565191166204
# 2025-07-22 10:50:42.413 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2043675169954784
# 2025-07-22 10:50:42.691 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.046289735467683
# 2025-07-22 10:50:42.968 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.998018798501648
# 2025-07-22 10:50:43.247 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9667970590751467
# 2025-07-22 10:50:43.526 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9163668518249604
# 2025-07-22 10:50:43.800 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8225558385834424
# 2025-07-22 10:50:44.068 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6773563508419265
# 2025-07-22 10:50:44.348 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.494774011622994
# 2025-07-22 10:50:44.626 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3334406707967406
# 2025-07-22 10:50:44.910 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2064233641639135
# 2025-07-22 10:50:45.168 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2064233641639135
# 2025-07-22 10:50:45.428 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2064233641639135
# 2025-07-22 10:50:45.686 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2064233641639135
# 2025-07-22 10:50:45.902 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.086822271347046
# 2025-07-22 10:50:45.955 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2064233641639135
# 2025-07-22 10:50:48.099 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.199117927731524
# 2025-07-22 10:50:49.649 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1961197733748445
# 2025-07-22 10:50:51.213 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.194793152650106
# 2025-07-22 10:50:52.789 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.194174011121899
# 2025-07-22 10:50:54.343 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.440593481063843
# 2025-07-22 10:50:55.578 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_002.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:55.595 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_002.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:55.609 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_002.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:50:55.610 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #3
# 2025-07-22 10:50:55.899 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3703557532017934
# 2025-07-22 10:50:56.199 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3054202414168237
# 2025-07-22 10:50:56.489 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.149634507670587
# 2025-07-22 10:50:56.771 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0453674749934185
# 2025-07-22 10:50:57.065 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0024615433922244
# 2025-07-22 10:50:57.359 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.973399687126942
# 2025-07-22 10:50:57.633 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9217630003673234
# 2025-07-22 10:50:57.909 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8264857093057054
# 2025-07-22 10:50:58.184 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6747090518398646
# 2025-07-22 10:50:58.457 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4975447062143041
# 2025-07-22 10:50:58.739 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3350648529882436
# 2025-07-22 10:50:59.024 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2170418203890434
# 2025-07-22 10:50:59.178 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2170418203890434
# 2025-07-22 10:50:59.439 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2170418203890434
# 2025-07-22 10:50:59.722 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2170418203890434
# 2025-07-22 10:50:59.953 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.104029655456543
# 2025-07-22 10:51:00.018 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2170418203890434
# 2025-07-22 10:51:02.248 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2097321224526394
# 2025-07-22 10:51:03.789 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.20700359881098
# 2025-07-22 10:51:05.355 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.205875121466133
# 2025-07-22 10:51:06.962 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.0090625286102295
# 2025-07-22 10:51:08.210 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_003.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:08.222 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_003.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:08.235 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_003.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:08.236 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #4
# 2025-07-22 10:51:08.513 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4235326023922203
# 2025-07-22 10:51:08.798 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.303318129320953
# 2025-07-22 10:51:09.073 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1477816268100467
# 2025-07-22 10:51:09.355 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.036279620832711
# 2025-07-22 10:51:09.637 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9964696039326837
# 2025-07-22 10:51:09.945 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9500243147198753
# 2025-07-22 10:51:10.231 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9075279749995206
# 2025-07-22 10:51:10.515 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8061693489535289
# 2025-07-22 10:51:10.815 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.656777310813901
# 2025-07-22 10:51:11.095 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.487422680410413
# 2025-07-22 10:51:11.395 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.32976196998328
# 2025-07-22 10:51:11.499 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.32976196998328
# 2025-07-22 10:51:11.785 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2505599900650368
# 2025-07-22 10:51:11.893 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2505599900650368
# 2025-07-22 10:51:12.006 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2505599900650368
# 2025-07-22 10:51:12.072 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.602583169937134
# 2025-07-22 10:51:12.128 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2505599900650368
# 2025-07-22 10:51:14.518 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.239414809467053
# 2025-07-22 10:51:16.072 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 3.997251510620117
# 2025-07-22 10:51:17.508 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_004.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:17.522 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_004.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:17.533 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_004.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:17.534 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #5
# 2025-07-22 10:51:17.790 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.5057304924769213
# 2025-07-22 10:51:18.072 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2749811577559216
# 2025-07-22 10:51:18.350 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1001298782145965
# 2025-07-22 10:51:18.627 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.028789679755736
# 2025-07-22 10:51:18.913 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.97208881323849
# 2025-07-22 10:51:19.196 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9447622952634493
# 2025-07-22 10:51:19.478 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9001577668013088
# 2025-07-22 10:51:19.751 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.7994724003844023
# 2025-07-22 10:51:20.027 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6555718606119552
# 2025-07-22 10:51:20.307 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4896501909033275
# 2025-07-22 10:51:20.591 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.328593532037904
# 2025-07-22 10:51:20.869 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2094137616666931
# 2025-07-22 10:51:21.039 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2094137616666931
# 2025-07-22 10:51:21.209 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2094137616666931
# 2025-07-22 10:51:21.391 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2094137616666931
# 2025-07-22 10:51:21.519 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.769007682800293
# 2025-07-22 10:51:21.574 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2094137616666931
# 2025-07-22 10:51:23.800 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2024145466567397
# 2025-07-22 10:51:25.371 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.199520674760955
# 2025-07-22 10:51:26.947 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1982315665620917
# 2025-07-22 10:51:28.514 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1976272693799352
# 2025-07-22 10:51:30.083 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.562508344650269
# 2025-07-22 10:51:31.332 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_005.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:31.344 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_005.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:31.355 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_005.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:31.356 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #6
# 2025-07-22 10:51:31.619 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.671894220658128
# 2025-07-22 10:51:31.891 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.691196928045396
# 2025-07-22 10:51:32.160 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2032493048870045
# 2025-07-22 10:51:32.435 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.062975815263087
# 2025-07-22 10:51:32.725 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0053249607693386
# 2025-07-22 10:51:33.002 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9746351043714727
# 2025-07-22 10:51:33.293 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9304972422853452
# 2025-07-22 10:51:33.576 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8376951435421458
# 2025-07-22 10:51:33.846 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6960682947045018
# 2025-07-22 10:51:34.113 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5150521771244243
# 2025-07-22 10:51:34.388 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3352274765084045
# 2025-07-22 10:51:34.657 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2109810428158299
# 2025-07-22 10:51:34.763 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2109810428158299
# 2025-07-22 10:51:34.867 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2109810428158299
# 2025-07-22 10:51:34.969 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2109810428158299
# 2025-07-22 10:51:35.040 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.457183837890625
# 2025-07-22 10:51:35.085 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2109810428158299
# 2025-07-22 10:51:37.320 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.203194764596425
# 2025-07-22 10:51:38.733 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 3.691753387451172
# 2025-07-22 10:51:39.991 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_006.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:40.004 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_006.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:40.017 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_006.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:40.018 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #7
# 2025-07-22 10:51:40.247 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.779107711254736
# 2025-07-22 10:51:40.513 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.2290108559551967
# 2025-07-22 10:51:40.779 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.3653138429576637
# 2025-07-22 10:51:41.049 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.104641295641778
# 2025-07-22 10:51:41.311 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0331412945340834
# 2025-07-22 10:51:41.595 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9929840851129332
# 2025-07-22 10:51:41.870 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.957951617532491
# 2025-07-22 10:51:42.154 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8589713310825595
# 2025-07-22 10:51:42.433 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.718912295855373
# 2025-07-22 10:51:42.705 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5376523640069804
# 2025-07-22 10:51:43.004 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3394377135529079
# 2025-07-22 10:51:43.274 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.196970076070688
# 2025-07-22 10:51:43.462 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.196970076070688
# 2025-07-22 10:51:43.660 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.196970076070688
# 2025-07-22 10:51:43.866 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.196970076070688
# 2025-07-22 10:51:44.036 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.822324752807617
# 2025-07-22 10:51:44.093 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.196970076070688
# 2025-07-22 10:51:46.360 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.189566958248248
# 2025-07-22 10:51:47.957 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1864941270216331
# 2025-07-22 10:51:49.510 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.185120180319237
# 2025-07-22 10:51:51.075 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1844742426421098
# 2025-07-22 10:51:52.636 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.598618745803833
# 2025-07-22 10:51:53.866 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_007.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:53.881 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_007.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:53.892 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_007.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:51:53.894 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #8
# 2025-07-22 10:51:54.116 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8690766069609857
# 2025-07-22 10:51:54.378 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.2733005104307553
# 2025-07-22 10:51:54.648 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.3223600142298984
# 2025-07-22 10:51:54.921 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1177906102210575
# 2025-07-22 10:51:55.197 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0628782807013706
# 2025-07-22 10:51:55.470 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0197937699029977
# 2025-07-22 10:51:55.737 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9656331164159888
# 2025-07-22 10:51:56.003 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8781659402630866
# 2025-07-22 10:51:56.285 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7369665116309374
# 2025-07-22 10:51:56.569 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5593377894809954
# 2025-07-22 10:51:56.837 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3476052538096324
# 2025-07-22 10:51:57.118 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2065530200045786
# 2025-07-22 10:51:57.242 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2065530200045786
# 2025-07-22 10:51:57.364 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2065530200045786
# 2025-07-22 10:51:57.492 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2065530200045786
# 2025-07-22 10:51:57.579 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.4962575435638428
# 2025-07-22 10:51:57.626 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2065530200045786
# 2025-07-22 10:51:59.871 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1978447930404668
# 2025-07-22 10:52:01.465 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1942726042303236
# 2025-07-22 10:52:03.070 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.192686879292732
# 2025-07-22 10:52:04.666 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1919443279905177
# 2025-07-22 10:52:06.228 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.647257804870605
# 2025-07-22 10:52:07.485 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_008.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:52:07.500 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_008.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:52:07.513 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_008.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:52:07.514 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #9
# 2025-07-22 10:52:07.743 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8873663463692285
# 2025-07-22 10:52:08.010 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.474447780518947
# 2025-07-22 10:52:08.290 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.263123701415674
# 2025-07-22 10:52:08.560 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.141165678410409
# 2025-07-22 10:52:08.836 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0842418542326717
# 2025-07-22 10:52:09.103 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0412814719335493
# 2025-07-22 10:52:09.370 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9922006543993729
# 2025-07-22 10:52:09.638 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8834934278485853
# 2025-07-22 10:52:09.917 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7352378815054306
# 2025-07-22 10:52:10.189 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5388725117570967
# 2025-07-22 10:52:10.451 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3233416810300156
# 2025-07-22 10:52:10.719 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1851778615009008
# 2025-07-22 10:52:10.911 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1851778615009008
# 2025-07-22 10:52:11.116 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1851778615009008
# 2025-07-22 10:52:11.304 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1851778615009008
# 2025-07-22 10:52:11.455 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.74464750289917
# 2025-07-22 10:52:11.499 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1851778615009008
# 2025-07-22 10:52:13.710 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1778282231206934
# 2025-07-22 10:52:15.306 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.174679820887234
# 2025-07-22 10:52:16.880 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1732471703955725
# 2025-07-22 10:52:18.443 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1725670512479516
# 2025-07-22 10:52:19.998 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.542240142822266
# 2025-07-22 10:52:21.414 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_009.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:52:21.433 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_009.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:52:21.444 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_009.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:52:21.445 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #10
# 2025-07-22 10:52:21.678 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8894857621371903
# 2025-07-22 10:52:21.940 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.190386340157654
# 2025-07-22 10:52:22.209 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.253854936317684
# 2025-07-22 10:52:22.471 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1345304372147886
# 2025-07-22 10:52:22.737 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.081358039806736
# 2025-07-22 10:52:23.008 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0362219332944664
# 2025-07-22 10:52:23.273 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9849165075277768
# 2025-07-22 10:52:23.541 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8915898702485159
# 2025-07-22 10:52:23.811 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.744654958060832
# 2025-07-22 10:52:24.073 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5577244178574405
# 2025-07-22 10:52:24.353 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3479025806594396
# 2025-07-22 10:52:24.626 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.206975932788635
# 2025-07-22 10:52:24.817 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.206975932788635
# 2025-07-22 10:52:25.002 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.206975932788635
# 2025-07-22 10:52:25.202 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.206975932788635
# 2025-07-22 10:52:25.360 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.7136707305908203
# 2025-07-22 10:52:25.404 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.206975932788635
# 2025-07-22 10:52:27.616 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1993241180696328
# 2025-07-22 10:52:29.198 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1963145604554588
# 2025-07-22 10:52:30.784 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1950140529185993
# ...
# 2025-07-22 10:54:42.327 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2046352284424375
# 2025-07-22 10:54:42.603 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2046352284424375
# 2025-07-22 10:54:42.821 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.351556777954102
# 2025-07-22 10:54:42.883 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2046352284424375
# 2025-07-22 10:54:45.144 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1965622084673024
# 2025-07-22 10:54:46.752 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.193355011282015
# 2025-07-22 10:54:48.363 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.191967639735912
# 2025-07-22 10:54:49.981 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1913287935050076
# 2025-07-22 10:54:51.571 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.748800992965698
# 2025-07-22 10:54:52.837 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_021.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:54:52.850 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_021.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:54:52.862 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_021.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:54:52.863 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #22
# 2025-07-22 10:54:53.152 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.375869110231275
# 2025-07-22 10:54:53.445 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3147702440725575
# 2025-07-22 10:54:53.730 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1948395589119447
# 2025-07-22 10:54:54.033 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.108848543927549
# 2025-07-22 10:54:54.330 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.04400355081658
# 2025-07-22 10:54:54.624 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0133764789281554
# 2025-07-22 10:54:54.916 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9574535659738221
# 2025-07-22 10:54:55.218 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8385241593069261
# 2025-07-22 10:54:55.512 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6801173284729876
# 2025-07-22 10:54:55.800 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5053239525427256
# 2025-07-22 10:54:56.083 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3459961059860412
# 2025-07-22 10:54:56.367 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2310489356157586
# 2025-07-22 10:54:56.629 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2310489356157586
# 2025-07-22 10:54:56.904 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2310489356157586
# 2025-07-22 10:54:57.170 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2310489356157586
# 2025-07-22 10:54:57.394 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.284974098205566
# 2025-07-22 10:54:57.448 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2310489356157586
# 2025-07-22 10:54:59.679 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2227610815492787
# 2025-07-22 10:55:01.289 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2193955910129728
# 2025-07-22 10:55:02.880 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2179184304668849
# 2025-07-22 10:55:04.465 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.217230772641
# 2025-07-22 10:55:06.021 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.624988794326782
# 2025-07-22 10:55:07.274 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_022.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:07.288 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_022.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:07.298 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_022.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:07.299 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #23
# 2025-07-22 10:55:07.591 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.403060088733344
# 2025-07-22 10:55:07.876 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.325635771577788
# 2025-07-22 10:55:08.163 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.207730259987521
# 2025-07-22 10:55:08.455 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.11338376988319
# 2025-07-22 10:55:08.737 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0588758624698356
# 2025-07-22 10:55:09.035 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0168706196708275
# 2025-07-22 10:55:09.321 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9715481077938883
# 2025-07-22 10:55:09.611 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.864662086890371
# 2025-07-22 10:55:09.887 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7085978819748882
# 2025-07-22 10:55:10.176 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5225539940174917
# 2025-07-22 10:55:10.465 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.359587641264097
# 2025-07-22 10:55:10.748 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2402652836840231
# 2025-07-22 10:55:11.018 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2402652836840231
# 2025-07-22 10:55:11.289 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2402652836840231
# 2025-07-22 10:55:11.557 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2402652836840231
# 2025-07-22 10:55:11.782 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 4.2417380809783936
# 2025-07-22 10:55:11.842 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2402652836840231
# 2025-07-22 10:55:14.051 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2339810400842526
# 2025-07-22 10:55:15.640 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2315184559667665
# 2025-07-22 10:55:17.219 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2304572558013587
# 2025-07-22 10:55:18.830 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.046807527542114
# 2025-07-22 10:55:20.100 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_023.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:20.114 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_023.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:20.125 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_023.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:20.127 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #24
# 2025-07-22 10:55:20.415 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.436870929853748
# 2025-07-22 10:55:20.712 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3478342180894587
# 2025-07-22 10:55:20.991 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2211385911860444
# 2025-07-22 10:55:21.268 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1312655397555402
# 2025-07-22 10:55:21.556 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0703004912049865
# 2025-07-22 10:55:21.831 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.022957804293447
# 2025-07-22 10:55:22.118 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9768028092712024
# 2025-07-22 10:55:22.395 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8741690520540535
# 2025-07-22 10:55:22.685 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7119771057534434
# 2025-07-22 10:55:22.967 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5323708199217008
# 2025-07-22 10:55:23.256 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3657415907952597
# 2025-07-22 10:55:23.541 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2532588177957098
# 2025-07-22 10:55:23.643 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2532588177957098
# 2025-07-22 10:55:23.735 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2532588177957098
# 2025-07-22 10:55:23.829 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2532588177957098
# 2025-07-22 10:55:23.875 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 3.5069704055786133
# 2025-07-22 10:55:23.937 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2532588177957098
# 2025-07-22 10:55:26.189 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.24528028937542
# 2025-07-22 10:55:27.741 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2420190883632016
# 2025-07-22 10:55:29.389 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2405718227103222
# 2025-07-22 10:55:31.028 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2398946420963843
# 2025-07-22 10:55:32.672 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.795482873916626
# 2025-07-22 10:55:33.971 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_LV_ENDOCARDIAL_024.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:33.986 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_EPICARDIAL_024.obj successfully saved to ..\output\patient1\obj
# 2025-07-22 10:55:33.997 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:422 - patient1_RV_ENDOCARDIAL_024.obj successfully saved to ..\output\patient1\obj
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-07-22 10:55:34.010 | INFO     | main:run_fitting:38 - Average residuals: 1.2094766097783767 for case patient1

# %% [markdown]
# ## (Optional) Analysis and/or visualisation of models
# You can visualise the fitted models frame-by-frame in your browser by opening an html in `output_directory\case\html`. Alternatively, if you have a mesh visualisation software, you can load in the .vtk or .obj files you generated to view the meshes beating through time. I recommend Paraview, as it is open source, and has nice camera controls for creating  videos of the meshes beating through time.
#
# We haven't added any analysis tools to this notebook yet. Refer to the main README on how to generate metrics from the biv-me models.
