# %% [markdown]
# # Interactive version of biv-me
# This jupyter notebook contains an identical implementation of biv-me to the main.py. The only difference is that it can be run step-by-step, allowing you to make manual corrections if and when needed to both the view selection and segmentation steps, which can be prone to occasional errors.
#
# The only thing you will need on top of the regular biv-me environment is to download a Python IDE which can run Jupyter notebooks (e.g. Visual Studio Code), and install the ipython kernel as below.
#
# ```
# conda install -n bivme311 ipykernel --update-deps --force-reinstall
# ```
#
# When you run the notebook, you will be prompted to select the kernel to use. Make sure to select your bivme311 environment.
#
# ### Troubleshooting model performance
# Though we are confident in the robustness of our deep learning models, they may not work perfectly for your data. If you find that the segmentation or view selection models perform poorly for your data, reach out to us at [joshua.dillon@auckland.ac.nz](joshua.dillon@auckland.ac.nz) or [charlene.1.mauger@kcl.ac.uk](charlene.1.mauger@kcl.ac.uk) and let us know what kind of data you are using. We are actively developing these models and always looking for ways to enhance their generalisability across vendors, protocols, centres, and patient demographics.

# %%
# Import libraries
import os,sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import tomli
from pathlib import Path
import shutil
import time
import datetime
from loguru import logger

import warnings
warnings.filterwarnings('ignore')

# %%
# This allows for modules to be reloaded automatically if you make any changes to those files.
# %load_ext autoreload
# %autoreload 2

# %%
# Import modules
from bivme.preprocessing.dicom.extract_cines import extract_cines
from bivme.preprocessing.dicom.select_views import select_views
from bivme.preprocessing.dicom.segment_views import segment_views
from bivme.preprocessing.dicom.correct_phase_mismatch import correct_phase_mismatch
from bivme.preprocessing.dicom.generate_contours import generate_contours
from bivme.preprocessing.dicom.export_guidepoints import export_guidepoints
from bivme.plotting.plot_guidepoints import generate_html 
from main import run_fitting

# %%
# Set up logging
log_level = "DEBUG"
log_format = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS zz}</green> | <level>{level: <8}</level> | <yellow>Line {line: >4} ({file}):</yellow> <b>{message}</b>"

# %%
# Check if GPU is available (torch)
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
    logger.warning('No GPU available. Using CPU instead. This may be very slow!')
    
logger.info(f"Using device: {device}")
# Out:
# 2025-08-29 16:08:09.638 | INFO     | __main__:<module>:10 - Using device: cuda

# %% [markdown]
# # Config file
# As with the main.py, you should customise the template config file in `src/bivme/configs/config.toml` for your specific batch and use case. This config file will be read in and the inputs used for the remainder of this pipeline.

# %%
config_file = 'configs/config.toml' # Path to the config file

# %%
# Load config
with open(config_file, mode="rb") as fp:
    logger.info(f'Loading config file: {config_file}')
    config = tomli.load(fp)

# TOML Schema Validation
# This needs to be done to make sure the config file is valid.
# Going forward, we will trust you that all of the inputs in the config file are correct, unlike the main.py which does not trust you.

match config:
    case {
        "modules": {"preprocessing": bool(), "fitting": bool()},

        "logging": {"show_detailed_logging": bool(), "generate_log_file": bool()},

        "plotting": {"generate_plots_preprocessing": bool(), "generate_plots_fitting": bool(), "include_images": bool(), "export_images": bool()},

        "input_pp": {"source": str(),
                    "batch_ID": str(),
                    "analyst_id": str(),
                    "processing": str(),
                    "states": str()
                    },
        "view-selection": {"option": str(), "correct_mode": str()},
        "contouring": {"smooth_landmarks": bool()},
        "output_pp": {"overwrite": bool(), "output_directory": str()},

        "input_fitting": {"gp_directory": str(),
                    "gp_suffix": str(),
                    "si_suffix": str(),
                    },
        "breathhold_correction": {"shifting": str(), "ed_frame": int()},
        "gp_processing": {"sampling": int(), "num_of_phantom_points_av": int(), "num_of_phantom_points_mv": int(), "num_of_phantom_points_tv": int(), "num_of_phantom_points_pv": int()},
        "multiprocessing": {"workers": int()},
        "fitting_weights": {"guide_points": float(), "convex_problem": float(), "transmural": float()},
        "output_fitting": {"output_directory": str(), "output_meshes": list(), "closed_mesh": bool(),   "export_control_mesh": bool(), "mesh_format": str(),  "overwrite": bool()},
    }:
        pass
    case _:
            raise ValueError(f"Invalid configuration: {config}")
# Out:
# 2025-08-29 16:08:10.027 | INFO     | __main__:<module>:3 - Loading config file: configs/config.toml

# %% [markdown]
# # Start of preprocessing
# This code reads in DICOM files and generates GPFiles for personalised biventricular mesh fitting.

# %% [markdown]
# ## Step 0: Set up directories
# All directories will be created for you except for the input_path. This should point to your DICOMs, separated into folders by case like so:
#
#     input_path
#     └─── case1
#         │─── *
#     └─── case2
#         │─── *
#     └─── ...
#
# Don't worry about preprocessing your dicoms, separating by scan type, or excluding non-cines. The pipeline should find which ones are cines and which ones aren't by checking key terms within the series descriptions. Check src/bivme/preprocessing/dicom/extract_cines.py for the list of key terms.

# %%
batch_ID = config['input_pp']['batch_ID'] # This will serve as your output folder name. Example: 'test'
analyst_id = config['input_pp']['analyst_id'] # Example: 'analyst1'
input_path = config['input_pp']['source'] # Path to the input DICOM folder
processed_path = config['input_pp']['processing'] # Path to the processed folder, where view predictions and segmentations will be stored. This will be created upon run time.
states_path = config['input_pp']['states'] # Path to the states folder, where the logs and view predictions will be stored for reference. This will be created upon run time.
output_path = config['output_pp']['output_directory'] # Path to the output folder, where GP files will be stored. This will be created upon run time.
plotting_path = processed_path # Path to the plotting folder, where the HTML file of plotted guidepoints will be stored. This will be created upon run time.

# Target path: src/bivme/preprocessing/dicom/models
# You can hardcode the model path here or set it as an environment variable.
cwd = os.getcwd()
print('Current working directory:', cwd)
MODEL_DIR = os.path.join(cwd,'preprocessing/dicom/models')
print('Model directory:', MODEL_DIR)
# Out:
# Current working directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme
# Model directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme\preprocessing/dicom/models

# %% [markdown]
# ## Step 0.1: Choose case

# %%
case = 'patient1' # Enter the case ID. This should be a subfolder within the input_path.

# %%
# Set up batch specific folders
src = os.path.join(input_path)
dst = os.path.join(processed_path, batch_ID)
states = os.path.join(states_path, batch_ID)
output = os.path.join(output_path, batch_ID)
plotting = os.path.join(plotting_path, batch_ID)


case_src = os.path.join(src, case)
if not os.path.isdir(case_src):
    logger.error(f'Case {case} not found in source folder. Please check the case ID.')
    sys.exit()

os.makedirs(dst, exist_ok=True)
os.makedirs(states, exist_ok=True)
os.makedirs(output, exist_ok=True)
os.makedirs(plotting, exist_ok=True)

case_dst = os.path.join(dst, case)
case_output = os.path.join(output, case)

if os.path.exists(case_output):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
        shutil.rmtree(case_output)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

elif os.path.exists(case_dst):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

# %%
# Create log file to record some details
states = os.path.join(states, case, analyst_id)
os.makedirs(states, exist_ok=True)

logger_id = logger.add(f'{states}/log_file_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.log', level=log_level, format=log_format,
    colorize=False, backtrace=True,
    diagnose=True)

logger.info(f'Processing case: {case}')

start_time = time.time()
# Out:
# 2025-08-29 16:08:10.972 | INFO     | __main__:<module>:9 - Processing case: patient1

# %% [markdown]
# ## Step 0.2: Pre-preprocess dicoms
# By default, the pipeline takes in only cardiac cine images in .dcm format. The pre-preprocessing reads in the raw dicoms and uses the series descriptions to infer which are cines and which aren't. The 'cine only' dicoms are saved to:
#
#     processed_path
#     └───batch_ID
#         └───processed-dicoms

# %%
logger.info(f'Finding cines...')
extract_cines(case_src, case_dst, logger)

case_src = os.path.join(case_dst, 'processed-dicoms') # Update source directory

logger.success(f'Pre-preprocessing complete. Cines extracted to {case_src}.')
# Out:
# 2025-08-29 16:08:11.224 | INFO     | __main__:<module>:1 - Finding cines...
# 2025-08-29 16:08:16.811 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:45 - Found 275 images in the source directory
# 2025-08-29 16:08:16.812 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:46 - Extracted 275 which matched the inclusion criteria.
# 2025-08-29 16:08:21.667 | SUCCESS  | __main__:<module>:6 - Pre-preprocessing complete. Cines extracted to ../../example/processing\test\patient1\processed-dicoms.

# %% [markdown]
# ## Step 1: View selection
# View selection can be carried out in three main ways.
#
# The first option is the **'default'** option. This involves the use of two models - one using only dicom metadata and one using only image data. The metadata predictions are only broad categories (SAX, LAX, or Outflow) and are used to correct image-based predictions. This should be the most robust option, but takes longer to complete.
#
# The second option is the **'image-only'** option. This only uses image data. Use this if the metadata step is adding unnecessary time, or is not performing as expected.
#
# The third option is the **'load'** option. This loads view predictions from the states folder. This is useful if view predictions have already been made, avoiding the need to rerun prediction from scratch. It also allows for you to make and save manual corrections to the selected views.
#
# On top of these options, you can also manually review and correct the selected views using a simple GUI. There are three options - **'manual'**, which always launches the GUI after view selection, **'adaptive'**, which only launches the GUI if there are low confidence predictions or missing views, or **'automatic'**, which does not launch the GUI and keeps the automatic predictions as they are.
#
# #### Important note about required views
# To proceed with fitting, you must have at least some SAX images and a 4ch image. This is because the fitting requires landmarks from the 4ch image to initialise the model (mitral valve, tricuspid valve, and apex point). The SAX images are required, along with at least one long axis image e.g. 4ch, to correct for breath-hold misalignment. Using the GUI on **'adaptive'** mode will make sure that you never miss a required view.

# %%
option = 'default' # Either 'default', 'image-only', or 'load'. 
# 'default' will combine dicom metadata and image data to select the correct view. 'image-only' will only use the image data. 
# 'load' will load view predictions from the states folder, if view predictions have already been made.

correct_mode = 'manual' # Either 'manual', 'adaptive', or 'automatic'. 
# 'manual' will launch a GUI after completing view predictions to allow you to correct any mispredictions. 
# 'adaptive' will only launch a GUI if there are any poor predictions or missing views
# 'automatic' will not launch the GUI and will use the predictions as they are.

slice_info_df, num_phases, slice_mapping = select_views(case, case_src, case_dst, MODEL_DIR, states, option, correct_mode, logger)

logger.success(f'View selection complete.')
logger.info(f'Number of phases: {num_phases}')
# Out:
# 2025-08-29 16:08:21.867 | INFO     | bivme.preprocessing.dicom.select_views:select_views:97 - Performing metadata-based view prediction...
# 2025-08-29 16:08:31.134 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:100 - Metadata-based view prediction complete.
# 2025-08-29 16:08:31.134 | INFO     | bivme.preprocessing.dicom.select_views:select_views:103 - Performing image-based view prediction...
# 2025-08-29 16:08:42.956 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:107 - Image-based view prediction complete.
# 2025-08-29 16:08:42.958 | INFO     | bivme.preprocessing.dicom.select_views:select_views:110 - Combining metadata and image-based view predictions...
# 2025-08-29 16:08:43.033 | WARNING  | bivme.preprocessing.dicom.select_views:select_views:137 - Low confidence for series 8001 with image based prediction (SAX)...
# 2025-08-29 16:08:43.056 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:181 - View predictions for patient1:
# 2025-08-29 16:08:43.060 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX: 5 series
# 2025-08-29 16:08:43.061 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 3ch: 1 series
# 2025-08-29 16:08:43.063 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch: 1 series
# 2025-08-29 16:08:43.065 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 4ch: 1 series
# 2025-08-29 16:08:43.067 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - RVOT: 1 series
# 2025-08-29 16:08:43.069 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - SAX-atria: 1 series
# 2025-08-29 16:08:43.071 | INFO     | bivme.preprocessing.dicom.select_views:select_views:183 - 2ch-RT: 1 series
# 2025-08-29 16:08:43.389 | INFO     | bivme.preprocessing.dicom.select_views:select_views:200 - Manual corrections mode enabled. Launching view correction GUI...
# 2025-08-29 16:08:48.518 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:55 - ----- Saving view predictions...
# 2025-08-29 16:08:48.520 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 10001 saved to SAX.
# 2025-08-29 16:08:48.523 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 11001 saved to SAX.
# 2025-08-29 16:08:48.525 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 12001 saved to SAX.
# 2025-08-29 16:08:48.527 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 14001 saved to 4ch.
# 2025-08-29 16:08:48.529 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 16001 saved to 3ch.
# 2025-08-29 16:08:48.530 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 17001 saved to 2ch.
# 2025-08-29 16:08:48.532 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 19001 saved to 2ch-RT.
# 2025-08-29 16:08:48.535 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 22001 saved to RVOT.
# 2025-08-29 16:08:48.536 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 7001 saved to SAX-atria.
# 2025-08-29 16:08:48.538 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 8001 saved to SAX.
# 2025-08-29 16:08:48.540 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:64 - ----- Series 9001 saved to SAX.
# 2025-08-29 16:08:48.544 | SUCCESS  | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:72 - ----- View predictions saved successfully. Close the window to continue.
# 2025-08-29 16:08:58.967 | SUCCESS  | bivme.preprocessing.dicom.select_views:correct_views:89 - View correction complete. Predictions saved.
# 2025-08-29 16:08:58.990 | SUCCESS  | __main__:<module>:12 - View selection complete.
# 2025-08-29 16:08:58.992 | INFO     | __main__:<module>:13 - Number of phases: 25

# %% [markdown]
# ## Step 2: Segmentation
# Using the view classifications from step 1, images will be written into nifti form and sent to the segmentation models to be automatically segmented. There is one segmentation model specific to each view (currently SAX, 2ch, 3ch, 4ch, or RVOT), so only images belonging to those classes will be used from now on.

# %%
## Segmentation
seg_start_time = time.time()
segment_views(case_dst, MODEL_DIR, slice_info_df, logger) # Segmentation occurs on 2D+t (3D) images using 3D nnU-Net models
seg_end_time = time.time()

logger.success(f'Segmentation complete. Time taken: {seg_end_time-seg_start_time} seconds.')
# Out:
# 2025-08-29 16:08:59.196 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:94 - Writing SAX images to nifti files...
# 2025-08-29 16:08:59.463 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:109 - Segmenting SAX images...
# There are 5 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 5 cases that I would like to predict
#
# Predicting SAX_3d_10001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:03<00:00,  1.93s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_10001
#
# Predicting SAX_3d_11001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_11001
#
# Predicting SAX_3d_12001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_12001
#
# Predicting SAX_3d_8001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_8001
#
# Predicting SAX_3d_9001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.58it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_9001
# 2025-08-29 16:09:52.324 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:62 - Done with SAX
# 2025-08-29 16:09:52.329 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:94 - Writing 2ch images to nifti files...
# 2025-08-29 16:09:52.409 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:109 - Segmenting 2ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 2ch_3d_17001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# sending off prediction to background worker for resampling and export
# done with 2ch_3d_17001
# 2025-08-29 16:10:24.570 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:62 - Done with 2ch
# 2025-08-29 16:10:24.578 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:94 - Writing 3ch images to nifti files...
# 2025-08-29 16:10:24.677 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:109 - Segmenting 3ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 3ch_3d_16001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:05<00:00,  1.40s/it]
# sending off prediction to background worker for resampling and export
# done with 3ch_3d_16001
# 2025-08-29 16:10:55.711 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:62 - Done with 3ch
# 2025-08-29 16:10:55.716 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:94 - Writing 4ch images to nifti files...
# 2025-08-29 16:10:55.794 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:109 - Segmenting 4ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 4ch_3d_14001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:06<00:00,  1.55s/it]
# sending off prediction to background worker for resampling and export
# done with 4ch_3d_14001
# 2025-08-29 16:11:28.829 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:62 - Done with 4ch
# 2025-08-29 16:11:28.838 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:94 - Writing RVOT images to nifti files...
# 2025-08-29 16:11:28.914 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:109 - Segmenting RVOT images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting RVOT_3d_22001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# sending off prediction to background worker for resampling and export
# done with RVOT_3d_22001
# 2025-08-29 16:11:58.671 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:62 - Done with RVOT
# 2025-08-29 16:11:58.674 | SUCCESS  | __main__:<module>:6 - Segmentation complete. Time taken: 179.48266506195068 seconds.

# %% [markdown]
# ## Step 2.1: Correct for mismatching phases (conditional)
# Often, LAX and SAX series do not have matching number of phases. In that case, we need to resample segmentations to have the same number of phases. We use the SAX series as the reference for the 'right' number of phases.

# %%
## Resample segmentations if phases are not consistent between SAX and LAX views
correct_phase_mismatch(case_dst, slice_info_df, num_phases, logger)
# Out:
# 2025-08-29 16:11:59.253 | SUCCESS  | bivme.preprocessing.dicom.correct_phase_mismatch:correct_phase_mismatch:27 - No phase mismatches found. No resampling required.

# %% [markdown]
# ## Step 2.2: Review segmentations (optional)
# Images and segmentations are stored here in nifti format (.nii.gz).
#
#     processed_path
#     └───batch_ID
#         └───case
#
#
# If needed, segmentations can be corrected here, and subsequent code executions will incorporate those changes. 3D Slicer or ITKSnap are good tools for correcting segmentations. We are working on a way to automatically load the images and segmentations into Slicer via a Python backend to make this review process easier.

# %% [markdown]
# ## Step 3: Generate contours
# Contours are generated from the perimeters of the segmentation labels, and other key landmarks (mitral valve, tricuspid valve, aortic valve, pulmonary valve, rv inserts, and LV apex) are estimated from intersections of contours. 2D contours are transformed into 3D cartesian space using the affine constructed from the image position, orientation, and pixel spacing metadata in the DICOMs.

# %%
slice_dict = generate_contours(case_dst, slice_info_df, num_phases, logger)
logger.success(f'Guide points generated successfully.')
# Out:
# 2025-08-29 16:11:59.549 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 8001...
# 2025-08-29 16:11:59.810 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 9001...
# 2025-08-29 16:12:00.217 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 10001...
# 2025-08-29 16:12:00.526 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 11001...
# 2025-08-29 16:12:00.741 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 12001...
# 2025-08-29 16:12:00.877 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 2ch slice 17001...
# 2025-08-29 16:12:01.150 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 3ch slice 16001...
# 2025-08-29 16:12:01.656 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 4ch slice 14001...
# 2025-08-29 16:12:02.212 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for RVOT slice 22001...
# 2025-08-29 16:12:02.572 | SUCCESS  | __main__:<module>:2 - Guide points generated successfully.

# %% [markdown]
# ## Step 4: Export guidepoints
# Contours are then exported into a standardised form, called a GPFile. There is one of these files per frame. This is what the model fitting part of the code requires. There is also a SliceInfoFile which contains the affine information for each slice, which is necessary to allow for breath hold correction prior to model fitting.
#
# Temporal smoothing of landmark points is enabled by default, but can be disabled by changing the boolean below.

# %%
smooth_landmarks = True # Set to True to smooth the landmarks, False to keep them as they are
gp_dir = os.path.join(output, case)

export_guidepoints(case_dst, gp_dir, slice_dict, slice_mapping, smooth_landmarks)
logger.success(f'Guide points exported successfully.')
logger.success(f'Case {case} complete.')
logger.info(f'Total time taken: {time.time()-start_time} seconds.')
# Out:
# 2025-08-29 16:12:06.897 | SUCCESS  | __main__:<module>:5 - Guide points exported successfully.
# 2025-08-29 16:12:06.899 | SUCCESS  | __main__:<module>:6 - Case patient1 complete.
# 2025-08-29 16:12:06.901 | INFO     | __main__:<module>:7 - Total time taken: 235.92653131484985 seconds.

# %% [markdown]
# ## Step 5 (Optional): Plot guidepoints
# The code below will plot the guidepoints at each frame as html files, which can be viewed at:
#
#     plotting_path
#     └───batch_ID
#         └───case
#             └───html
#
# Here's a good place to find any issues before proceeding to model fitting.

# %%
generate_plots_preprocessing = False # Set to True to generate plots for preprocessing, False to skip plotting
include_images = True # Set to True to include images in the HTML file, False to exclude them. Setting to False will speed up the plotting process, as images take a long time to plot and take up a lot of space in the HTML file.

if generate_plots_preprocessing:
    if include_images:
        image_path = os.path.join(case_dst, 'images')
    else:
        image_path = None

    generate_html(gp_dir, out_dir=plotting, gp_suffix='', si_suffix='', frames_to_fit=[], my_logger=logger, model_path=None, image_path=image_path)

    logger.info(f'Guidepoints plotted at {os.path.join(plotting,case,"html")}.')

# %% [markdown]
# # Start of model fitting

# %% [markdown]
# # Step 6: Model fitting
# The model fitting takes in the GPFiles and SliceInfoFiles generated during preprocessing to generate biventricular meshes at each frame. An iterative linear least squares fit is applied, as described in Mauger, C., Gilbert, K., Suinesiaputra, A., Pontre, B., Omens, J., McCulloch, A., & Young, A. (2018, July). An iterative diffeomorphic algorithm for registration of subdivision surfaces: application to congenital heart disease. In 2018 40th Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC) (pp. 596-599). IEEE. DOI: 10.1109/EMBC.2018.8512394.
#
# Breath hold misalignment is corrected by the intersection of short and long axis contours.
#
# Meshes are generated in the output directory you provided in the config file. Mesh vertices are exported in .txt format by default, but can also be exported with faces in .vtk and .obj formats as well for visualisation and postprocessing purposes.
#
# Unfortunately, there is no opportunity for intervention during this step.

# %%
# Set input for fitting equal to the output of preprocessing
config["input_fitting"]["gp_directory"] = output

# Save a copy of the config file to the output folder
output_folder = Path(config["output_fitting"]["output_directory"])
output_folder.mkdir(parents=True, exist_ok=True)
shutil.copy(config_file, output_folder)

# Force overwrite to true
config["output_fitting"]["overwrite"] = True

# Set whether to generate plots for fitting
config["plotting"]["generate_plots_fitting"] = True
config["plotting"]["include_images"] = True # Set to True to include images in the HTML plots, False to exclude them. Setting to False will speed up the plotting process, as images take a long time to plot and take up a lot of space in the HTML file.

# %%
# Where Charlène's magic happens
run_fitting(case, config, logger)
# Out:
# 2025-08-29 16:12:07.861 | INFO     | main:run_fitting:26 - Processing patient1
# 2025-08-29 16:12:07.869 | INFO     | bivme.fitting.perform_fit:perform_fitting:80 - case: patient1
# 2025-08-29 16:12:07.874 | INFO     | bivme.fitting.perform_fit:perform_fitting:88 - ED set to frame #0
# 2025-08-29 16:12:07.877 | INFO     | bivme.fitting.perform_fit:perform_fitting:105 - Shift measured only at ED frame
# 2025-08-29 16:12:10.384 | INFO     | bivme.fitting.perform_fit:perform_fitting:204 - Calculating pose and scale patient1...
# 2025-08-29 16:12:10.521 | INFO     | bivme.fitting.perform_fit:perform_fitting:209 - Fitting of patient1
# 2025-08-29 16:12:10.530 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #0
# 2025-08-29 16:12:11.070 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4073344137637562
# 2025-08-29 16:12:11.521 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.36123493920356
# 2025-08-29 16:12:11.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.213971550789253
# 2025-08-29 16:12:12.459 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1295292885735733
# 2025-08-29 16:12:12.921 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0783306347687156
# 2025-08-29 16:12:13.385 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0426237232750752
# 2025-08-29 16:12:13.851 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9970804870516945
# 2025-08-29 16:12:14.326 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8881567072556418
# 2025-08-29 16:12:14.792 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7208654919429
# 2025-08-29 16:12:15.243 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5150102083922181
# 2025-08-29 16:12:15.728 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3322458977750975
# 2025-08-29 16:12:15.924 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3322458977750975
# 2025-08-29 16:12:16.411 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2502179073756308
# 2025-08-29 16:12:16.613 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2502179073756308
# 2025-08-29 16:12:17.063 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2502179073756308
# 2025-08-29 16:12:17.140 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.160945892333984
# 2025-08-29 16:12:17.247 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2502179073756308
# 2025-08-29 16:12:21.454 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2387335791911416
# 2025-08-29 16:12:24.352 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.234414362251726
# 2025-08-29 16:12:27.274 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2326393902350743
# 2025-08-29 16:12:30.112 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.231850432395482
# 2025-08-29 16:12:32.917 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 15.776089906692505
# 2025-08-29 16:12:39.517 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:12:39.536 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:12:39.551 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:12:39.554 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #1
# 2025-08-29 16:12:40.068 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3796305197451044
# 2025-08-29 16:12:40.504 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2791958777994474
# 2025-08-29 16:12:40.950 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1777801830805337
# 2025-08-29 16:12:41.397 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1017756376556394
# 2025-08-29 16:12:41.866 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0571271814833807
# 2025-08-29 16:12:42.379 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.023596346311882
# 2025-08-29 16:12:42.960 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9794433830586176
# 2025-08-29 16:12:43.719 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8751109657163314
# 2025-08-29 16:12:44.288 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7045761266255204
# 2025-08-29 16:12:44.845 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5185261187850831
# 2025-08-29 16:12:45.365 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3382293156655276
# 2025-08-29 16:12:45.876 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2267898219890108
# 2025-08-29 16:12:46.196 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2267898219890108
# 2025-08-29 16:12:46.524 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2267898219890108
# 2025-08-29 16:12:46.841 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2267898219890108
# 2025-08-29 16:12:47.077 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 7.08658504486084
# 2025-08-29 16:12:47.188 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2267898219890108
# 2025-08-29 16:12:52.415 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.218876726672205
# 2025-08-29 16:12:56.001 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2158759737761073
# 2025-08-29 16:12:59.852 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2146178734092008
# 2025-08-29 16:13:03.874 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 16.795355796813965
# 2025-08-29 16:13:07.275 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:07.291 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:07.308 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:07.311 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #2
# 2025-08-29 16:13:07.866 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3691620359257013
# 2025-08-29 16:13:08.330 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.574508445253503
# 2025-08-29 16:13:08.809 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.241515720024585
# 2025-08-29 16:13:09.278 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.087220500255826
# 2025-08-29 16:13:09.766 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.02783161770765
# 2025-08-29 16:13:10.241 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9953703645268897
# 2025-08-29 16:13:10.726 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9609363999139182
# 2025-08-29 16:13:11.211 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8595714988470153
# 2025-08-29 16:13:11.700 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7002058455804638
# 2025-08-29 16:13:12.195 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5082189651030962
# 2025-08-29 16:13:12.666 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3372442732297567
# 2025-08-29 16:13:13.122 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3372442732297567
# 2025-08-29 16:13:13.610 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2545967018937796
# 2025-08-29 16:13:13.904 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2545967018937796
# 2025-08-29 16:13:14.222 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2545967018937796
# 2025-08-29 16:13:14.439 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.655629634857178
# 2025-08-29 16:13:14.564 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2545967018937796
# 2025-08-29 16:13:18.645 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2451612579565456
# 2025-08-29 16:13:21.503 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.24126698304112
# 2025-08-29 16:13:24.401 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.239533539933311
# 2025-08-29 16:13:27.267 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2387212816120363
# 2025-08-29 16:13:30.246 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 15.804880380630493
# 2025-08-29 16:13:33.726 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:33.741 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:33.755 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:33.759 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #3
# 2025-08-29 16:13:34.293 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.400939652151889
# 2025-08-29 16:13:34.788 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.656001990841839
# 2025-08-29 16:13:35.256 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2543412292092646
# 2025-08-29 16:13:35.765 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.088796358516278
# 2025-08-29 16:13:36.255 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.021703469429248
# 2025-08-29 16:13:36.754 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9854364237227156
# 2025-08-29 16:13:37.247 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9471739174720162
# 2025-08-29 16:13:37.736 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8579853890512572
# 2025-08-29 16:13:38.236 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.703159895250841
# 2025-08-29 16:13:38.712 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5145302450645597
# 2025-08-29 16:13:39.175 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3338591532735333
# 2025-08-29 16:13:39.335 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3338591532735333
# 2025-08-29 16:13:39.789 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2446131021567735
# 2025-08-29 16:13:39.954 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2446131021567735
# 2025-08-29 16:13:40.137 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2446131021567735
# 2025-08-29 16:13:40.238 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.024822473526001
# 2025-08-29 16:13:40.341 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2446131021567735
# 2025-08-29 16:13:44.891 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.234857202103337
# 2025-08-29 16:13:47.880 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2308638772440965
# 2025-08-29 16:13:50.479 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 10.238811492919922
# 2025-08-29 16:13:54.007 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:54.025 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:54.039 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:13:54.042 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #4
# 2025-08-29 16:13:54.551 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.443909136511137
# 2025-08-29 16:13:55.048 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2432627771570512
# 2025-08-29 16:13:55.534 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.091878434226527
# 2025-08-29 16:13:56.029 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.025016593249047
# 2025-08-29 16:13:56.498 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9813438579224225
# 2025-08-29 16:13:56.980 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9568906415069305
# 2025-08-29 16:13:57.486 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9169482237261828
# 2025-08-29 16:13:57.982 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.830785258089841
# 2025-08-29 16:13:58.486 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6814786158655908
# 2025-08-29 16:13:58.982 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5055977214865082
# 2025-08-29 16:13:59.464 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.342100436757748
# 2025-08-29 16:13:59.641 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.342100436757748
# 2025-08-29 16:13:59.847 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 320000.0	 ICF error 1.342100436757748
# 2025-08-29 16:14:00.041 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 200000.0	 ICF error 1.342100436757748
# 2025-08-29 16:14:00.148 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.6738762855529785
# 2025-08-29 16:14:00.259 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.342100436757748
# 2025-08-29 16:14:04.526 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.3172411530127666
# 2025-08-29 16:14:07.393 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.3077308423280423
# 2025-08-29 16:14:10.301 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.3037614406523497
# 2025-08-29 16:14:13.215 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.3019774946741005
# 2025-08-29 16:14:16.105 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 6 Smoothing weight 1000000.0	 ECF error 1.3011365191813398
# 2025-08-29 16:14:19.028 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 18.87735867500305
# 2025-08-29 16:14:22.544 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:14:22.560 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:14:22.572 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:14:22.575 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #5
# 2025-08-29 16:14:23.058 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.540838041869641
# 2025-08-29 16:14:23.551 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.528062296415492
# 2025-08-29 16:14:23.978 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1835741109625464
# 2025-08-29 16:14:24.440 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0297517861381196
# 2025-08-29 16:14:24.899 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.977580001095681
# 2025-08-29 16:14:25.386 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9450406468331736
# 2025-08-29 16:14:25.874 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9147441963996117
# 2025-08-29 16:14:26.373 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8223647255809148
# 2025-08-29 16:14:26.880 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6801180468009804
# 2025-08-29 16:14:27.366 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5077269425707003
# 2025-08-29 16:14:27.838 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3395438372280377
# 2025-08-29 16:14:28.133 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3395438372280377
# 2025-08-29 16:14:28.610 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2506878540215862
# 2025-08-29 16:14:28.798 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2506878540215862
# 2025-08-29 16:14:28.972 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2506878540215862
# 2025-08-29 16:14:29.074 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.0848517417907715
# 2025-08-29 16:14:29.180 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2506878540215862
# 2025-08-29 16:14:33.702 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2402200987865015
# 2025-08-29 16:14:36.685 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 7.6088807582855225
# 2025-08-29 16:14:40.025 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:14:40.038 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:14:40.050 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:14:40.052 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #6
# 2025-08-29 16:14:40.498 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.6873389766739564
# 2025-08-29 16:14:40.949 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.4440857737348165
# 2025-08-29 16:14:41.400 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.162685431803166
# 2025-08-29 16:14:41.852 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.053950726854653
# 2025-08-29 16:14:42.319 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0105259662165382
# 2025-08-29 16:14:42.764 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9798396151751023
# 2025-08-29 16:14:43.239 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.942562574796928
# 2025-08-29 16:14:43.703 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8436652727361442
# 2025-08-29 16:14:44.190 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6946959256119267
# 2025-08-29 16:14:44.686 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5163212042953154
# 2025-08-29 16:14:45.172 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.336190045971598
# 2025-08-29 16:14:45.650 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2073594432772257
# 2025-08-29 16:14:45.823 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2073594432772257
# 2025-08-29 16:14:45.998 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2073594432772257
# 2025-08-29 16:14:46.168 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2073594432772257
# 2025-08-29 16:14:46.267 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.8291404247283936
# 2025-08-29 16:14:46.361 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2073594432772257
# 2025-08-29 16:14:50.438 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.200378681606222
# 2025-08-29 16:14:53.306 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1977162664731253
# 2025-08-29 16:14:56.141 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.196598872582706
# 2025-08-29 16:14:59.032 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.762324810028076
# 2025-08-29 16:15:02.318 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:02.333 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:02.346 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:02.349 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #7
# 2025-08-29 16:15:02.791 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.803707551485527
# 2025-08-29 16:15:03.223 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.4742354091906917
# 2025-08-29 16:15:03.667 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2071923609507182
# 2025-08-29 16:15:04.092 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.094547495467028
# 2025-08-29 16:15:04.553 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.048860965105104
# 2025-08-29 16:15:04.995 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.02241772550233
# 2025-08-29 16:15:05.420 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9807420377730378
# 2025-08-29 16:15:05.859 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8791756358730614
# 2025-08-29 16:15:06.291 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7278223178799093
# 2025-08-29 16:15:06.748 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5313655998865565
# 2025-08-29 16:15:07.194 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.329481205559724
# 2025-08-29 16:15:07.648 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1971285816642856
# 2025-08-29 16:15:07.797 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1971285816642856
# 2025-08-29 16:15:07.958 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1971285816642856
# 2025-08-29 16:15:08.106 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1971285816642856
# 2025-08-29 16:15:08.204 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.477606534957886
# 2025-08-29 16:15:08.293 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1971285816642856
# 2025-08-29 16:15:12.432 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1900437371158117
# 2025-08-29 16:15:15.263 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1872886517786094
# 2025-08-29 16:15:18.054 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1861108582520552
# 2025-08-29 16:15:21.043 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.836992979049683
# 2025-08-29 16:15:24.426 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:24.440 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:24.453 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:24.456 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #8
# 2025-08-29 16:15:24.885 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8801513981262907
# 2025-08-29 16:15:25.322 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.7053974361356423
# 2025-08-29 16:15:25.754 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2542458441670616
# 2025-08-29 16:15:26.217 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.119956735054277
# 2025-08-29 16:15:26.665 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0697559355341433
# 2025-08-29 16:15:27.124 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0385552457033667
# 2025-08-29 16:15:27.559 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9970879255574325
# 2025-08-29 16:15:28.019 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.903026542548884
# 2025-08-29 16:15:28.464 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7516868036341708
# 2025-08-29 16:15:28.927 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5589450428250626
# 2025-08-29 16:15:29.382 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.343913268316271
# 2025-08-29 16:15:29.837 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1865468313103003
# 2025-08-29 16:15:29.985 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1865468313103003
# 2025-08-29 16:15:30.138 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1865468313103003
# 2025-08-29 16:15:30.294 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1865468313103003
# 2025-08-29 16:15:30.393 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.565784215927124
# 2025-08-29 16:15:30.469 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1865468313103003
# 2025-08-29 16:15:35.006 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1791938387628988
# 2025-08-29 16:15:38.158 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.176202304409986
# 2025-08-29 16:15:40.773 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 10.3787522315979
# 2025-08-29 16:15:43.984 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:44.002 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:44.014 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:15:44.018 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #9
# 2025-08-29 16:15:44.409 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.913310024489018
# 2025-08-29 16:15:44.840 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.7058591385873974
# 2025-08-29 16:15:45.295 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2894861458525293
# 2025-08-29 16:15:45.745 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1323410908448595
# 2025-08-29 16:15:46.194 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.077696909814954
# 2025-08-29 16:15:46.651 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.042821255193212
# 2025-08-29 16:15:47.130 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9996988680160082
# 2025-08-29 16:15:47.590 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.900433440426062
# 2025-08-29 16:15:48.041 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.763980836698157
# 2025-08-29 16:15:48.483 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5682883045067681
# 2025-08-29 16:15:48.930 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3384328081201118
# 2025-08-29 16:15:49.094 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3384328081201118
# 2025-08-29 16:15:49.553 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2278626479678596
# 2025-08-29 16:15:49.716 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2278626479678596
# 2025-08-29 16:15:49.870 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2278626479678596
# 2025-08-29 16:15:49.971 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.6217687129974365
# 2025-08-29 16:15:50.049 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2278626479678596
# 2025-08-29 16:15:54.107 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2165145808756723
# 2025-08-29 16:15:57.025 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2117647025274554
# 2025-08-29 16:16:00.001 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2096290788409794
# 2025-08-29 16:16:02.863 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.208622549987094
# 2025-08-29 16:16:05.745 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 15.771466255187988
# 2025-08-29 16:16:09.330 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:16:09.346 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:16:09.357 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:16:09.360 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #10
# 2025-08-29 16:16:09.750 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8953999780446686
# 2025-08-29 16:16:10.187 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.5108616016868353
# 2025-08-29 16:16:10.631 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2852588547326858
# 2025-08-29 16:16:11.043 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1334875576461494
# 2025-08-29 16:16:11.465 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.073799960559536
# 2025-08-29 16:16:11.926 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.039943242789216
# 2025-08-29 16:16:12.369 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9917110361470762
# 2025-08-29 16:16:12.831 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.9029927264404862
# 2025-08-29 16:16:13.297 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7561589625131373
# 2025-08-29 16:16:13.750 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5588699979495235
# 2025-08-29 16:16:14.228 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3347933429089982
# 2025-08-29 16:16:14.392 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3347933429089982
# 2025-08-29 16:16:14.845 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2227942561331782
# 2025-08-29 16:16:14.999 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2227942561331782
# 2025-08-29 16:16:15.144 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2227942561331782
# 2025-08-29 16:16:15.245 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.551110744476318
# 2025-08-29 16:16:15.324 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2227942561331782
# 2025-08-29 16:16:19.329 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.211840125452863
# 2025-08-29 16:16:22.233 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.207382280652044
# 2025-08-29 16:16:25.083 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2054155375263724
# 2025-08-29 16:16:27.892 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2044987823848528
# 2025-08-29 16:16:30.699 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 15.451813220977783
# ...
# 2025-08-29 16:19:59.256 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0328335211891835
# 2025-08-29 16:19:59.708 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0057663178197016
# 2025-08-29 16:20:00.160 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9582139252571824
# 2025-08-29 16:20:00.637 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8570114099116146
# 2025-08-29 16:20:01.088 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6864280245767813
# 2025-08-29 16:20:01.528 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5023676737862997
# 2025-08-29 16:20:01.963 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3358392784316628
# 2025-08-29 16:20:02.139 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3358392784316628
# 2025-08-29 16:20:02.572 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2375896048234587
# 2025-08-29 16:20:02.729 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2375896048234587
# 2025-08-29 16:20:02.888 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2375896048234587
# 2025-08-29 16:20:02.965 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.606435537338257
# 2025-08-29 16:20:03.068 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2375896048234587
# 2025-08-29 16:20:07.490 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.225463930132774
# 2025-08-29 16:20:10.995 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.220524716060127
# 2025-08-29 16:20:14.713 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.745754480361938
# 2025-08-29 16:20:17.881 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:17.898 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:17.913 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:17.914 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #22
# 2025-08-29 16:20:18.411 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3798377235087576
# 2025-08-29 16:20:18.829 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.333983545260087
# 2025-08-29 16:20:19.290 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1979133079069952
# 2025-08-29 16:20:19.781 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.106427342033853
# 2025-08-29 16:20:20.271 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.060582777698349
# 2025-08-29 16:20:20.759 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0218026919415912
# 2025-08-29 16:20:21.214 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9726650315068677
# 2025-08-29 16:20:21.694 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8615367848938291
# 2025-08-29 16:20:22.177 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.693585404780841
# 2025-08-29 16:20:22.648 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.499933514624721
# 2025-08-29 16:20:23.131 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3350279137409127
# 2025-08-29 16:20:23.630 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.211149949368973
# 2025-08-29 16:20:23.814 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.211149949368973
# 2025-08-29 16:20:24.001 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.211149949368973
# 2025-08-29 16:20:24.195 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.211149949368973
# 2025-08-29 16:20:24.306 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.966343641281128
# 2025-08-29 16:20:24.413 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.211149949368973
# 2025-08-29 16:20:29.199 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 4.892464876174927
# 2025-08-29 16:20:32.722 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:32.738 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:32.751 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:32.754 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #23
# 2025-08-29 16:20:33.306 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4095788504932854
# 2025-08-29 16:20:33.754 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 4.2797829647172465
# 2025-08-29 16:20:34.216 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.93166798619686
# 2025-08-29 16:20:34.692 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.2785726014628356
# 2025-08-29 16:20:35.132 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0829682405491923
# 2025-08-29 16:20:35.595 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0324515474142046
# 2025-08-29 16:20:36.064 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9850214668619253
# 2025-08-29 16:20:36.549 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8954379500754355
# 2025-08-29 16:20:36.995 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7264031206746047
# 2025-08-29 16:20:37.427 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.537770415909616
# 2025-08-29 16:20:37.889 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3619271878884245
# 2025-08-29 16:20:38.042 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3619271878884245
# 2025-08-29 16:20:38.470 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.278746673793649
# 2025-08-29 16:20:38.655 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.278746673793649
# 2025-08-29 16:20:38.819 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.278746673793649
# 2025-08-29 16:20:38.904 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.675194025039673
# 2025-08-29 16:20:39.010 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.278746673793649
# 2025-08-29 16:20:43.508 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 4.602656126022339
# 2025-08-29 16:20:46.706 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:46.723 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:46.737 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:20:46.740 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #24
# 2025-08-29 16:20:47.278 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4240568633795805
# 2025-08-29 16:20:47.729 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.83283830961986
# 2025-08-29 16:20:48.177 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.5123521467312697
# 2025-08-29 16:20:48.668 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.282811109163511
# 2025-08-29 16:20:49.162 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.1368078234656753
# 2025-08-29 16:20:49.653 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0772320999128864
# 2025-08-29 16:20:50.154 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 2.020658928438441
# 2025-08-29 16:20:50.631 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.9245391232731721
# 2025-08-29 16:20:51.096 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7472020837534548
# 2025-08-29 16:20:51.549 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5440626941479958
# 2025-08-29 16:20:52.024 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3789900465459801
# 2025-08-29 16:20:52.196 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3789900465459801
# 2025-08-29 16:20:52.367 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 320000.0	 ICF error 1.3789900465459801
# 2025-08-29 16:20:52.534 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 200000.0	 ICF error 1.3789900465459801
# 2025-08-29 16:20:52.619 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.4237024784088135
# 2025-08-29 16:20:52.720 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.3789900465459801
# 2025-08-29 16:20:56.752 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.3533258053438224
# 2025-08-29 16:20:59.505 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.3436644965390223
# 2025-08-29 16:21:02.329 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.339708258996368
# 2025-08-29 16:21:05.138 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.3379560905065242
# 2025-08-29 16:21:07.916 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 6 Smoothing weight 1000000.0	 ECF error 1.3371364243232529
# 2025-08-29 16:21:10.825 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 18.204301118850708
# 2025-08-29 16:21:14.070 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_LV_ENDOCARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:21:14.081 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_EPICARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# 2025-08-29 16:21:14.095 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - patient1_RV_ENDOCARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-08-29 16:21:14.138 | INFO     | main:run_fitting:38 - Average residuals: 1.2333102084996408 for case patient1

# %% [markdown]
# ## (Optional) Analysis and/or visualisation of models
# You can visualise the fitted models frame-by-frame in your browser by opening an html in `output_directory\case\html`. Alternatively, if you have a mesh visualisation software, you can load in the .vtk or .obj files you generated to view the meshes beating through time. I recommend Paraview, as it is open source, and has nice camera controls for creating  videos of the meshes beating through time.
#
# We haven't added any analysis tools to this notebook yet. Refer to the main README on how to generate metrics from the biv-me models.
