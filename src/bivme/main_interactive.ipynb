# %% [markdown]
# # Interactive version of biv-me
# This jupyter notebook contains an identical implementation of biv-me to the main.py. The only difference is that it can be run step-by-step, allowing you to make manual corrections if and when needed to both the view selection and segmentation steps, which can be prone to occasional errors.
#
# The only thing you will need on top of the regular biv-me environment is to download a Python IDE which can run Jupyter notebooks (e.g. Visual Studio Code), and install the ipython kernel as below.
#
# ```
# conda install -n bivme311 ipykernel --update-deps --force-reinstall
# ```
#
# When you run the notebook, you will be prompted to select the kernel to use. Make sure to select your bivme311 environment.
#
# ### Troubleshooting model performance
# Though we are confident in the robustness of our deep learning models, they may not work perfectly for your data. If you find that the segmentation or view selection models perform poorly for your data, reach out to us at [joshua.dillon@auckland.ac.nz](joshua.dillon@auckland.ac.nz) or [charlene.1.mauger@kcl.ac.uk](charlene.1.mauger@kcl.ac.uk) and let us know what kind of data you are using. We are actively developing these models and always looking for ways to enhance their generalisability across vendors, protocols, centres, and patient demographics.

# %%
# Import libraries
import os,sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import tomli
from pathlib import Path
import shutil
import time
import datetime
from loguru import logger

import warnings
warnings.filterwarnings('ignore')

# %%
# This allows for modules to be reloaded automatically if you make any changes to those files.
# %load_ext autoreload
# %autoreload 2

# %%
# Import modules
from bivme.preprocessing.dicom.extract_cines import extract_cines
from bivme.preprocessing.dicom.select_views import select_views
from bivme.preprocessing.dicom.segment_views import segment_views
from bivme.preprocessing.dicom.correct_phase_mismatch import correct_phase_mismatch
from bivme.preprocessing.dicom.generate_contours import generate_contours
from bivme.preprocessing.dicom.export_guidepoints import export_guidepoints
from bivme.plotting.plot_guidepoints import generate_html 
from main import run_fitting

# %%
# Set up logging
log_level = "DEBUG"
log_format = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS zz}</green> | <level>{level: <8}</level> | <yellow>Line {line: >4} ({file}):</yellow> <b>{message}</b>"

# %%
# Check if GPU is available (torch)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2025-06-13 01:40:55.276 | INFO     | __main__:<module>:3 - Using device: cuda

# %% [markdown]
# # Config file
# As with the main.py, you should customise the template config file in `src/bivme/configs/config.toml` for your specific batch and use case. This config file will be read in and the inputs used for the remainder of this pipeline.

# %%
config_file = 'configs/config.toml' # Path to the config file

# %%
# Load config
with open(config_file, mode="rb") as fp:
    logger.info(f'Loading config file: {config_file}')
    config = tomli.load(fp)

# TOML Schema Validation
# This needs to be done to make sure the config file is valid.
# Going forward, we will trust you that all of the inputs in the config file are correct, unlike the main.py which does not trust you.

match config:
    case {
        "modules": {"preprocessing": bool(), "fitting": bool()},

        "logging": {"show_detailed_logging": bool(), "generate_log_file": bool()},

        "input_pp": {"source": str(),
                    "batch_ID": str(),
                    "analyst_id": str(),
                    "processing": str(),
                    "states": str()
                    },
        "view-selection": {"option": str(), "correct_mode": str()},
        "output_pp": {"overwrite": bool(), "generate_plots": bool(), "output_directory": str()},

        "input_fitting": {"gp_directory": str(),
                    "gp_suffix": str(),
                    "si_suffix": str(),
                    },
        "breathhold_correction": {"shifting": str(), "ed_frame": int()},
        "gp_processing": {"sampling": int(), "num_of_phantom_points_av": int(), "num_of_phantom_points_mv": int(), "num_of_phantom_points_tv": int(), "num_of_phantom_points_pv": int()},
        "multiprocessing": {"workers": int()},
        "fitting_weights": {"guide_points": float(), "convex_problem": float(), "transmural": float()},
        "output_fitting": {"output_directory": str(), "output_meshes": list(), "closed_mesh": bool(),   "export_control_mesh": bool(), "mesh_format": str(),  "overwrite": bool()},
    }:
        pass
    case _:
            raise ValueError(f"Invalid configuration: {config}")
# Out:
# 2025-06-13 01:40:55.755 | INFO     | __main__:<module>:3 - Loading config file: configs/config.toml

# %% [markdown]
# ## Start of preprocessing
# This code reads in DICOM files and generates GPFiles for personalised biventricular mesh fitting.

# %% [markdown]
# ## Step 0: Set up directories
# All directories will be created for you except for the input_path. This should point to your DICOMs, separated into folders by case like so:
#
#     input_path
#     └─── case1
#         │─── *
#     └─── case2
#         │─── *
#     └─── ...
#
# Don't worry about preprocessing your dicoms, separating by scan type, or excluding non-cines. The pipeline should find which ones are cines and which ones aren't by checking key terms within the series descriptions. Check src/bivme/preprocessing/dicom/extract_cines.py for the list of key terms.

# %%
batch_ID = config['input_pp']['batch_ID'] # This will serve as your output folder name. Example: 'test'
analyst_id = config['input_pp']['analyst_id'] # Example: 'analyst1'
input_path = config['input_pp']['source'] # Path to the input DICOM folder
processed_path = config['input_pp']['processing'] # Path to the processed folder, where view predictions and segmentations will be stored. This will be created upon run time.
states_path = config['input_pp']['states'] # Path to the states folder, where the logs and view predictions will be stored for reference. This will be created upon run time.
output_path = config['output_pp']['output_directory'] # Path to the output folder, where GP files will be stored. This will be created upon run time.
plotting_path = processed_path # Path to the plotting folder, where the HTML file of plotted guidepoints will be stored. This will be created upon run time.

# Target path: src/bivme/preprocessing/dicom/models
# You can hardcode the model path here or set it as an environment variable.
cwd = os.getcwd()
print('Current working directory:', cwd)
MODEL_DIR = os.path.join(cwd,'preprocessing/dicom/models')
print('Model directory:', MODEL_DIR)
# Out:
# Current working directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme
# Model directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme\preprocessing/dicom/models

# %% [markdown]
# ## Step 0.1: Choose case

# %%
case = 'patient1' # Enter the case ID. This should be a subfolder within the input_path.

# %%
# Set up batch specific folders
src = os.path.join(input_path)
dst = os.path.join(processed_path, batch_ID)
states = os.path.join(states_path, batch_ID)
output = os.path.join(output_path, batch_ID)
plotting = os.path.join(plotting_path, batch_ID)


case_src = os.path.join(src, case)
if not os.path.isdir(case_src):
    logger.error(f'Case {case} not found in source folder. Please check the case ID.')
    sys.exit()

os.makedirs(dst, exist_ok=True)
os.makedirs(states, exist_ok=True)
os.makedirs(output, exist_ok=True)
os.makedirs(plotting, exist_ok=True)

case_dst = os.path.join(dst, case)
case_output = os.path.join(output, case)

if os.path.exists(case_output):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_output)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

# %%
# Create log file to record some details
states = os.path.join(states, case, analyst_id)
os.makedirs(states, exist_ok=True)

logger_id = logger.add(f'{states}/log_file_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.log', level=log_level, format=log_format,
    colorize=False, backtrace=True,
    diagnose=True)

logger.info(f'Processing case: {case}')

start_time = time.time()
# Out:
# 2025-06-13 01:40:56.759 | INFO     | __main__:<module>:9 - Processing case: patient1

# %% [markdown]
# ## Step 0.2: Pre-preprocess dicoms
# By default, the pipeline takes in only cardiac cine images in .dcm format. The pre-preprocessing reads in the raw dicoms and uses the series descriptions to infer which are cines and which aren't. The 'cine only' dicoms are saved to:
#
#     processed_path
#     └───batch_ID
#         └───processed-dicoms

# %%
logger.info(f'Finding cines...')
extract_cines(case_src, case_dst, logger)

case_src = os.path.join(case_dst, 'processed-dicoms') # Update source directory

logger.success(f'Pre-preprocessing complete. Cines extracted to {case_src}.')
# Out:
# 2025-06-13 01:40:57.017 | INFO     | __main__:<module>:1 - Finding cines...
# 2025-06-13 01:41:03.471 | SUCCESS  | __main__:<module>:6 - Pre-preprocessing complete. Cines extracted to ../../example/processing\test\patient1\processed-dicoms.

# %% [markdown]
# ## Step 1: View selection
# View selection can be carried out in four main ways.
#
# The first option is the 'default' option. This involves the use of two models - one using only dicom metadata and one using only image data. Each model performs prediction separately and then predictions are combined for a final verdict. This should be the most robust option, but takes longer to complete.
#
# The second option is the 'metadata-only' option. This only uses metadata. This model can struggle with subtle distinctions between similar views (e.g. between SAX and SAX-atria) but is excellent at distinguishing between general categories of view (e.g. SAX vs LAX).
#
# The third option is the 'image-only' option. This only uses image data. This model is better all round than the metadata-only model, but can occasionally produce spurious predictions.
#
# The fourth option is the 'load' option. This loads view predictions from the states folder. This is useful if view predictions have already been made, avoiding the need to rerun prediction from scratch. It also allows for you to make and save manual corrections to the selected views.

# %%
option = 'default' # Either 'default', 'metadata-only', 'image-only', or 'load'. 
# 'default' will combine dicom metadata and image data to select the correct view. 'metadata-only' will only use metadata. 'image-only' will only use the image data. 
# 'load' will load view predictions from the states folder, if view predictions have already been made.

correct_mode = 'manual' # Either 'manual', 'adaptive', or 'automatic'. 
# 'manual' will launch a GUI after completing view predictions to allow you to correct any mispredictions. 
# 'adaptive' will only launch a GUI if there are any poor predictions or missing views
# 'automatic' will not launch the GUI and will use the predictions as they are.

slice_info_df, num_phases, slice_mapping = select_views(case, case_src, case_dst, MODEL_DIR, states, option, correct_mode, logger)

logger.success(f'View selection complete.')
logger.info(f'Number of phases: {num_phases}')
# Out:
# 2025-06-13 01:41:03.781 | INFO     | bivme.preprocessing.dicom.select_views:select_views:92 - Performing metadata-based view prediction...
# 2025-06-13 01:41:18.258 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:95 - Metadata-based view prediction complete.
# 2025-06-13 01:41:18.258 | INFO     | bivme.preprocessing.dicom.select_views:select_views:98 - Performing image-based view prediction...
# 2025-06-13 01:41:29.808 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:102 - Image-based view prediction complete.
# 2025-06-13 01:41:29.808 | INFO     | bivme.preprocessing.dicom.select_views:select_views:105 - Combining metadata and image-based view predictions...
# 2025-06-13 01:41:29.858 | WARNING  | bivme.preprocessing.dicom.select_views:select_views:129 - Low confidence for series 8001 with image based prediction (SAX). Metadata-based prediction is SAX.
# 2025-06-13 01:41:29.884 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:202 - View predictions for patient1:
# 2025-06-13 01:41:29.884 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - 3ch: 1 series
# 2025-06-13 01:41:29.888 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - SAX: 5 series
# 2025-06-13 01:41:29.888 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - 2ch: 1 series
# 2025-06-13 01:41:29.888 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - 2ch-RT: 1 series
# 2025-06-13 01:41:29.894 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - 4ch: 1 series
# 2025-06-13 01:41:29.894 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - RVOT: 1 series
# 2025-06-13 01:41:29.894 | INFO     | bivme.preprocessing.dicom.select_views:select_views:204 - SAX-atria: 1 series
# 2025-06-13 01:41:30.214 | INFO     | bivme.preprocessing.dicom.select_views:select_views:221 - Manual corrections mode enabled. Launching view correction GUI...
# 2025-06-13 01:41:50.112 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:52 - ----- Saving view predictions...
# 2025-06-13 01:41:50.112 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 10001 corrected to SAX.
# 2025-06-13 01:41:50.112 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 11001 corrected to SAX.
# 2025-06-13 01:41:50.122 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 12001 corrected to SAX.
# 2025-06-13 01:41:50.122 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 14001 corrected to 4ch.
# 2025-06-13 01:41:50.122 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 16001 corrected to 3ch.
# 2025-06-13 01:41:50.122 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 17001 corrected to 2ch.
# 2025-06-13 01:41:50.122 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 19001 corrected to 2ch-RT.
# 2025-06-13 01:41:50.132 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 22001 corrected to RVOT.
# 2025-06-13 01:41:50.132 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 7001 corrected to SAX-atria.
# 2025-06-13 01:41:50.132 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 8001 corrected to SAX.
# 2025-06-13 01:41:50.138 | INFO     | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:61 - ----- Series 9001 corrected to SAX.
# 2025-06-13 01:41:50.142 | SUCCESS  | bivme.preprocessing.dicom.src.viewcorrection:save_corrections:69 - ----- View predictions saved successfully. Close the window to continue.
# 2025-06-13 01:41:59.555 | SUCCESS  | bivme.preprocessing.dicom.select_views:correct_views:84 - View correction complete. Predictions saved.
# 2025-06-13 01:41:59.581 | SUCCESS  | __main__:<module>:12 - View selection complete.
# 2025-06-13 01:41:59.581 | INFO     | __main__:<module>:13 - Number of phases: 25

# %% [markdown]
# ## Step 2: Segmentation
# Using the view classifications from step 1, images will be written into nifti form and sent to the segmentation models to be automatically segmented. There is one segmentation model specific to each view (currently SAX, 2ch, 3ch, 4ch, or RVOT), so only images belonging to those classes will be used from now on.

# %%
## Segmentation
seg_start_time = time.time()
segment_views(case_dst, MODEL_DIR, slice_info_df, logger) # Segmentation occurs on 2D+t (3D) images using 3D nnU-Net models
seg_end_time = time.time()

logger.success(f'Segmentation complete. Time taken: {seg_end_time-seg_start_time} seconds.')
# Out:
# 2025-06-13 01:41:59.843 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:86 - Writing SAX images to nifti files...
# 2025-06-13 01:42:00.111 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:101 - Segmenting SAX images...
# There are 5 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 5 cases that I would like to predict
#
# Predicting SAX_3d_10001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_10001
#
# Predicting SAX_3d_11001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_11001
#
# Predicting SAX_3d_12001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_12001
#
# Predicting SAX_3d_8001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_8001
#
# Predicting SAX_3d_9001:
# perform_everything_on_device: True
# 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]
# sending off prediction to background worker for resampling and export
# done with SAX_3d_9001
# 2025-06-13 01:42:49.214 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with SAX
# 2025-06-13 01:42:49.220 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:86 - Writing 2ch images to nifti files...
# 2025-06-13 01:42:49.282 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:101 - Segmenting 2ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 2ch_3d_17001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:03<00:00,  3.27s/it]
# sending off prediction to background worker for resampling and export
# done with 2ch_3d_17001
# 2025-06-13 01:43:10.704 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 2ch
# 2025-06-13 01:43:10.704 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:86 - Writing 3ch images to nifti files...
# 2025-06-13 01:43:10.762 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:101 - Segmenting 3ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 3ch_3d_16001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:07<00:00,  1.76s/it]
# sending off prediction to background worker for resampling and export
# done with 3ch_3d_16001
# 2025-06-13 01:43:36.061 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 3ch
# 2025-06-13 01:43:36.069 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:86 - Writing 4ch images to nifti files...
# 2025-06-13 01:43:36.127 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:101 - Segmenting 4ch images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting 4ch_3d_14001:
# perform_everything_on_device: True
# 100%|██████████| 4/4 [00:07<00:00,  1.93s/it]
# sending off prediction to background worker for resampling and export
# done with 4ch_3d_14001
# 2025-06-13 01:44:02.071 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with 4ch
# 2025-06-13 01:44:02.081 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:86 - Writing RVOT images to nifti files...
# 2025-06-13 01:44:02.142 | INFO     | bivme.preprocessing.dicom.segment_views:segment_views:101 - Segmenting RVOT images...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting RVOT_3d_22001:
# perform_everything_on_device: True
# 100%|██████████| 1/1 [00:02<00:00,  2.43s/it]
# sending off prediction to background worker for resampling and export
# done with RVOT_3d_22001
# 2025-06-13 01:44:22.394 | INFO     | bivme.preprocessing.dicom.segment_views:predict_view:58 - Done with RVOT
# 2025-06-13 01:44:22.404 | SUCCESS  | __main__:<module>:6 - Segmentation complete. Time taken: 142.57711219787598 seconds.

# %% [markdown]
# ## Step 2.1: Correct for mismatching phases (conditional)
# Often, LAX and SAX series do not have matching number of phases. In that case, we need to resample segmentations to have the same number of phases. We use the SAX series as the reference for the 'right' number of phases.

# %%
## Resample segmentations if phases are not consistent between SAX and LAX views
correct_phase_mismatch(case_dst, slice_info_df, num_phases, logger)
# Out:
# 2025-06-13 01:44:22.778 | SUCCESS  | bivme.preprocessing.dicom.correct_phase_mismatch:correct_phase_mismatch:27 - No phase mismatches found. No resampling required.

# %% [markdown]
# ## Step 2.2: Review segmentations (optional)
# Images and segmentations are stored here in nifti format (.nii.gz).
#
#     processed_path
#     └───batch_ID
#         └───case
#
#
# Hopefully it won't be necessary 99% of the time, but, if you wish, segmentations can be corrected here, and the rest of the code will incorporate those changes.
#
# By default, the contouring code (after segmentation) carries out some basic QC. All label types (except for the RV myocardium) have all but their largest components removed, so you shouldn't need to worry about fixing minor things such as removing extraneous label regions. If you find a problem with the exported contours or fitted models, it's more likely due to poor RV myo segmentation or poor segmentation around valve planes.
#
# 3D Slicer or ITKSnap are good tools for correcting segmentations. We are working on a way to automatically load the images and segmentations into Slicer via a Python backend to make this review process easier.

# %% [markdown]
# ## Step 3: Generate contours
# Contours are generated from the perimeters of the segmentation labels, and other key landmarks (mitral valve, tricuspid valve, aortic valve, pulmonary valve, rv inserts, and LV apex) are estimated from intersections of contours. 2D contours are transformed into 3D cartesian space using the affine constructed from the image position, orientation, and pixel spacing metadata in the DICOMs.

# %%
slice_dict = generate_contours(case_dst, slice_info_df, num_phases, logger)
logger.success(f'Guide points generated successfully.')
# Out:
# 2025-06-13 01:44:23.025 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 8001...
# 2025-06-13 01:44:23.278 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 9001...
# 2025-06-13 01:44:23.625 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 10001...
# 2025-06-13 01:44:23.845 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 11001...
# 2025-06-13 01:44:24.008 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for SAX slice 12001...
# 2025-06-13 01:44:24.108 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 2ch slice 17001...
# 2025-06-13 01:44:24.245 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 3ch slice 16001...
# 2025-06-13 01:44:24.545 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for 4ch slice 14001...
# 2025-06-13 01:44:24.816 | INFO     | bivme.preprocessing.dicom.generate_contours:generate_contours:10 - Generating contours for RVOT slice 22001...
# 2025-06-13 01:44:25.042 | SUCCESS  | __main__:<module>:2 - Guide points generated successfully.

# %% [markdown]
# ## Step 4: Export guidepoints
# Contours are then exported into a standardised form, called a GPFile. There is one of these files per frame. This is what the model fitting part of the code requires. There is also a SliceInfoFile which contains the affine information for each slice, which is necessary to allow for breath hold correction prior to model fitting.

# %%
gp_dir = os.path.join(output, case)
export_guidepoints(case_dst, gp_dir, slice_dict, slice_mapping)
logger.success(f'Guide points exported successfully.')
logger.success(f'Case {case} complete.')
logger.info(f'Total time taken: {time.time()-start_time} seconds.')
# Out:
# 2025-06-13 01:44:28.322 | SUCCESS  | __main__:<module>:3 - Guide points exported successfully.
# 2025-06-13 01:44:28.322 | SUCCESS  | __main__:<module>:4 - Case patient1 complete.
# 2025-06-13 01:44:28.322 | INFO     | __main__:<module>:5 - Total time taken: 211.56310319900513 seconds.

# %% [markdown]
# ## Step 5 (Optional): Plot guidepoints
# The code below will plot the guidepoints at each frame as html files, which can be viewed at:
#
#     plotting_path
#     └───batch_ID
#         └───case
#             └───html
#
# Here's a good place to find any issues before proceeding to model fitting.

# %%
gp_dir = os.path.join(output, case)
generate_html(gp_dir, out_dir=plotting, gp_suffix='', si_suffix='', frames_to_fit=[], my_logger=logger, model_path=None)

logger.info(f'Guidepoints plotted at {os.path.join(plotting,case,"html")}.')
# Out:
# 2025-06-13 01:44:28.580 | INFO     | bivme.plotting.plot_guidepoints:generate_html:63 - case: patient1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-06-13 01:44:34.227 | INFO     | __main__:<module>:4 - Guidepoints plotted at ../../example/processing\test\patient1\html.

# %% [markdown]
# # Start of model fitting

# %% [markdown]
# # Step 6: Model fitting
# The model fitting takes in the GPFiles and SliceInfoFiles generated during preprocessing to generate biventricular meshes at each frame. An iterative linear least squares fit is applied, as described in Mauger, C., Gilbert, K., Suinesiaputra, A., Pontre, B., Omens, J., McCulloch, A., & Young, A. (2018, July). An iterative diffeomorphic algorithm for registration of subdivision surfaces: application to congenital heart disease. In 2018 40th Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC) (pp. 596-599). IEEE. DOI: 10.1109/EMBC.2018.8512394.
#
# Breath hold misalignment is corrected by the intersection of short and long axis contours.
#
# Meshes are generated in the output directory you provided in the config file. Mesh vertices are exported in .txt format by default, but can also be exported with faces in .vtk and .obj formats as well for visualisation and postprocessing purposes.
#
# Unfortunately, there is no opportunity for intervention during this step.

# %%
# Set input for fitting equal to the output of preprocessing
config["input_fitting"]["gp_directory"] = output

# Save a copy of the config file to the output folder
output_folder = Path(config["output_fitting"]["output_directory"])
output_folder.mkdir(parents=True, exist_ok=True)
shutil.copy(config_file, output_folder)

# Force overwrite to true
config["output_fitting"]["overwrite"] = True

# %%
# Where Charlène's magic happens
run_fitting(case, config, logger)
# Out:
# 2025-06-13 01:44:34.815 | INFO     | main:run_fitting:26 - Processing patient1
# 2025-06-13 01:44:34.825 | INFO     | bivme.fitting.perform_fit:perform_fitting:85 - case: patient1
# 2025-06-13 01:44:34.827 | INFO     | bivme.fitting.perform_fit:perform_fitting:93 - ED set to frame #0
# 2025-06-13 01:44:34.829 | INFO     | bivme.fitting.perform_fit:perform_fitting:110 - Shift measured only at ED frame
# 2025-06-13 01:44:37.001 | INFO     | bivme.fitting.perform_fit:perform_fitting:209 - Calculating pose and scale patient1...
# 2025-06-13 01:44:37.121 | INFO     | bivme.fitting.perform_fit:perform_fitting:214 - Fitting of patient1
# 2025-06-13 01:44:37.131 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #0
# 2025-06-13 01:44:37.633 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3999114009323237
# 2025-06-13 01:44:38.105 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3448940451264693
# 2025-06-13 01:44:38.587 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2047864965044206
# 2025-06-13 01:44:39.035 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1113009191143295
# 2025-06-13 01:44:39.517 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.063308172205394
# 2025-06-13 01:44:39.968 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0191638192196324
# 2025-06-13 01:44:40.460 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9607155769163147
# 2025-06-13 01:44:40.950 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8561283539174043
# 2025-06-13 01:44:41.433 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7168552419430598
# 2025-06-13 01:44:41.893 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5278610934803365
# 2025-06-13 01:44:42.371 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3493450628912744
# 2025-06-13 01:44:42.853 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2354167198663344
# 2025-06-13 01:44:42.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2354167198663344
# 2025-06-13 01:44:43.144 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2354167198663344
# 2025-06-13 01:44:43.581 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2354167198663344
# 2025-06-13 01:44:43.651 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.087671518325806
# 2025-06-13 01:44:43.752 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2354167198663344
# 2025-06-13 01:44:47.552 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.22775335981235
# 2025-06-13 01:44:50.164 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2247076821962757
# 2025-06-13 01:44:52.739 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2233779460236056
# 2025-06-13 01:44:55.375 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2227614326888905
# 2025-06-13 01:44:57.959 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.307708024978638
# 2025-06-13 01:45:00.123 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:00.133 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:00.143 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_000.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:00.143 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #1
# 2025-06-13 01:45:00.627 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3697001265509465
# 2025-06-13 01:45:00.711 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 2500000000000.0	 ICF error 2.3697001265509465
# 2025-06-13 01:45:01.164 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 1000000000000.0	 ICF error 2.314197818015027
# 2025-06-13 01:45:01.625 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 400000000000.0	 ICF error 2.2472565171471164
# 2025-06-13 01:45:02.064 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 160000000000.0	 ICF error 2.173014780280852
# 2025-06-13 01:45:02.519 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 64000000000.0	 ICF error 2.097945780671221
# 2025-06-13 01:45:02.972 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 25600000000.0	 ICF error 2.0602788830415992
# 2025-06-13 01:45:03.425 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 10240000000.0	 ICF error 2.030584082875378
# 2025-06-13 01:45:03.881 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 4096000000.0	 ICF error 1.991533639554176
# 2025-06-13 01:45:04.346 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 1638400000.0	 ICF error 1.9717124869801284
# 2025-06-13 01:45:04.809 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 655360000.0	 ICF error 1.946809876901972
# 2025-06-13 01:45:05.259 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 262144000.0	 ICF error 1.9287681588654086
# 2025-06-13 01:45:05.715 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 104857600.0	 ICF error 1.8941768138874737
# 2025-06-13 01:45:06.179 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 41943040.0	 ICF error 1.8344082736330718
# 2025-06-13 01:45:06.646 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 16777216.0	 ICF error 1.756388195375083
# 2025-06-13 01:45:07.111 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 16 Weight 6710886.4	 ICF error 1.6731393596646353
# 2025-06-13 01:45:07.576 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 17 Weight 2684354.56	 ICF error 1.5686226731570734
# 2025-06-13 01:45:08.026 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 18 Weight 1073741.824	 ICF error 1.455711319055119
# 2025-06-13 01:45:08.476 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 19 Weight 429496.7296	 ICF error 1.3586287149176337
# 2025-06-13 01:45:08.929 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 20 Weight 171798.69184	 ICF error 1.2759410770783048
# 2025-06-13 01:45:09.409 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 21 Weight 68719.47673600001	 ICF error 1.2186340274879333
# 2025-06-13 01:45:09.860 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 22 Weight 85899.34592000002	 ICF error 1.2186340274879333
# 2025-06-13 01:45:10.326 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 23 Weight 53687.09120000001	 ICF error 1.2186340274879333
# 2025-06-13 01:45:10.679 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 10.120080947875977
# 2025-06-13 01:45:10.759 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2186340274879333
# 2025-06-13 01:45:14.426 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.21228336126399
# 2025-06-13 01:45:17.043 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2095262883447282
# 2025-06-13 01:45:19.643 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2082566797261518
# 2025-06-13 01:45:22.257 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2076504115366689
# 2025-06-13 01:45:24.865 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.185796976089478
# 2025-06-13 01:45:26.967 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:26.976 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:26.996 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_001.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:26.996 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #2
# 2025-06-13 01:45:27.479 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3516749224488067
# 2025-06-13 01:45:27.960 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2386345454200014
# 2025-06-13 01:45:28.430 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.133730930558711
# 2025-06-13 01:45:28.877 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.051776237788272
# 2025-06-13 01:45:29.343 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0132832937364955
# 2025-06-13 01:45:29.799 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9802692207466694
# 2025-06-13 01:45:30.259 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9330392122751265
# 2025-06-13 01:45:30.719 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8257090960600808
# 2025-06-13 01:45:31.179 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6836995321973462
# 2025-06-13 01:45:31.669 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4972372140508137
# 2025-06-13 01:45:32.136 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3269510048895892
# 2025-06-13 01:45:32.593 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2136897746447306
# 2025-06-13 01:45:33.027 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2136897746447306
# 2025-06-13 01:45:33.453 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2136897746447306
# 2025-06-13 01:45:33.883 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2136897746447306
# 2025-06-13 01:45:34.243 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.840147495269775
# 2025-06-13 01:45:34.350 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2136897746447306
# 2025-06-13 01:45:38.036 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2062835344538072
# 2025-06-13 01:45:40.626 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2032382459501114
# 2025-06-13 01:45:43.309 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2018841161749187
# 2025-06-13 01:45:45.940 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2012501346314326
# 2025-06-13 01:45:48.570 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.31667447090149
# 2025-06-13 01:45:50.614 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:50.627 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:50.643 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_002.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:45:50.643 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #3
# 2025-06-13 01:45:51.106 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3695679631315465
# 2025-06-13 01:45:51.554 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2461408939985197
# 2025-06-13 01:45:52.011 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1137703482811663
# 2025-06-13 01:45:52.461 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0258623031718983
# 2025-06-13 01:45:52.910 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9978772841804364
# 2025-06-13 01:45:53.368 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9606535706920214
# 2025-06-13 01:45:53.827 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9175558521561042
# 2025-06-13 01:45:54.277 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8230077930586908
# 2025-06-13 01:45:54.730 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6791027722061909
# 2025-06-13 01:45:55.183 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.4921357695364332
# 2025-06-13 01:45:55.653 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.326121877608715
# 2025-06-13 01:45:56.096 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.215227498132395
# 2025-06-13 01:45:56.310 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.215227498132395
# 2025-06-13 01:45:56.710 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.215227498132395
# 2025-06-13 01:45:57.120 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.215227498132395
# 2025-06-13 01:45:57.460 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.430200815200806
# 2025-06-13 01:45:57.561 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.215227498132395
# 2025-06-13 01:46:01.216 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2077503459546755
# 2025-06-13 01:46:03.727 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2048242138693832
# 2025-06-13 01:46:06.300 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2035785031809825
# 2025-06-13 01:46:08.877 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.416797161102295
# 2025-06-13 01:46:11.254 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:11.270 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:11.280 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_003.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:11.280 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #4
# 2025-06-13 01:46:11.747 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4255683224967606
# 2025-06-13 01:46:12.170 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 3.796598136960663
# 2025-06-13 01:46:12.627 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.328416263953996
# 2025-06-13 01:46:13.078 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0598665701272996
# 2025-06-13 01:46:13.514 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.971745114139283
# 2025-06-13 01:46:13.973 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9380736288693088
# 2025-06-13 01:46:14.420 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8972444335830105
# 2025-06-13 01:46:14.861 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.805830370616385
# 2025-06-13 01:46:15.303 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6544101395756607
# 2025-06-13 01:46:15.757 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.469587326257122
# 2025-06-13 01:46:16.200 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.312972587022956
# 2025-06-13 01:46:16.660 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2107095484402604
# 2025-06-13 01:46:16.861 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2107095484402604
# 2025-06-13 01:46:17.071 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2107095484402604
# 2025-06-13 01:46:17.274 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2107095484402604
# 2025-06-13 01:46:17.400 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.7319183349609375
# 2025-06-13 01:46:17.496 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2107095484402604
# 2025-06-13 01:46:21.211 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.20353139212963
# 2025-06-13 01:46:23.807 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2006830112107112
# 2025-06-13 01:46:26.344 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1994438822497426
# 2025-06-13 01:46:28.947 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.536448240280151
# 2025-06-13 01:46:30.973 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:30.984 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:31.004 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_004.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:31.004 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #5
# 2025-06-13 01:46:31.432 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.5055682185896284
# 2025-06-13 01:46:31.866 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.242467565730128
# 2025-06-13 01:46:32.301 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1002158632920014
# 2025-06-13 01:46:32.748 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.026282471337581
# 2025-06-13 01:46:33.201 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9778888699989317
# 2025-06-13 01:46:33.645 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9434134193779207
# 2025-06-13 01:46:34.104 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9072579274284556
# 2025-06-13 01:46:34.546 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.799489171839947
# 2025-06-13 01:46:34.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6561278645826454
# 2025-06-13 01:46:35.440 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.491346214094765
# 2025-06-13 01:46:35.904 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3286014141498785
# 2025-06-13 01:46:36.360 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.21155286610089
# 2025-06-13 01:46:36.621 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.21155286610089
# 2025-06-13 01:46:36.895 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.21155286610089
# 2025-06-13 01:46:37.170 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.21155286610089
# 2025-06-13 01:46:37.366 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.9953272342681885
# 2025-06-13 01:46:37.454 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.21155286610089
# 2025-06-13 01:46:41.304 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2044262698014714
# 2025-06-13 01:46:44.061 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2014856047100473
# 2025-06-13 01:46:46.594 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2001710229162448
# 2025-06-13 01:46:49.148 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1995526803764078
# 2025-06-13 01:46:51.751 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.384957551956177
# 2025-06-13 01:46:53.831 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:53.852 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:53.861 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_005.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:46:53.861 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #6
# 2025-06-13 01:46:54.285 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.6715396915877085
# 2025-06-13 01:46:54.726 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.426230274138933
# 2025-06-13 01:46:55.158 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1824769223714418
# 2025-06-13 01:46:55.595 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0853459990175893
# 2025-06-13 01:46:56.038 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0227625575907093
# 2025-06-13 01:46:56.471 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.984269446219611
# 2025-06-13 01:46:56.895 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.937804334677093
# 2025-06-13 01:46:57.354 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.843854310325441
# 2025-06-13 01:46:57.787 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6942009863560814
# 2025-06-13 01:46:58.228 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5097386721047539
# 2025-06-13 01:46:58.672 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3314613200925713
# 2025-06-13 01:46:59.106 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2007808622093838
# 2025-06-13 01:46:59.262 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2007808622093838
# 2025-06-13 01:46:59.428 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2007808622093838
# 2025-06-13 01:46:59.598 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2007808622093838
# 2025-06-13 01:46:59.695 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.4661054611206055
# 2025-06-13 01:46:59.781 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2007808622093838
# 2025-06-13 01:47:03.546 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1919719948691005
# 2025-06-13 01:47:06.269 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1883904096656757
# 2025-06-13 01:47:08.678 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 8.98348879814148
# 2025-06-13 01:47:10.817 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:10.836 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:10.849 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_006.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:10.849 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #7
# 2025-06-13 01:47:11.232 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.7786089219070225
# 2025-06-13 01:47:11.662 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.725837249975553
# 2025-06-13 01:47:12.121 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.220818749660112
# 2025-06-13 01:47:12.548 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.090876127534158
# 2025-06-13 01:47:12.995 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.039766449622361
# 2025-06-13 01:47:13.429 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9991919413938726
# 2025-06-13 01:47:13.884 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9538532407197209
# 2025-06-13 01:47:14.326 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8575833057026758
# 2025-06-13 01:47:14.765 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.711625099822244
# 2025-06-13 01:47:15.212 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5352286487676934
# 2025-06-13 01:47:15.655 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3336853918876643
# 2025-06-13 01:47:16.112 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2027526478341872
# 2025-06-13 01:47:16.412 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2027526478341872
# 2025-06-13 01:47:16.719 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2027526478341872
# 2025-06-13 01:47:17.019 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2027526478341872
# 2025-06-13 01:47:17.269 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.1038877964019775
# 2025-06-13 01:47:17.345 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2027526478341872
# 2025-06-13 01:47:21.099 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.19591427562317
# 2025-06-13 01:47:23.705 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.193134771897298
# 2025-06-13 01:47:26.329 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1919063907304654
# 2025-06-13 01:47:28.995 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.726584911346436
# 2025-06-13 01:47:31.129 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:31.138 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:31.155 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_007.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:31.159 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #8
# 2025-06-13 01:47:31.496 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.8684544380624892
# 2025-06-13 01:47:31.932 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.7356634187223308
# 2025-06-13 01:47:32.379 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.254789929319152
# 2025-06-13 01:47:32.812 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1148391875974157
# 2025-06-13 01:47:33.255 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0627175999712235
# 2025-06-13 01:47:33.703 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.020951106980367
# 2025-06-13 01:47:34.139 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.980745139842653
# 2025-06-13 01:47:34.572 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8851107446723465
# 2025-06-13 01:47:34.996 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.74730971361391
# 2025-06-13 01:47:35.429 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5539162502047907
# 2025-06-13 01:47:35.866 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.352874088476317
# 2025-06-13 01:47:36.319 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1981621822984587
# 2025-06-13 01:47:36.509 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1981621822984587
# 2025-06-13 01:47:36.684 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1981621822984587
# 2025-06-13 01:47:36.869 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1981621822984587
# 2025-06-13 01:47:37.002 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.54850697517395
# 2025-06-13 01:47:37.089 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1981621822984587
# 2025-06-13 01:47:40.798 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1892512447434642
# 2025-06-13 01:47:43.462 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1856011734639913
# 2025-06-13 01:47:46.079 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1839894291658422
# 2025-06-13 01:47:48.753 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1832375005259597
# 2025-06-13 01:47:51.387 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.3844633102417
# 2025-06-13 01:47:53.533 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:53.553 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:53.565 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_008.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:47:53.565 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #9
# 2025-06-13 01:47:53.956 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.889174352611492
# 2025-06-13 01:47:54.389 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.557608142692422
# 2025-06-13 01:47:54.836 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.2496185579654746
# 2025-06-13 01:47:55.255 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1377934400743737
# 2025-06-13 01:47:55.689 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0763976471510666
# 2025-06-13 01:47:56.146 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0387139831945915
# 2025-06-13 01:47:56.579 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9848059911003437
# 2025-06-13 01:47:57.022 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.881412323722402
# 2025-06-13 01:47:57.468 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.735229241220308
# 2025-06-13 01:47:57.899 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5429153763767942
# 2025-06-13 01:47:58.356 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3239510549863924
# 2025-06-13 01:47:58.809 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.1855215692652168
# 2025-06-13 01:47:59.109 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.1855215692652168
# 2025-06-13 01:47:59.399 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.1855215692652168
# 2025-06-13 01:47:59.699 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.1855215692652168
# 2025-06-13 01:47:59.946 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.064810752868652
# 2025-06-13 01:48:00.013 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.1855215692652168
# 2025-06-13 01:48:03.867 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.1783050040835619
# 2025-06-13 01:48:06.560 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.1752316000202305
# 2025-06-13 01:48:09.170 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.1738375904269345
# 2025-06-13 01:48:11.879 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.1731771553416532
# 2025-06-13 01:48:14.559 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.612759590148926
# 2025-06-13 01:48:17.013 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:48:17.030 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:48:17.060 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_009.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:48:17.063 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #10
# 2025-06-13 01:48:17.424 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.888094560569466
# 2025-06-13 01:48:17.863 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.720492219803465
# 2025-06-13 01:48:18.304 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.288691608745402
# 2025-06-13 01:48:18.750 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1341300913786725
# 2025-06-13 01:48:19.185 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0796693590550723
# 2025-06-13 01:48:19.630 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.038783298941688
# 2025-06-13 01:48:20.072 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9967826774329758
# 2025-06-13 01:48:20.496 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8884378781318303
# ...
# 2025-06-13 01:52:07.597 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.213591231429259
# 2025-06-13 01:52:08.030 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.213591231429259
# 2025-06-13 01:52:08.385 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.85072922706604
# 2025-06-13 01:52:08.490 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.213591231429259
# 2025-06-13 01:52:12.285 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2055229511087904
# 2025-06-13 01:52:14.957 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2022819075261415
# 2025-06-13 01:52:17.526 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2008610075336743
# 2025-06-13 01:52:20.168 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2002018897828575
# 2025-06-13 01:52:22.851 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.459697246551514
# 2025-06-13 01:52:24.953 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:52:24.961 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:52:24.980 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_021.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:52:24.980 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #22
# 2025-06-13 01:52:25.451 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.3750477587931136
# 2025-06-13 01:52:25.916 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3061851878772117
# 2025-06-13 01:52:26.368 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.186352045790137
# 2025-06-13 01:52:26.855 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.099591757256798
# 2025-06-13 01:52:27.322 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0419971537201516
# 2025-06-13 01:52:27.795 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.010398413168305
# 2025-06-13 01:52:28.252 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9531953477075263
# 2025-06-13 01:52:28.718 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8373187955099872
# 2025-06-13 01:52:29.187 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6800285033898559
# 2025-06-13 01:52:29.635 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5026786959245664
# 2025-06-13 01:52:30.105 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3455146017394837
# 2025-06-13 01:52:30.573 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2308831509617062
# 2025-06-13 01:52:31.018 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2308831509617062
# 2025-06-13 01:52:31.452 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2308831509617062
# 2025-06-13 01:52:31.878 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2308831509617062
# 2025-06-13 01:52:32.248 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.870530843734741
# 2025-06-13 01:52:32.349 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2308831509617062
# 2025-06-13 01:52:36.122 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2233014793837422
# 2025-06-13 01:52:38.744 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2202429856571908
# 2025-06-13 01:52:41.385 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2189035743786873
# 2025-06-13 01:52:44.019 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2182807298292861
# 2025-06-13 01:52:46.695 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.446754217147827
# 2025-06-13 01:52:48.952 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:52:48.964 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:52:48.981 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_022.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:52:48.983 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #23
# 2025-06-13 01:52:49.497 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4002248219453426
# 2025-06-13 01:52:49.962 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.314765449496682
# 2025-06-13 01:52:50.409 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.20443180933658
# 2025-06-13 01:52:50.894 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.1075357731160898
# 2025-06-13 01:52:51.394 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0543898688906963
# 2025-06-13 01:52:51.835 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0135577748926283
# 2025-06-13 01:52:52.298 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.968776078481295
# 2025-06-13 01:52:52.773 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8660408405590718
# 2025-06-13 01:52:53.247 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7134373378658072
# 2025-06-13 01:52:53.702 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5271728818380457
# 2025-06-13 01:52:54.178 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.359900862850562
# 2025-06-13 01:52:54.643 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2378487426126048
# 2025-06-13 01:52:55.085 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2378487426126048
# 2025-06-13 01:52:55.508 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2378487426126048
# 2025-06-13 01:52:55.945 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2378487426126048
# 2025-06-13 01:52:56.307 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.88810396194458
# 2025-06-13 01:52:56.401 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2378487426126048
# 2025-06-13 01:53:00.075 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2308751026161926
# 2025-06-13 01:53:02.792 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2281257564577701
# 2025-06-13 01:53:05.425 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2269415141765867
# 2025-06-13 01:53:08.041 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.734002828598022
# 2025-06-13 01:53:10.259 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:53:10.279 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:53:10.298 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_023.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:53:10.298 | INFO     | bivme.fitting.perform_fit:perform_fitting:224 - Processing frame #24
# 2025-06-13 01:53:10.799 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.439655040347658
# 2025-06-13 01:53:11.242 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.3566116423904093
# 2025-06-13 01:53:11.719 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.225279458962064
# 2025-06-13 01:53:12.203 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.126652208459532
# 2025-06-13 01:53:12.672 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0695840227714744
# 2025-06-13 01:53:13.160 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.023998765201255
# 2025-06-13 01:53:13.653 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9765667841738461
# 2025-06-13 01:53:14.139 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8751749584942887
# 2025-06-13 01:53:14.627 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7117089623584612
# 2025-06-13 01:53:15.103 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5320177613293608
# 2025-06-13 01:53:15.569 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3663724908072856
# 2025-06-13 01:53:16.053 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2519748945946683
# 2025-06-13 01:53:16.196 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2519748945946683
# 2025-06-13 01:53:16.333 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2519748945946683
# 2025-06-13 01:53:16.457 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2519748945946683
# 2025-06-13 01:53:16.519 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.799282073974609
# 2025-06-13 01:53:16.616 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2519748945946683
# 2025-06-13 01:53:20.376 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2440297332561128
# 2025-06-13 01:53:23.070 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2408010796937745
# 2025-06-13 01:53:25.646 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.239378891119922
# 2025-06-13 01:53:28.296 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2387164228845216
# 2025-06-13 01:53:30.963 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.440205812454224
# 2025-06-13 01:53:33.186 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_LV_ENDOCARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:53:33.203 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_EPICARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# 2025-06-13 01:53:33.226 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:404 - patient1_RV_ENDOCARDIAL_024.vtk successfully saved to ..\output\patient1\vtk
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-06-13 01:53:33.252 | INFO     | main:run_fitting:38 - Average residuals: 1.214808729579821 for case patient1

# %% [markdown]
# ## (Optional) Analysis and/or visualisation of models
# You can visualise the fitted models frame-by-frame in your browser by opening an html in `output_directory\case\html`. Alternatively, if you have a mesh visualisation software, you can load in the .vtk or .obj files you generated to view the meshes beating through time. I recommend Paraview, as it is open source, and has nice camera controls for creating  videos of the meshes beating through time.
#
# We haven't added any analysis tools to this notebook yet. Refer to the main README on how to generate metrics from the biv-me models.
