# %% [markdown]
# # Interactive version of biv-me
# This jupyter notebook contains an identical implementation of biv-me to the main.py. The only difference is that it can be run step-by-step, allowing you to make manual corrections if and when needed to both the view selection and segmentation steps, which can be prone to occasional errors.
#
# The only thing you will need on top of the regular biv-me environment is to download a Python IDE which can run Jupyter notebooks (e.g. Visual Studio Code), and install the ipython kernel as below.
#
# ```
# conda install -n bivme311 ipykernel --update-deps --force-reinstall
# ```
#
# When you run the notebook, you will be prompted to select the kernel to use. Make sure to select your bivme311 environment.
#
# ### Troubleshooting model performance
# Though we are confident in the robustness of our deep learning models, they may not work perfectly for your data. If you find that the segmentation or view selection models perform poorly for your data, reach out to us at [joshua.dillon@auckland.ac.nz](joshua.dillon@auckland.ac.nz) or [charlene.1.mauger@kcl.ac.uk](charlene.1.mauger@kcl.ac.uk) and let us know what kind of data you are using. We are actively developing these models and always looking for ways to enhance their generalisability across vendors, protocols, centres, and patient demographics.

# %%
# Import libraries
import os,sys
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import tomli
from pathlib import Path
import shutil
import time
import datetime
from loguru import logger

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import os,sys
#       3 os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# ----> 5 import torch
#       6 import tomli
#       7 from pathlib import Path
#
# File c:\Users\jdil469\.conda\envs\bivme311-clean\Lib\site-packages\torch\__init__.py:2169
#    2153 ################################################################################
#    2154 # Import most common subpackages
#    2155 ################################################################################
#    (...)   2160
#    2161 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2162 from torch.autograd import (  # usort: skip
#    2163     enable_grad as enable_grad,
#    2164     inference_mode as inference_mode,
#    2165     no_grad as no_grad,
#    2166     set_grad_enabled as set_grad_enabled,
#    2167 )
# -> 2169 from torch import (
#    2170     __config__ as __config__,
#    2171     __future__ as __future__,
#    2172     _awaits as _awaits,
#    2173     accelerator as accelerator,
#    2174     autograd as autograd,
#    2175     backends as backends,
#    2176     cpu as cpu,
#    2177     cuda as cuda,
#    2178     distributed as distributed,
#    2179     distributions as distributions,
#    2180     fft as fft,
#    2181     futures as futures,
#    2182     hub as hub,
#    2183     jit as jit,
#    2184     linalg as linalg,
#    2185     mps as mps,
#    2186     mtia as mtia,
#    2187     multiprocessing as multiprocessing,
#    2188     nested as nested,
#    2189     nn as nn,
#    2190     optim as optim,
#    2191     overrides as overrides,
#    2192     profiler as profiler,
#    2193     sparse as sparse,
#    2194     special as special,
#    2195     testing as testing,
#    2196     types as types,
#    2197     utils as utils,
#    2198     xpu as xpu,
#    2199 )
#    2200 from torch.signal import windows as windows
#    2203 # Quantized, sparse, AO, etc. should be last to get imported, as nothing
#    2204 # is expected to depend on them.
#
# File c:\Users\jdil469\.conda\envs\bivme311-clean\Lib\site-packages\torch\hub.py:64
#      60         sys.stderr.write("\n")
#      63 try:
# ---> 64     from tqdm import tqdm  # If tqdm is installed use it, otherwise use the fake wrapper
#      65 except ImportError:
#      66     tqdm = _Faketqdm
#
# File c:\Users\jdil469\.conda\envs\bivme311-clean\Lib\site-packages\tqdm\__init__.py:1
# ----> 1 from ._monitor import TMonitor, TqdmSynchronisationWarning
#       2 from ._tqdm_pandas import tqdm_pandas
#       3 from .cli import main  # TODO: remove in v5.0.0
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1138, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1078, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1507, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1479, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1648, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:161, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:153, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
# This allows for modules to be reloaded automatically if you make any changes to those files.
# %load_ext autoreload
# %autoreload 2

# %%
# Import modules
from bivme.preprocessing.dicom.extract_cines import extract_cines
from bivme.preprocessing.dicom.select_views import select_views
from bivme.preprocessing.dicom.segment_views import segment_views
from bivme.preprocessing.dicom.correct_phase_mismatch import correct_phase_mismatch
from bivme.preprocessing.dicom.generate_contours import generate_contours
from bivme.preprocessing.dicom.export_guidepoints import export_guidepoints
from bivme.plotting.plot_guidepoints import generate_html 
from main import run_fitting

# %%
# Set up logging
log_level = "DEBUG"
log_format = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS zz}</green> | <level>{level: <8}</level> | <yellow>Line {line: >4} ({file}):</yellow> <b>{message}</b>"

# %%
# Check if GPU is available (torch)
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
    logger.warning('No GPU available. Using CPU instead. This may be very slow!')
    
logger.info(f"Using device: {device}")
# Out:
# 2025-08-27 15:33:07.951 | INFO     | __main__:<module>:10 - Using device: cuda

# %% [markdown]
# # Config file
# As with the main.py, you should customise the template config file in `src/bivme/configs/config.toml` for your specific batch and use case. This config file will be read in and the inputs used for the remainder of this pipeline.

# %%
config_file = 'configs/config.toml' # Path to the config file

# %%
# Load config
with open(config_file, mode="rb") as fp:
    logger.info(f'Loading config file: {config_file}')
    config = tomli.load(fp)

# TOML Schema Validation
# This needs to be done to make sure the config file is valid.
# Going forward, we will trust you that all of the inputs in the config file are correct, unlike the main.py which does not trust you.

match config:
    case {
        "modules": {"preprocessing": bool(), "fitting": bool()},

        "logging": {"show_detailed_logging": bool(), "generate_log_file": bool()},

        "plotting": {"generate_plots_preprocessing": bool(), "generate_plots_fitting": bool(), "include_images": bool()},

        "input_pp": {"source": str(),
                    "batch_ID": str(),
                    "analyst_id": str(),
                    "processing": str(),
                    "states": str()
                    },
        "view-selection": {"option": str(), "correct_mode": str()},
        "contouring": {"smooth_landmarks": bool()},
        "output_pp": {"overwrite": bool(), "output_directory": str()},

        "input_fitting": {"gp_directory": str(),
                    "gp_suffix": str(),
                    "si_suffix": str(),
                    },
        "breathhold_correction": {"shifting": str(), "ed_frame": int()},
        "gp_processing": {"sampling": int(), "num_of_phantom_points_av": int(), "num_of_phantom_points_mv": int(), "num_of_phantom_points_tv": int(), "num_of_phantom_points_pv": int()},
        "multiprocessing": {"workers": int()},
        "fitting_weights": {"guide_points": float(), "convex_problem": float(), "transmural": float()},
        "output_fitting": {"output_directory": str(), "output_meshes": list(), "closed_mesh": bool(),   "export_control_mesh": bool(), "mesh_format": str(),  "overwrite": bool()},
    }:
        pass
    case _:
            raise ValueError(f"Invalid configuration: {config}")
# Out:
# 2025-08-27 15:33:08.339 | INFO     | __main__:<module>:3 - Loading config file: configs/boris-config.toml

# %% [markdown]
# ## Start of preprocessing
# This code reads in DICOM files and generates GPFiles for personalised biventricular mesh fitting.

# %% [markdown]
# ## Step 0: Set up directories
# All directories will be created for you except for the input_path. This should point to your DICOMs, separated into folders by case like so:
#
#     input_path
#     └─── case1
#         │─── *
#     └─── case2
#         │─── *
#     └─── ...
#
# Don't worry about preprocessing your dicoms, separating by scan type, or excluding non-cines. The pipeline should find which ones are cines and which ones aren't by checking key terms within the series descriptions. Check src/bivme/preprocessing/dicom/extract_cines.py for the list of key terms.

# %%
batch_ID = config['input_pp']['batch_ID'] # This will serve as your output folder name. Example: 'test'
analyst_id = config['input_pp']['analyst_id'] # Example: 'analyst1'
input_path = config['input_pp']['source'] # Path to the input DICOM folder
processed_path = config['input_pp']['processing'] # Path to the processed folder, where view predictions and segmentations will be stored. This will be created upon run time.
states_path = config['input_pp']['states'] # Path to the states folder, where the logs and view predictions will be stored for reference. This will be created upon run time.
output_path = config['output_pp']['output_directory'] # Path to the output folder, where GP files will be stored. This will be created upon run time.
plotting_path = processed_path # Path to the plotting folder, where the HTML file of plotted guidepoints will be stored. This will be created upon run time.

# Target path: src/bivme/preprocessing/dicom/models
# You can hardcode the model path here or set it as an environment variable.
cwd = os.getcwd()
print('Current working directory:', cwd)
MODEL_DIR = os.path.join(cwd,'preprocessing/dicom/models')
print('Model directory:', MODEL_DIR)
# Out:
# Current working directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme
# Model directory: c:\Users\jdil469\Code\biv-me-dev\src\bivme\preprocessing/dicom/models

# %% [markdown]
# ## Step 0.1: Choose case

# %%
case = 'patient1' # Enter the case ID. This should be a subfolder within the input_path.

# %%
# Set up batch specific folders
src = os.path.join(input_path)
dst = os.path.join(processed_path, batch_ID)
states = os.path.join(states_path, batch_ID)
output = os.path.join(output_path, batch_ID)
plotting = os.path.join(plotting_path, batch_ID)


case_src = os.path.join(src, case)
if not os.path.isdir(case_src):
    logger.error(f'Case {case} not found in source folder. Please check the case ID.')
    sys.exit()

os.makedirs(dst, exist_ok=True)
os.makedirs(states, exist_ok=True)
os.makedirs(output, exist_ok=True)
os.makedirs(plotting, exist_ok=True)

case_dst = os.path.join(dst, case)
case_output = os.path.join(output, case)

if os.path.exists(case_output):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
        shutil.rmtree(case_output)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

elif os.path.exists(case_dst):
    overwrite = config['output_pp']['overwrite']
    if overwrite:
        shutil.rmtree(case_dst)
    else:
        print(f'This case has already been processed and you have set overwrite to false in the config file. Change the case ID or delete the existing folder {case_dst} before proceeding.')
        sys.exit()

# %%
# Create log file to record some details
states = os.path.join(states, case, analyst_id)
os.makedirs(states, exist_ok=True)

logger_id = logger.add(f'{states}/log_file_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.log', level=log_level, format=log_format,
    colorize=False, backtrace=True,
    diagnose=True)

logger.info(f'Processing case: {case}')

start_time = time.time()
# Out:
# 2025-08-27 15:33:09.331 | INFO     | __main__:<module>:9 - Processing case: cardiohance_073

# %% [markdown]
# ## Step 0.2: Pre-preprocess dicoms
# By default, the pipeline takes in only cardiac cine images in .dcm format. The pre-preprocessing reads in the raw dicoms and uses the series descriptions to infer which are cines and which aren't. The 'cine only' dicoms are saved to:
#
#     processed_path
#     └───batch_ID
#         └───processed-dicoms

# %%
logger.info(f'Finding cines...')
extract_cines(case_src, case_dst, logger)

case_src = os.path.join(case_dst, 'processed-dicoms') # Update source directory

logger.success(f'Pre-preprocessing complete. Cines extracted to {case_src}.')
# Out:
# 2025-08-27 15:33:09.477 | INFO     | __main__:<module>:1 - Finding cines...
# 2025-08-27 15:33:22.634 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:45 - Found 645 images in the source directory
# 2025-08-27 15:33:22.636 | INFO     | bivme.preprocessing.dicom.extract_cines:extract_cines:46 - Extracted 391 which matched the inclusion criteria.
# 2025-08-27 15:33:24.794 | SUCCESS  | __main__:<module>:6 - Pre-preprocessing complete. Cines extracted to C:\Users\jdil469\bivme-data\fitting\processed\boris-cim-v2\cardiohance_073\processed-dicoms.

# %% [markdown]
# ## Step 1: View selection
# View selection can be carried out in three main ways.
#
# The first option is the **'default'** option. This involves the use of two models - one using only dicom metadata and one using only image data. The metadata predictions are only broad categories (SAX, LAX, or Outflow) and are used to correct image-based predictions. This should be the most robust option, but takes longer to complete.
#
# The second option is the **'image-only'** option. This only uses image data. Use this if the metadata step is adding unnecessary time, or is not performing as expected.
#
# The third option is the **'load'** option. This loads view predictions from the states folder. This is useful if view predictions have already been made, avoiding the need to rerun prediction from scratch. It also allows for you to make and save manual corrections to the selected views.
#
# On top of these options, you can also manually review and correct the selected views using a simple GUI. There are three options - **'manual'**, which always launches the GUI after view selection, **'adaptive'**, which only launches the GUI if there are low confidence predictions or missing views, or **'automatic'**, which does not launch the GUI and keeps the automatic predictions as they are.
#
# #### Important note about required views
# To proceed with fitting, you must have at least some SAX images and a 4ch image. This is because the fitting requires landmarks from the 4ch image to initialise the model (mitral valve, tricuspid valve, and apex point). The SAX images are required, along with at least one long axis image e.g. 4ch, to correct for breath-hold misalignment. Using the GUI on **'adaptive'** mode will make sure that you never miss a required view.

# %%
option = 'default' # Either 'default', 'image-only', or 'load'. 
# 'default' will combine dicom metadata and image data to select the correct view. 'image-only' will only use the image data. 
# 'load' will load view predictions from the states folder, if view predictions have already been made.

correct_mode = 'manual' # Either 'manual', 'adaptive', or 'automatic'. 
# 'manual' will launch a GUI after completing view predictions to allow you to correct any mispredictions. 
# 'adaptive' will only launch a GUI if there are any poor predictions or missing views
# 'automatic' will not launch the GUI and will use the predictions as they are.

slice_info_df, num_phases, slice_mapping = select_views(case, case_src, case_dst, MODEL_DIR, states, option, correct_mode, logger)

logger.success(f'View selection complete.')
logger.info(f'Number of phases: {num_phases}')
# Out:
# 2025-08-27 15:33:25.059 | INFO     | bivme.preprocessing.dicom.select_views:select_views:340 - Loading view predictions from states folder...
# 2025-08-27 15:33:33.233 | INFO     | bivme.preprocessing.dicom.src.viewselection:sort_dicom_per_series:227 - Series 26 contains 1 merged series. Splitting...
# 2025-08-27 15:33:33.234 | INFO     | bivme.preprocessing.dicom.src.viewselection:sort_dicom_per_series:228 - New 'synthetic' series will range from: 30 to 30
# 2025-08-27 15:33:41.788 | SUCCESS  | bivme.preprocessing.dicom.select_views:select_views:365 - View predictions for cardiohance_073:
# 2025-08-27 15:33:41.790 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - SAX-atria: 2 series
# 2025-08-27 15:33:41.791 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - SAX: 6 series
# 2025-08-27 15:33:41.793 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - 4ch: 1 series
# 2025-08-27 15:33:41.795 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - 2ch: 1 series
# 2025-08-27 15:33:41.796 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - LVOT: 1 series
# 2025-08-27 15:33:41.799 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - 3ch: 1 series
# 2025-08-27 15:33:41.800 | INFO     | bivme.preprocessing.dicom.select_views:select_views:367 - Excluded: 1 series
# 2025-08-27 15:33:41.815 | SUCCESS  | __main__:<module>:12 - View selection complete.
# 2025-08-27 15:33:41.817 | INFO     | __main__:<module>:13 - Number of phases: 30

# %% [markdown]
# ## Step 2: Segmentation
# Using the view classifications from step 1, images will be written into nifti form and sent to the segmentation models to be automatically segmented. There is one segmentation model specific to each view (currently SAX, 2ch, 3ch, 4ch, or RVOT), so only images belonging to those classes will be used from now on.

# %%
## Segmentation
seg_start_time = time.time()
segment_views(case_dst, MODEL_DIR, slice_info_df, logger) # Segmentation occurs on 2D+t (3D) images using 3D nnU-Net models
seg_end_time = time.time()

logger.success(f'Segmentation complete. Time taken: {seg_end_time-seg_start_time} seconds.')

# %% [markdown]
# ## Step 2.1: Correct for mismatching phases (conditional)
# Often, LAX and SAX series do not have matching number of phases. In that case, we need to resample segmentations to have the same number of phases. We use the SAX series as the reference for the 'right' number of phases.

# %%
## Resample segmentations if phases are not consistent between SAX and LAX views
correct_phase_mismatch(case_dst, slice_info_df, num_phases, logger)

# %% [markdown]
# ## Step 2.2: Review segmentations (optional)
# Images and segmentations are stored here in nifti format (.nii.gz).
#
#     processed_path
#     └───batch_ID
#         └───case
#
#
# If needed, segmentations can be corrected here, and subsequent code executions will incorporate those changes. 3D Slicer or ITKSnap are good tools for correcting segmentations. We are working on a way to automatically load the images and segmentations into Slicer via a Python backend to make this review process easier.

# %% [markdown]
# ## Step 3: Generate contours
# Contours are generated from the perimeters of the segmentation labels, and other key landmarks (mitral valve, tricuspid valve, aortic valve, pulmonary valve, rv inserts, and LV apex) are estimated from intersections of contours. 2D contours are transformed into 3D cartesian space using the affine constructed from the image position, orientation, and pixel spacing metadata in the DICOMs.

# %%
slice_dict = generate_contours(case_dst, slice_info_df, num_phases, logger)
logger.success(f'Guide points generated successfully.')

# %% [markdown]
# ## Step 4: Export guidepoints
# Contours are then exported into a standardised form, called a GPFile. There is one of these files per frame. This is what the model fitting part of the code requires. There is also a SliceInfoFile which contains the affine information for each slice, which is necessary to allow for breath hold correction prior to model fitting.
#
# Temporal smoothing of landmark points is enabled by default, but can be disabled by changing the boolean below.

# %%
smooth_landmarks = True # Set to True to smooth the landmarks, False to keep them as they are
gp_dir = os.path.join(output, case)

export_guidepoints(case_dst, gp_dir, slice_dict, slice_mapping, smooth_landmarks)
logger.success(f'Guide points exported successfully.')
logger.success(f'Case {case} complete.')
logger.info(f'Total time taken: {time.time()-start_time} seconds.')
# Out:
# 2025-08-27 16:43:02.973 | SUCCESS  | __main__:<module>:5 - Guide points exported successfully.
# 2025-08-27 16:43:02.975 | SUCCESS  | __main__:<module>:6 - Case cardiohance_073 complete.
# 2025-08-27 16:43:02.976 | INFO     | __main__:<module>:7 - Total time taken: 4193.643523693085 seconds.

# %% [markdown]
# ## Step 5 (Optional): Plot guidepoints
# The code below will plot the guidepoints at each frame as html files, which can be viewed at:
#
#     plotting_path
#     └───batch_ID
#         └───case
#             └───html
#
# Here's a good place to find any issues before proceeding to model fitting.

# %%
generate_plots_preprocessing = False # Set to True to generate plots for preprocessing, False to skip plotting
include_images = True # Set to True to include images in the HTML file, False to exclude them. Setting to False will speed up the plotting process, as images take a long time to plot and take up a lot of space in the HTML file.

if generate_plots_preprocessing:
    if include_images:
        image_path = os.path.join(case_dst, 'images')
    else:
        image_path = None

    generate_html(gp_dir, out_dir=plotting, gp_suffix='', si_suffix='', frames_to_fit=[], my_logger=logger, model_path=None, image_path=image_path)

    logger.info(f'Guidepoints plotted at {os.path.join(plotting,case,"html")}.')

# %% [markdown]
# # Start of model fitting

# %% [markdown]
# # Step 6: Model fitting
# The model fitting takes in the GPFiles and SliceInfoFiles generated during preprocessing to generate biventricular meshes at each frame. An iterative linear least squares fit is applied, as described in Mauger, C., Gilbert, K., Suinesiaputra, A., Pontre, B., Omens, J., McCulloch, A., & Young, A. (2018, July). An iterative diffeomorphic algorithm for registration of subdivision surfaces: application to congenital heart disease. In 2018 40th Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC) (pp. 596-599). IEEE. DOI: 10.1109/EMBC.2018.8512394.
#
# Breath hold misalignment is corrected by the intersection of short and long axis contours.
#
# Meshes are generated in the output directory you provided in the config file. Mesh vertices are exported in .txt format by default, but can also be exported with faces in .vtk and .obj formats as well for visualisation and postprocessing purposes.
#
# Unfortunately, there is no opportunity for intervention during this step.

# %%
# Set input for fitting equal to the output of preprocessing
config["input_fitting"]["gp_directory"] = output

# Save a copy of the config file to the output folder
output_folder = Path(config["output_fitting"]["output_directory"])
output_folder.mkdir(parents=True, exist_ok=True)
shutil.copy(config_file, output_folder)

# Force overwrite to true
config["output_fitting"]["overwrite"] = True

# Set whether to generate plots for fitting
config["plotting"]["generate_plots_fitting"] = True
config["plotting"]["include_images"] = True # Set to True to include images in the HTML plots, False to exclude them. Setting to False will speed up the plotting process, as images take a long time to plot and take up a lot of space in the HTML file.

# %%
# Where Charlène's magic happens
run_fitting(case, config, logger)
# Out:
# 2025-08-27 16:43:03.666 | INFO     | main:run_fitting:26 - Processing cardiohance_073
# 2025-08-27 16:43:03.669 | INFO     | bivme.fitting.perform_fit:perform_fitting:80 - case: cardiohance_073
# 2025-08-27 16:43:03.671 | INFO     | bivme.fitting.perform_fit:perform_fitting:88 - ED set to frame #0
# 2025-08-27 16:43:03.673 | INFO     | bivme.fitting.perform_fit:perform_fitting:105 - Shift measured only at ED frame
# 2025-08-27 16:43:06.031 | INFO     | bivme.fitting.perform_fit:perform_fitting:204 - Calculating pose and scale cardiohance_073...
# 2025-08-27 16:43:06.288 | INFO     | bivme.fitting.perform_fit:perform_fitting:209 - Fitting of cardiohance_073
# 2025-08-27 16:43:06.293 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #0
# 2025-08-27 16:43:06.860 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.100290967122534
# 2025-08-27 16:43:07.415 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 1.9701079617869182
# 2025-08-27 16:43:07.998 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.927527158375695
# 2025-08-27 16:43:08.584 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.9103090264215448
# 2025-08-27 16:43:09.185 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.90780446758756
# 2025-08-27 16:43:09.695 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9016155440042084
# 2025-08-27 16:43:10.166 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8752961684298861
# 2025-08-27 16:43:10.637 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8109844970490756
# 2025-08-27 16:43:11.113 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.710206300818682
# 2025-08-27 16:43:11.591 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5597238216386382
# 2025-08-27 16:43:12.046 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3914424103036294
# 2025-08-27 16:43:12.444 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3914424103036294
# 2025-08-27 16:43:12.935 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2934767510083256
# 2025-08-27 16:43:13.328 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2934767510083256
# 2025-08-27 16:43:13.688 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2934767510083256
# 2025-08-27 16:43:14.021 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 7.240212917327881
# 2025-08-27 16:43:14.108 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2934767510083256
# 2025-08-27 16:43:17.672 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2829799127747112
# 2025-08-27 16:43:20.027 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2784125957393522
# 2025-08-27 16:43:22.547 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2763086882921506
# 2025-08-27 16:43:24.729 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2753023352546
# 2025-08-27 16:43:26.861 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.838218688964844
# 2025-08-27 16:43:33.693 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_000.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:43:33.705 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_000.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:43:33.716 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_000.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:43:33.721 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #1
# 2025-08-27 16:43:34.214 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.0628587721561296
# 2025-08-27 16:43:34.734 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 1.9790711789066189
# 2025-08-27 16:43:35.284 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.910036109249526
# 2025-08-27 16:43:35.840 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.8949325528722663
# 2025-08-27 16:43:36.409 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.893114771680166
# 2025-08-27 16:43:36.909 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.8824278775590249
# 2025-08-27 16:43:37.416 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.863643459867728
# 2025-08-27 16:43:37.909 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.7988237608700988
# 2025-08-27 16:43:38.396 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.691559648782907
# 2025-08-27 16:43:38.909 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5495081622199418
# 2025-08-27 16:43:39.461 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3992902298058534
# 2025-08-27 16:43:40.009 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.274703161080515
# 2025-08-27 16:43:40.142 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.274703161080515
# 2025-08-27 16:43:40.525 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.274703161080515
# 2025-08-27 16:43:40.898 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.274703161080515
# 2025-08-27 16:43:40.943 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.798841238021851
# 2025-08-27 16:43:41.030 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.274703161080515
# 2025-08-27 16:43:45.057 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2672258496510536
# 2025-08-27 16:43:47.555 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2641855418482897
# 2025-08-27 16:43:49.801 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2628534851839595
# 2025-08-27 16:43:52.323 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 11.377237796783447
# 2025-08-27 16:43:57.595 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_001.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:43:57.610 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_001.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:43:57.624 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_001.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:43:57.628 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #2
# 2025-08-27 16:43:58.104 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.0418968589151674
# 2025-08-27 16:43:58.603 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.478674549853869
# 2025-08-27 16:43:59.086 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.117634335862406
# 2025-08-27 16:43:59.605 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.9562346502723305
# 2025-08-27 16:44:00.073 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9154981206796082
# 2025-08-27 16:44:00.575 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.8969730740379644
# 2025-08-27 16:44:01.100 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8681284017869235
# 2025-08-27 16:44:01.654 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.799008368998121
# 2025-08-27 16:44:02.209 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6909349461935956
# 2025-08-27 16:44:02.671 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5663255609870959
# 2025-08-27 16:44:03.142 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.4024822244586364
# 2025-08-27 16:44:03.620 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.272794429705145
# 2025-08-27 16:44:03.746 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.272794429705145
# 2025-08-27 16:44:03.868 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.272794429705145
# 2025-08-27 16:44:03.994 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.272794429705145
# 2025-08-27 16:44:04.038 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.013829946517944
# 2025-08-27 16:44:04.124 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.272794429705145
# 2025-08-27 16:44:07.054 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2652186005136452
# 2025-08-27 16:44:09.185 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2620105061578037
# 2025-08-27 16:44:11.648 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.260559054703897
# 2025-08-27 16:44:14.118 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2598717503182397
# 2025-08-27 16:44:16.366 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.327112197875977
# 2025-08-27 16:44:22.142 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_002.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:44:22.152 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_002.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:44:22.162 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_002.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:44:22.167 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #3
# 2025-08-27 16:44:22.643 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.034791107865508
# 2025-08-27 16:44:23.146 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.0239999161165376
# 2025-08-27 16:44:23.747 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.9145672167628456
# 2025-08-27 16:44:24.303 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.8886363292092903
# 2025-08-27 16:44:24.787 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.8860309321134774
# 2025-08-27 16:44:25.255 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.880870296275891
# 2025-08-27 16:44:25.748 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8575935410686233
# 2025-08-27 16:44:26.226 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.7872658849721208
# 2025-08-27 16:44:26.719 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6868091090197488
# 2025-08-27 16:44:27.180 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5559198937319398
# 2025-08-27 16:44:27.639 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3893787255820598
# 2025-08-27 16:44:28.098 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.271662779712258
# 2025-08-27 16:44:28.211 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.271662779712258
# 2025-08-27 16:44:28.328 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.271662779712258
# 2025-08-27 16:44:28.449 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.271662779712258
# 2025-08-27 16:44:28.490 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.920111417770386
# 2025-08-27 16:44:28.567 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.271662779712258
# 2025-08-27 16:44:31.676 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2640805266579123
# 2025-08-27 16:44:33.973 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2609787063663758
# 2025-08-27 16:44:36.461 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2596035322964347
# 2025-08-27 16:44:38.645 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.258960079096619
# 2025-08-27 16:44:40.945 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.451737642288208
# 2025-08-27 16:44:46.885 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_003.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:44:46.897 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_003.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:44:46.912 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_003.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:44:46.915 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #4
# 2025-08-27 16:44:47.466 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.046475737724468
# 2025-08-27 16:44:48.004 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 1.9956794987747604
# 2025-08-27 16:44:48.473 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.912384538017931
# 2025-08-27 16:44:48.970 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.891534355946808
# 2025-08-27 16:44:49.486 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.8800348038853585
# 2025-08-27 16:44:50.011 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.8696479078435575
# 2025-08-27 16:44:50.478 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8425987652143812
# 2025-08-27 16:44:50.962 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.783962458545131
# 2025-08-27 16:44:51.451 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6741378978990067
# 2025-08-27 16:44:51.910 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5506778477949026
# 2025-08-27 16:44:52.400 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3890988866984875
# 2025-08-27 16:44:52.905 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2638899473089085
# 2025-08-27 16:44:53.022 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2638899473089085
# 2025-08-27 16:44:53.150 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2638899473089085
# 2025-08-27 16:44:53.265 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2638899473089085
# 2025-08-27 16:44:53.319 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 5.930485248565674
# 2025-08-27 16:44:53.407 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2638899473089085
# 2025-08-27 16:44:56.464 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2556865648653948
# 2025-08-27 16:44:58.834 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.252229626150732
# 2025-08-27 16:45:01.187 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2506710579011562
# 2025-08-27 16:45:03.420 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2499353883942441
# 2025-08-27 16:45:05.531 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.210326194763184
# 2025-08-27 16:45:11.423 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_004.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:45:11.433 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_004.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:45:11.444 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_004.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:45:11.447 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #5
# 2025-08-27 16:45:11.937 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.11139135437646
# 2025-08-27 16:45:12.471 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.0044616354814955
# 2025-08-27 16:45:12.948 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.9302326025255965
# 2025-08-27 16:45:13.439 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.8961594037355123
# 2025-08-27 16:45:13.895 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.8908349423959905
# 2025-08-27 16:45:14.354 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.886452769358559
# 2025-08-27 16:45:14.825 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8645976349201738
# 2025-08-27 16:45:15.301 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.7996951575535667
# 2025-08-27 16:45:15.813 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7025032431057803
# 2025-08-27 16:45:16.277 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5648989475130806
# 2025-08-27 16:45:16.747 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3955435853034535
# 2025-08-27 16:45:17.125 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3955435853034535
# 2025-08-27 16:45:17.613 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.3066391698529287
# 2025-08-27 16:45:18.017 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.3066391698529287
# 2025-08-27 16:45:18.438 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.3066391698529287
# 2025-08-27 16:45:18.755 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.89082407951355
# 2025-08-27 16:45:18.839 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.3066391698529287
# 2025-08-27 16:45:22.039 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2966495299552971
# 2025-08-27 16:45:24.213 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2923335145735315
# 2025-08-27 16:45:26.528 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2903654460805496
# 2025-08-27 16:45:28.732 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.289428770792586
# 2025-08-27 16:45:31.141 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 12.384700536727905
# 2025-08-27 16:45:37.218 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_005.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:45:37.231 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_005.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:45:37.243 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_005.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:45:37.247 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #6
# 2025-08-27 16:45:37.781 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.2061832501776624
# 2025-08-27 16:45:38.339 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.0484395664827293
# 2025-08-27 16:45:38.860 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.9552404409987316
# 2025-08-27 16:45:39.420 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.9273127326680413
# 2025-08-27 16:45:39.979 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.918543331480525
# 2025-08-27 16:45:40.528 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9091946889715867
# 2025-08-27 16:45:41.053 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8871214612525256
# 2025-08-27 16:45:41.621 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8307374135397538
# 2025-08-27 16:45:42.201 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.7264580952613922
# 2025-08-27 16:45:42.745 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.576149403062521
# 2025-08-27 16:45:43.305 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3971802345898108
# 2025-08-27 16:45:43.876 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2699407012924635
# 2025-08-27 16:45:44.116 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2699407012924635
# 2025-08-27 16:45:44.590 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2699407012924635
# 2025-08-27 16:45:45.046 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2699407012924635
# 2025-08-27 16:45:45.425 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 7.716188907623291
# 2025-08-27 16:45:45.509 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2699407012924635
# 2025-08-27 16:45:48.596 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2630796364032784
# 2025-08-27 16:45:50.822 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2601930071686742
# 2025-08-27 16:45:53.319 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.258889864102857
# 2025-08-27 16:45:55.892 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 10.465667486190796
# 2025-08-27 16:46:02.024 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_006.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:02.042 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_006.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:02.055 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_006.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:02.060 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #7
# 2025-08-27 16:46:02.548 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.310902147422666
# 2025-08-27 16:46:03.074 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.184786493496594
# 2025-08-27 16:46:03.612 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.0413797631686226
# 2025-08-27 16:46:04.163 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.012763896056951
# 2025-08-27 16:46:04.692 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9973946869790293
# 2025-08-27 16:46:05.266 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9897706677387204
# 2025-08-27 16:46:05.868 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9694749553392819
# 2025-08-27 16:46:06.430 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.9109824506326119
# 2025-08-27 16:46:07.018 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.8001156139178982
# 2025-08-27 16:46:07.503 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.638899662141239
# 2025-08-27 16:46:08.011 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.4436006604216733
# 2025-08-27 16:46:08.504 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.3041660760856482
# 2025-08-27 16:46:08.696 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.3041660760856482
# 2025-08-27 16:46:08.974 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.3041660760856482
# 2025-08-27 16:46:09.261 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.3041660760856482
# 2025-08-27 16:46:09.415 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.93648624420166
# 2025-08-27 16:46:09.500 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.3041660760856482
# 2025-08-27 16:46:13.116 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2956118982007914
# 2025-08-27 16:46:15.650 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.292026932514925
# 2025-08-27 16:46:18.337 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2904084515739414
# 2025-08-27 16:46:20.929 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2896432594167895
# 2025-08-27 16:46:23.515 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.096683263778687
# 2025-08-27 16:46:30.221 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_007.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:30.234 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_007.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:30.245 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_007.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:30.249 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #8
# 2025-08-27 16:46:30.730 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.4000150731493046
# 2025-08-27 16:46:31.251 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.1836718296121442
# 2025-08-27 16:46:31.742 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.090152684965481
# 2025-08-27 16:46:32.190 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.036852659237127
# 2025-08-27 16:46:32.667 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0245960391354094
# 2025-08-27 16:46:33.138 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0183883694164084
# 2025-08-27 16:46:33.635 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.9989933749418147
# 2025-08-27 16:46:34.092 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.9486635633257758
# 2025-08-27 16:46:34.562 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.8409743242791272
# 2025-08-27 16:46:35.008 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.6693886649154817
# 2025-08-27 16:46:35.422 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.4422724321856428
# 2025-08-27 16:46:35.905 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2857400412296625
# 2025-08-27 16:46:36.045 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2857400412296625
# 2025-08-27 16:46:36.407 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2857400412296625
# 2025-08-27 16:46:36.938 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 51200.0	 ICF error 1.2187032284363768
# 2025-08-27 16:46:37.267 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 16 Weight 32000.0	 ICF error 1.2187032284363768
# 2025-08-27 16:46:37.426 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.7573277950286865
# 2025-08-27 16:46:37.508 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2187032284363768
# 2025-08-27 16:46:40.826 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.214651967767465
# 2025-08-27 16:46:43.042 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.2129820872220307
# 2025-08-27 16:46:45.672 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.212238052148907
# 2025-08-27 16:46:48.292 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 10.86426043510437
# 2025-08-27 16:46:53.938 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_008.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:53.951 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_008.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:53.962 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_008.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:46:53.967 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #9
# 2025-08-27 16:46:54.387 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.468715631436511
# 2025-08-27 16:46:54.873 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.2209147134460934
# 2025-08-27 16:46:55.329 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 2.1176109248820794
# 2025-08-27 16:46:55.808 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 2.0686900360994462
# 2025-08-27 16:46:56.274 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 2.0589389207303084
# 2025-08-27 16:46:56.752 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 2.0556440458848675
# 2025-08-27 16:46:57.220 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 2.031416332236145
# 2025-08-27 16:46:57.694 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.9776325669522135
# 2025-08-27 16:46:58.141 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.8802146070946928
# 2025-08-27 16:46:58.603 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.6960248202134993
# 2025-08-27 16:46:59.091 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.4495318647776998
# 2025-08-27 16:46:59.555 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2837500521493919
# 2025-08-27 16:46:59.690 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2837500521493919
# 2025-08-27 16:47:00.061 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2837500521493919
# 2025-08-27 16:47:00.412 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2837500521493919
# 2025-08-27 16:47:00.755 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.43023943901062
# 2025-08-27 16:47:00.826 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2837500521493919
# 2025-08-27 16:47:04.672 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2740594206653004
# 2025-08-27 16:47:07.500 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.270001005227162
# 2025-08-27 16:47:10.237 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2681756811398373
# 2025-08-27 16:47:12.879 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2673149485431576
# 2025-08-27 16:47:14.968 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 14.211382150650024
# 2025-08-27 16:47:20.356 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_009.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:47:20.370 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_009.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:47:20.382 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_009.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:47:20.385 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #10
# 2025-08-27 16:47:20.823 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.5283737426414246
# 2025-08-27 16:47:21.321 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.525844533605782
# ...
# 2025-08-27 16:54:28.420 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3748870732068827
# 2025-08-27 16:54:28.869 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2925050220335768
# 2025-08-27 16:54:29.099 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2925050220335768
# 2025-08-27 16:54:29.545 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2925050220335768
# 2025-08-27 16:54:29.664 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 7.099170684814453
# 2025-08-27 16:54:29.745 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2925050220335768
# 2025-08-27 16:54:33.151 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2821723185564495
# 2025-08-27 16:54:35.669 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.277696353211397
# 2025-08-27 16:54:38.307 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2756371814290124
# 2025-08-27 16:54:41.202 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.2746532331890146
# 2025-08-27 16:54:43.557 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 13.89148998260498
# 2025-08-27 16:54:49.700 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_026.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:54:49.717 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_026.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:54:49.732 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_026.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:54:49.736 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #27
# 2025-08-27 16:54:50.325 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.0997918640810216
# 2025-08-27 16:54:50.850 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 1.9806161494334114
# 2025-08-27 16:54:51.391 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.9171741052603095
# 2025-08-27 16:54:51.909 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.8995683089863944
# 2025-08-27 16:54:52.406 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.8931323075608062
# 2025-08-27 16:54:52.903 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.8812344046408753
# 2025-08-27 16:54:53.385 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8577411015125675
# 2025-08-27 16:54:53.870 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.7894104890382194
# 2025-08-27 16:54:54.355 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6812415417452016
# 2025-08-27 16:54:54.858 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5371934700147762
# 2025-08-27 16:54:55.347 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3706723384126358
# 2025-08-27 16:54:55.882 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.2503479193069056
# 2025-08-27 16:54:56.003 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.2503479193069056
# 2025-08-27 16:54:56.130 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.2503479193069056
# 2025-08-27 16:54:56.253 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.2503479193069056
# 2025-08-27 16:54:56.308 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 6.051303148269653
# 2025-08-27 16:54:56.401 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2503479193069056
# 2025-08-27 16:55:00.301 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 3.991790533065796
# 2025-08-27 16:55:07.078 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_027.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:55:07.092 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_027.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:55:07.107 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_027.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:55:07.112 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #28
# 2025-08-27 16:55:07.779 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.119201739557691
# 2025-08-27 16:55:08.493 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 1.9889017411713483
# 2025-08-27 16:55:09.028 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.9359147525731157
# 2025-08-27 16:55:09.548 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.9196695652277371
# 2025-08-27 16:55:10.193 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9103734224686553
# 2025-08-27 16:55:10.942 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.9021517332591134
# 2025-08-27 16:55:11.657 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8762024368369625
# 2025-08-27 16:55:12.317 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8071337637852714
# 2025-08-27 16:55:13.012 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6898136850262868
# 2025-08-27 16:55:13.521 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.5477757849040845
# 2025-08-27 16:55:14.032 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3835088152996
# 2025-08-27 16:55:14.479 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 256000.0	 ICF error 1.3835088152996
# 2025-08-27 16:55:15.040 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 102400.0	 ICF error 1.2859516686750443
# 2025-08-27 16:55:15.418 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 128000.0	 ICF error 1.2859516686750443
# 2025-08-27 16:55:15.828 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 80000.0	 ICF error 1.2859516686750443
# 2025-08-27 16:55:15.869 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 8.177884101867676
# 2025-08-27 16:55:15.962 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.2859516686750443
# 2025-08-27 16:55:19.218 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.2743550833968875
# 2025-08-27 16:55:21.769 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 3 Smoothing weight 1000000.0	 ECF error 1.269398465865321
# 2025-08-27 16:55:24.510 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 4 Smoothing weight 1000000.0	 ECF error 1.2671466524032904
# 2025-08-27 16:55:27.252 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 5 Smoothing weight 1000000.0	 ECF error 1.266080001527926
# 2025-08-27 16:55:29.791 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 13.920072078704834
# 2025-08-27 16:55:39.094 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_028.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:55:39.124 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_028.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:55:39.153 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_028.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:55:39.161 | INFO     | bivme.fitting.perform_fit:perform_fitting:222 - Processing frame #29
# 2025-08-27 16:55:40.556 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 1 Weight 1000000000000.0	 ICF error 2.121552247363983
# 2025-08-27 16:55:42.150 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 2 Weight 200000000000.0	 ICF error 2.0023594301016407
# 2025-08-27 16:55:43.769 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 3 Weight 40000000000.0	 ICF error 1.9398876953000548
# 2025-08-27 16:55:45.434 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 4 Weight 8000000000.0	 ICF error 1.9239934508620917
# 2025-08-27 16:55:47.073 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 5 Weight 1600000000.0	 ICF error 1.9125946387581605
# 2025-08-27 16:55:48.679 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 6 Weight 320000000.0	 ICF error 1.906776037174593
# 2025-08-27 16:55:50.345 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 7 Weight 64000000.0	 ICF error 1.8814983531407639
# 2025-08-27 16:55:52.035 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 8 Weight 12800000.0	 ICF error 1.8064296090658378
# 2025-08-27 16:55:53.677 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 9 Weight 2560000.0	 ICF error 1.6936244660275988
# 2025-08-27 16:55:55.313 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 10 Weight 512000.0	 ICF error 1.548613958607722
# 2025-08-27 16:55:56.922 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 11 Weight 102400.0	 ICF error 1.3854222983125268
# 2025-08-27 16:55:58.634 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 12 Weight 20480.0	 ICF error 1.256742109242034
# 2025-08-27 16:55:58.985 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 13 Weight 51200.0	 ICF error 1.256742109242034
# 2025-08-27 16:55:59.910 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 14 Weight 64000.0	 ICF error 1.256742109242034
# 2025-08-27 16:56:00.893 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:277 -      Iteration 15 Weight 40000.0	 ICF error 1.256742109242034
# 2025-08-27 16:56:01.738 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_least_squares_problem:318 - End of the implicitly constrained fit. Time taken: 21.356348276138306
# 2025-08-27 16:56:01.943 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 1 Smoothing weight 1000000.0	 ECF error 1.256742109242034
# 2025-08-27 16:56:11.357 | INFO     | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:99 -      Iteration 2 Smoothing weight 1000000.0	 ECF error 1.248303577963351
# 2025-08-27 16:56:18.485 | SUCCESS  | bivme.fitting.diffeomorphic_fitting_utils:solve_convex_problem:186 - End of the explicitly constrained fit. Time taken: 16.744382858276367
# 2025-08-27 16:56:34.409 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_LV_ENDOCARDIAL_029.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:56:34.443 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_EPICARDIAL_029.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# 2025-08-27 16:56:34.475 | SUCCESS  | bivme.fitting.perform_fit:perform_fitting:423 - cardiohance_073_RV_ENDOCARDIAL_029.vtk successfully saved to C:\Users\jdil469\bivme-data\fitting\fitted-geometries\boris-cim-v2\cardiohance_073\vtk
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2025-08-27 16:56:34.533 | INFO     | main:run_fitting:38 - Average residuals: 1.2759336008523945 for case cardiohance_073

# %% [markdown]
# ## (Optional) Analysis and/or visualisation of models
# You can visualise the fitted models frame-by-frame in your browser by opening an html in `output_directory\case\html`. Alternatively, if you have a mesh visualisation software, you can load in the .vtk or .obj files you generated to view the meshes beating through time. I recommend Paraview, as it is open source, and has nice camera controls for creating  videos of the meshes beating through time.
#
# We haven't added any analysis tools to this notebook yet. Refer to the main README on how to generate metrics from the biv-me models.
